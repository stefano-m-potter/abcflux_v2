# %%
#!/usr/bin/env python3
# Robust EASE-Grid 2.0 sampling (EPSG:6933) for SMAP L4 soil moisture (North-hemisphere subset in your files)
# - Reprojects sites to EPSG:6933 (EASE-Grid 2.0 Global, 9 km)
# - Computes (row, col) from a 90°N anchor (no hard-coded XMIN/YMAX)
# - Auto-detects subset height from the data (e.g., 40N+ => 289 rows)
# - Indexes sm_surface / sm_rootzone directly
# - Writes monthly CSV for 2000–2023

import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
from pyproj import Transformer

# -------------------- CONFIG --------------------
SHAPEFILE   = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_sites.shp"
H5_DIR      = "/explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture"
OUT_CSV     = "/explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv"

START_YEAR  = 2000
END_YEAR    = 2023

# EASE-Grid 2.0 Global (EPSG:6933) constants for 9-km product
PIX_SIZE_M    = 9000.0          # meters
GLOBAL_NCOLS  = 3856            # confirmed global width
FILLVALUE     = -9999.0
# ------------------------------------------------

def build_filename(year: int, month: int) -> str:
    return f"L4_SM_NRv11-4_40N+_soil_moisture_Y{year:04d}M{month:02d}.h5"

def read_arrays(h5_path: str):
    """Open H5 and return (sm_surface, sm_rootzone) as float32 numpy arrays with FILLVALUE set to NaN."""
    ds = xr.open_dataset(h5_path, engine="h5netcdf", phony_dims="sort")
    sm_surf = ds["sm_surface"].values.astype("float32")
    sm_root = ds["sm_rootzone"].values.astype("float32")
    sm_surf[sm_surf == FILLVALUE] = np.nan
    sm_root[sm_root == FILLVALUE] = np.nan
    # Mild sanity: width should match global columns
    nrows, ncols = sm_surf.shape
    if ncols != GLOBAL_NCOLS:
        raise ValueError(f"Unexpected number of columns {ncols} in {os.path.basename(h5_path)}; expected {GLOBAL_NCOLS}.")
    return sm_surf, sm_root

def make_transformer():
    # lon/lat -> EPSG:6933
    return Transformer.from_crs("EPSG:4326", "EPSG:6933", always_xy=True)

def compute_row_anchor(transformer):
    """
    Compute projected Y at 90N to anchor the TOP of the north-hemisphere grid.
    Row index is measured down from this anchor in PIX_SIZE_M increments.
    """
    _, y90 = transformer.transform(0.0, 90.0)
    return y90  # row 0 at 90N

def lonlat_to_epsg6933(transformer, lon, lat):
    return transformer.transform(lon, lat)

def xy_to_colrow_from_anchors(x_m, y_m, y_top_anchor):
    """
    Column (centered): col = floor(x/PIX + GLOBAL_NCOLS/2)
    Row anchored to y at 90N: row_global_from_90 = floor((y_top_anchor - y)/PIX)
    For any north-hemisphere subset starting at 90N, local rows are the same as row_global_from_90,
    and validity is determined by checking within the current array's (nrows, ncols).
    """
    col = int(np.floor(x_m / PIX_SIZE_M + GLOBAL_NCOLS / 2.0))
    row_from_90 = int(np.floor((y_top_anchor - y_m) / PIX_SIZE_M))
    return col, row_from_90

def find_first_existing_file():
    """Locate the first existing monthly file to report subset shape for logging."""
    for year in range(START_YEAR, END_YEAR + 1):
        for month in range(1, 13):
            fpath = os.path.join(H5_DIR, build_filename(year, month))
            if os.path.exists(fpath):
                try:
                    sm_surface, _ = read_arrays(fpath)
                    return fpath, sm_surface.shape
                except Exception:
                    # Keep looking if a particular month is corrupt
                    pass
    return None, None

def main():
    # Load sites; keep only rows with geometry
    gdf = gpd.read_file(SHAPEFILE)
    gdf = gdf[gdf.geometry.notnull()].copy()
    if gdf.crs is None:
        gdf = gdf.set_crs("EPSG:4326")
    else:
        gdf = gdf.to_crs("EPSG:4326")

    # Normalize site id column
    if "site_refer" in gdf.columns and "site_reference" not in gdf.columns:
        gdf = gdf.rename(columns={"site_refer": "site_reference"})
    if "site_reference" not in gdf.columns:
        gdf["site_reference"] = [f"site_{i}" for i in range(len(gdf))]

    # Prepare transformer and compute top (90N) y-anchor
    tf = make_transformer()
    y_top = compute_row_anchor(tf)

    # Precompute site indices (no lat-cut; bounds checked later per file)
    site_index_info = []
    for _, row in gdf.iterrows():
        lon, lat = row.geometry.x, row.geometry.y
        x_m, y_m = lonlat_to_epsg6933(tf, lon, lat)
        col, row_from_90 = xy_to_colrow_from_anchors(x_m, y_m, y_top)
        site_index_info.append({
            "site_reference": row["site_reference"],
            "col": col,
            "row_from_90": row_from_90
        })

    site_idx_df = pd.DataFrame(site_index_info)
    # Ensure numeric dtype
    site_idx_df["row_from_90"] = pd.to_numeric(site_idx_df["row_from_90"], errors="coerce")
    site_idx_df["col"]         = pd.to_numeric(site_idx_df["col"], errors="coerce")

    # Log the subset shape (from first available file)
    first_file, first_shape = find_first_existing_file()
    if first_file and first_shape:
        nrows0, ncols0 = first_shape
        print(f"[INFO] First available file: {os.path.basename(first_file)} has shape {first_shape} "
              f"(implies subset height {nrows0} rows from 90°N).")
    else:
        print("[WARN] Could not locate any input files to infer subset shape; proceeding anyway.")

    records = []

    for year in range(START_YEAR, END_YEAR + 1):
        for month in range(1, 13):
            fpath = os.path.join(H5_DIR, build_filename(year, month))
            if not os.path.exists(fpath):
                print(f"[WARN] Missing file: {fpath}")
                continue

            try:
                sm_surface, sm_rootzone = read_arrays(fpath)
            except Exception as e:
                print(f"[ERROR] {fpath}: {e}")
                continue

            nrows, ncols = sm_surface.shape  # subset rows may be 289 for 40N+, etc.

            # Sample each site using direct numpy indexing
            for _, r in site_idx_df.iterrows():
                rs = int(r["row_from_90"]) if pd.notna(r["row_from_90"]) else -1
                cs = int(r["col"])         if pd.notna(r["col"])         else -1

                if (0 <= rs < nrows) and (0 <= cs < ncols):
                    val_s = sm_surface[rs, cs]
                    val_r = sm_rootzone[rs, cs]
                else:
                    val_s = np.nan
                    val_r = np.nan

                records.append({
                    "site_reference": r["site_reference"],
                    "year": year,
                    "month": month,
                    "sm_surface": float(val_s) if np.isfinite(val_s) else np.nan,
                    "sm_rootzone": float(val_r) if np.isfinite(val_r) else np.nan
                })

    out_df = pd.DataFrame.from_records(records)
    out_df.sort_values(["site_reference", "year", "month"], inplace=True)
    out_df.to_csv(OUT_CSV, index=False)
    print(f"Saved: {OUT_CSV}  (rows={len(out_df)})")

if __name__ == "__main__":
    main()
# Out:
# [INFO] First available file: L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.h5 has shape (289, 3856) (implies subset height 289 rows from 90°N).
# Saved: /explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv  (rows=616032)

# %%
df = pd.read_csv('/explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv')

df
# Out:
#                                    site_reference  year  month  sm_surface  \
# 0       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      1    0.538579
# 1       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      2    0.538579
# 2       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      3    0.538579
# 3       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      4    0.639189
# 4       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      5    0.660515
# ...                                           ...   ...    ...         ...
# 617467                        Zotino_RU-Zot_tower  2023      8    0.226507
# 617468                        Zotino_RU-Zot_tower  2023      9    0.208362
# 617469                        Zotino_RU-Zot_tower  2023     10    0.234460
# 617470                        Zotino_RU-Zot_tower  2023     11    0.238286
# 617471                        Zotino_RU-Zot_tower  2023     12    0.238286
#
#         sm_rootzone
# 0          0.848821
# 1          0.848813
# 2          0.848805
# 3          0.881813
# 4          0.897082
# ...             ...
# 617467     0.151379
# 617468     0.137487
# 617469     0.144890
# 617470     0.152914
# 617471     0.152905
#
# [617472 rows x 5 columns]

# %%
df['sm_surface'].unique()
# Out:
# array([nan])

# %% [markdown]
# Save to tif file

# %%
#!/usr/bin/env python3
# Convert SMAP L4 soil moisture H5 monthly files (40N+) to GeoTIFFs
# snapped to an existing grid (grid.tif) using bilinear resampling.
#
# - Input: H5 SMAP L4 soil moisture, 40N+ subset in EPSG:6933 (EASE-Grid 2.0, 9 km)
# - Target: grid.tif (any EPSG/resolution/extent); we fully snap to this grid.
# - Output: one 2-band GeoTIFF per year-month:
#       band 1 = sm_surface
#       band 2 = sm_rootzone

import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import xarray as xr
from pyproj import Transformer

import rasterio
from rasterio.transform import Affine
from rasterio.warp import reproject, Resampling

# -------------------- CONFIG --------------------
H5_DIR      = "/explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture"
OUT_DIR_TIF = "/explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif"
GRID_TIF    = "/explore/nobackup/people/spotter5/anna_v/v2/grid.tif"

os.makedirs(OUT_DIR_TIF, exist_ok=True)

START_YEAR  = 2000
END_YEAR    = 2023

# EASE-Grid 2.0 Global (EPSG:6933) constants for 9-km product
PIX_SIZE_M    = 9000.0          # meters
GLOBAL_NCOLS  = 3856            # confirmed global width
FILLVALUE     = -9999.0
SRC_CRS       = "EPSG:6933"
# ------------------------------------------------

def build_filename(year: int, month: int) -> str:
    return f"L4_SM_NRv11-4_40N+_soil_moisture_Y{year:04d}M{month:02d}.h5"

def build_tif_name(year: int, month: int) -> str:
    return f"L4_SM_NRv11-4_40N+_soil_moisture_Y{year:04d}M{month:02d}.tif"

def read_arrays(h5_path: str):
    """Open H5 and return (sm_surface, sm_rootzone) as float32 numpy arrays with FILLVALUE set to NaN."""
    ds = xr.open_dataset(h5_path, engine="h5netcdf", phony_dims="sort")
    sm_surf = ds["sm_surface"].values.astype("float32")
    sm_root = ds["sm_rootzone"].values.astype("float32")
    sm_surf[sm_surf == FILLVALUE] = np.nan
    sm_root[sm_root == FILLVALUE] = np.nan
    # Mild sanity: width should match global columns
    nrows, ncols = sm_surf.shape
    if ncols != GLOBAL_NCOLS:
        raise ValueError(
            f"Unexpected number of columns {ncols} in {os.path.basename(h5_path)}; "
            f"expected {GLOBAL_NCOLS}."
        )
    return sm_surf, sm_root

def make_transformer():
    # lon/lat -> EPSG:6933
    return Transformer.from_crs("EPSG:4326", SRC_CRS, always_xy=True)

def compute_y_top_anchor(transformer):
    """
    Compute projected Y at 90N to anchor the TOP of the north-hemisphere grid.
    Row index is measured down from this anchor in PIX_SIZE_M increments.
    """
    _, y90 = transformer.transform(0.0, 90.0)
    return y90  # row 0 at 90N (top of grid)

def build_global_transform(y_top_anchor: float) -> Affine:
    """
    Build the Affine transform for the GLOBAL grid (full width),
    given the y-coordinate at 90N (top edge of the first row).

    Column indexing:
        col = floor(x / PIX_SIZE_M + GLOBAL_NCOLS/2)

    Pixel center:
        x_center = (col - GLOBAL_NCOLS/2 + 0.5) * PIX_SIZE_M
    Upper-left pixel CORNER:
        x_min = -GLOBAL_NCOLS/2 * PIX_SIZE_M

    For rows:
        row_from_90 = floor((y_top_anchor - y) / PIX_SIZE_M)
    Pixel center for row 0: y_top_anchor - 0.5 * PIX_SIZE_M
    Upper-left pixel CORNER: y_max = y_top_anchor
    """
    x_min = -GLOBAL_NCOLS / 2.0 * PIX_SIZE_M
    y_max = y_top_anchor
    transform = Affine(
        PIX_SIZE_M, 0.0, x_min,
        0.0, -PIX_SIZE_M, y_max
    )
    return transform

def find_first_existing_file():
    """Locate the first existing monthly file to report subset shape for logging."""
    for year in range(START_YEAR, END_YEAR + 1):
        for month in range(1, 13):
            fpath = os.path.join(H5_DIR, build_filename(year, month))
            if os.path.exists(fpath):
                try:
                    sm_surface, _ = read_arrays(fpath)
                    return fpath, sm_surface.shape
                except Exception:
                    # Keep looking if a particular month is corrupt
                    pass
    return None, None

def main():
    # Prepare transformer and compute top (90N) y-anchor, then global transform
    tf = make_transformer()
    y_top = compute_y_top_anchor(tf)
    global_transform = build_global_transform(y_top)

    # Log the subset shape (from first available file)
    first_file, first_shape = find_first_existing_file()
    if first_file and first_shape:
        nrows0, ncols0 = first_shape
        print(
            f"[INFO] First available file: {os.path.basename(first_file)} "
            f"has shape {first_shape} "
            f"(subset height {nrows0} rows, width {ncols0} cols)."
        )
    else:
        print("[WARN] Could not locate any input files to infer subset shape; proceeding anyway.")

    # Read target grid (snap to this)
    with rasterio.open(GRID_TIF) as grid_src:
        grid_profile = grid_src.profile
        dst_transform = grid_src.transform
        dst_crs       = grid_src.crs
        dst_height    = grid_src.height
        dst_width     = grid_src.width

    print(f"[INFO] Target grid: {GRID_TIF}")
    print(f"       CRS: {dst_crs}")
    print(f"       Size: {dst_width} x {dst_height}")

    # Base output profile: copy from grid but adjust for our data
    base_profile = grid_profile.copy()
    base_profile.update(
        driver="GTiff",
        count=2,               # surface + rootzone
        dtype="float32",
        compress="LZW",
        nodata=np.nan
    )

    # Loop over year/month, convert each H5 to a 2-band GeoTIFF snapped to grid.tif
    for year in range(START_YEAR, END_YEAR + 1):
        for month in range(1, 13):
            h5_path = os.path.join(H5_DIR, build_filename(year, month))
            if not os.path.exists(h5_path):
                print(f"[WARN] Missing file: {h5_path}")
                continue

            tif_path = os.path.join(OUT_DIR_TIF, build_tif_name(year, month))
            if os.path.exists(tif_path):
                print(f"[INFO] Output exists, skipping: {tif_path}")
                continue

            try:
                sm_surface, sm_rootzone = read_arrays(h5_path)
            except Exception as e:
                print(f"[ERROR] {h5_path}: {e}")
                continue

            # Prepare destination arrays on the target grid
            dst_surface  = np.full((dst_height, dst_width), np.nan, dtype="float32")
            dst_rootzone = np.full((dst_height, dst_width), np.nan, dtype="float32")

            # Reproject to target grid with bilinear resampling
            print(f"[INFO] Reprojecting {os.path.basename(h5_path)} → snapped to grid (bilinear)")

            reproject(
                source=sm_surface,
                destination=dst_surface,
                src_transform=global_transform,
                src_crs=SRC_CRS,
                dst_transform=dst_transform,
                dst_crs=dst_crs,
                resampling=Resampling.bilinear,
                src_nodata=np.nan,
                dst_nodata=np.nan,
            )

            reproject(
                source=sm_rootzone,
                destination=dst_rootzone,
                src_transform=global_transform,
                src_crs=SRC_CRS,
                dst_transform=dst_transform,
                dst_crs=dst_crs,
                resampling=Resampling.bilinear,
                src_nodata=np.nan,
                dst_nodata=np.nan,
            )

            # Write snapped GeoTIFF
            profile = base_profile.copy()
            print(f"[INFO] Writing {tif_path}")
            with rasterio.open(tif_path, "w", **profile) as dst:
                dst.write(dst_surface, 1)
                dst.write(dst_rootzone, 2)

    print(f"[DONE] Snapped GeoTIFFs written to: {OUT_DIR_TIF}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] First available file: L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.h5 has shape (289, 3856) (subset height 289 rows, width 3856 cols).
# [INFO] Target grid: /explore/nobackup/people/spotter5/anna_v/v2/grid.tif
#        CRS: EPSG:3413
#        Size: 11320 x 11320
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2000M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2001M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2002M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2003M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2004M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2005M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2006M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2007M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2008M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2009M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2010M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2011M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2012M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2013M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2014M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2015M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2016M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M10.tif
# ...
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2018M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2018M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2019M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2020M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2021M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2022M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M12.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M01.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M01.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M02.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M02.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M03.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M03.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M04.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M04.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M05.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M05.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M06.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M06.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M07.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M07.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M08.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M08.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M09.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M09.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M10.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M10.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M11.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M11.tif
# [INFO] Reprojecting L4_SM_NRv11-4_40N+_soil_moisture_Y2023M12.h5 → snapped to grid (bilinear)
# [INFO] Writing /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M12.tif
# [DONE] Snapped GeoTIFFs written to: /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture_tif

# %%
't'
# Out:
# 't'
