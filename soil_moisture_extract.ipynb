# %%
#!/usr/bin/env python3
# Exact EASE-Grid 2.0 sampling (EPSG:6933) for SMAP L4 soil moisture (45N+ monthly subset)
# - Reprojects sites to EPSG:6933 (EASE-Grid 2.0 Global, 9 km)
# - Computes (row, col) using a projection-anchored formula (no hard-coded XMIN/YMAX)
# - Indexes sm_surface / sm_rootzone directly
# - Writes monthly CSV for 2000–2023

import os
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
from pyproj import Transformer

# -------------------- CONFIG --------------------
SHAPEFILE   = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_sites.shp"
H5_DIR      = "/explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture"
OUT_CSV     = "/explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv"

START_YEAR  = 2000
END_YEAR    = 2023

# EASE-Grid 2.0 Global (EPSG:6933) constants for 9-km product
PIX_SIZE_M    = 9000.0          # meters
GLOBAL_NCOLS  = 3856            # confirmed by your arrays (width)
SUBSET_NROWS  = 236             # confirmed by your arrays (height 90N→45N)
FILLVALUE     = -9999.0
# ------------------------------------------------

def build_filename(year: int, month: int) -> str:
    return f"L4_SM_NRv11-4_40N+_soil_moisture_Y{year:04d}M{month:02d}.h5"

def read_arrays(h5_path: str):
    """Open H5 and return (sm_surface, sm_rootzone) as float32 numpy arrays with FILLVALUE set to NaN."""
    ds = xr.open_dataset(h5_path, engine="h5netcdf", phony_dims="sort")
    sm_surf = ds["sm_surface"].values.astype("float32")
    sm_root = ds["sm_rootzone"].values.astype("float32")
    sm_surf[sm_surf == FILLVALUE] = np.nan
    sm_root[sm_root == FILLVALUE] = np.nan
    # Sanity shape check
    nrows, ncols = sm_surf.shape
    if (nrows, ncols) != (SUBSET_NROWS, GLOBAL_NCOLS):
        raise ValueError(f"Unexpected array shape {sm_surf.shape} in {os.path.basename(h5_path)}; "
                         f"expected ({SUBSET_NROWS}, {GLOBAL_NCOLS}).")
    return sm_surf, sm_root

def make_transformer():
    # lon/lat -> EPSG:6933
    return Transformer.from_crs("EPSG:4326", "EPSG:6933", always_xy=True)

def compute_row_anchor(transformer):
    """
    Compute projected Y at 90N to anchor the TOP of the north-hemisphere grid.
    Row index is measured down from this anchor in PIX_SIZE_M increments.
    """
    x90, y90 = transformer.transform(0.0, 90.0)
    x45, y45 = transformer.transform(0.0, 45.0)
    est_rows_45N = (y90 - y45) / PIX_SIZE_M
    print(f"[INFO] Projected span 90N→45N ≈ {est_rows_45N:.2f} rows (expected ~{SUBSET_NROWS})")
    return y90  # top anchor (row 0 at 90N)

def lonlat_to_epsg6933(transformer, lon, lat):
    return transformer.transform(lon, lat)

def xy_to_colrow_from_anchors(x_m, y_m, y_top_anchor):
    """
    Column (centered): col = floor(x/PIX + GLOBAL_NCOLS/2)
    Row anchored to y at 90N: row_global_from_90 = floor((y_top_anchor - y)/PIX)
    For the 45N+ subset, local rows are the first SUBSET_NROWS starting at 90N.
    """
    col = int(np.floor(x_m / PIX_SIZE_M + GLOBAL_NCOLS / 2.0))
    row_global_from_90 = int(np.floor((y_top_anchor - y_m) / PIX_SIZE_M))
    row_local = row_global_from_90  # subset starts right at 90N
    return col, row_local

def main():
    # Load sites; keep only rows with geometry
    gdf = gpd.read_file(SHAPEFILE)
    gdf = gdf[gdf.geometry.notnull()].copy()
    if gdf.crs is None:
        gdf = gdf.set_crs("EPSG:4326")

    # Normalize site id column
    if "site_refer" in gdf.columns and "site_reference" not in gdf.columns:
        gdf = gdf.rename(columns={"site_refer": "site_reference"})
    if "site_reference" not in gdf.columns:
        gdf["site_reference"] = [f"site_{i}" for i in range(len(gdf))]

    # Prepare transformer and compute top (90N) y-anchor
    tf = make_transformer()
    y_top = compute_row_anchor(tf)

    # Precompute site indices (allow NaN for out-of-range)
    site_index_info = []
    for _, row in gdf.iterrows():
        lon, lat = row.geometry.x, row.geometry.y

        # Sites south of 45N are outside subset by definition
        if lat < 45.0:
            site_index_info.append({
                "site_reference": row["site_reference"],
                "usable": False,
                "reason": "lat<45N",
                "col": np.nan, "row_local": np.nan
            })
            continue

        x_m, y_m = lonlat_to_epsg6933(tf, lon, lat)
        col, row_local = xy_to_colrow_from_anchors(x_m, y_m, y_top)
        usable = (0 <= col < GLOBAL_NCOLS) and (0 <= row_local < SUBSET_NROWS)

        site_index_info.append({
            "site_reference": row["site_reference"],
            "usable": bool(usable),
            "reason": None if usable else "out_of_bounds",
            "col": col if usable else np.nan,
            "row_local": row_local if usable else np.nan
        })

    site_idx_df = pd.DataFrame(site_index_info)

    # Ensure numeric dtype (avoids float indexing issues)
    site_idx_df["row_local"] = pd.to_numeric(site_idx_df["row_local"], errors="coerce")
    site_idx_df["col"]       = pd.to_numeric(site_idx_df["col"], errors="coerce")

    n_total = len(site_idx_df)
    n_use = int(site_idx_df["usable"].sum())
    n_bad = n_total - n_use
    print(f"[INFO] Sites usable in 40N+ subset: {n_use}/{n_total} "
          f"(excluded south of 40N or out_of_bounds: {n_bad})")
    if n_use == 0:
        print("[WARN] No sites landed in the 45N+ strip. Check site latitudes/CRS.")

    records = []

    for year in range(START_YEAR, END_YEAR + 1):
        for month in range(1, 13):
            fpath = os.path.join(H5_DIR, build_filename(year, month))
            if not os.path.exists(fpath):
                print(f"[WARN] Missing file: {fpath}")
                continue

            try:
                sm_surface, sm_rootzone = read_arrays(fpath)
            except Exception as e:
                print(f"[ERROR] {fpath}: {e}")
                continue

            # Sample each site using direct numpy indexing
            for _, r in site_idx_df.iterrows():
                if (not r["usable"]) or pd.isna(r["row_local"]) or pd.isna(r["col"]):
                    val_s = np.nan
                    val_r = np.nan
                else:
                    rs = int(r["row_local"])
                    cs = int(r["col"])
                    if 0 <= rs < SUBSET_NROWS and 0 <= cs < GLOBAL_NCOLS:
                        val_s = sm_surface[rs, cs]
                        val_r = sm_rootzone[rs, cs]
                    else:
                        val_s = np.nan
                        val_r = np.nan

                records.append({
                    "site_reference": r["site_reference"],
                    "year": year,
                    "month": month,
                    "sm_surface": float(val_s) if np.isfinite(val_s) else np.nan,
                    "sm_rootzone": float(val_r) if np.isfinite(val_r) else np.nan
                })

    out_df = pd.DataFrame.from_records(records)
    out_df.sort_values(["site_reference", "year", "month"], inplace=True)
    out_df.to_csv(OUT_CSV, index=False)
    print(f"Saved: {OUT_CSV}  (rows={len(out_df)})")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Projected span 90N→45N ≈ 240.24 rows (expected ~236)
# [INFO] Sites usable in 40N+ subset: 2143/2144 (excluded south of 40N or out_of_bounds: 1)
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2000M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2000M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2001M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2001M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2002M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2002M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2003M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2003M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2004M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2004M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2005M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2005M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2006M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2006M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2007M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2007M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2008M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2008M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2009M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2009M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2010M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2010M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2011M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2011M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2012M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2012M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2013M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2013M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2014M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2014M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2015M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2015M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2016M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2016M09.h5; expected (236, 3856).
# ...
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2019M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2019M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2020M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2020M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2021M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2021M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2022M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2022M12.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M01.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M01.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M02.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M02.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M03.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M03.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M04.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M04.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M05.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M05.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M06.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M06.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M07.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M07.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M08.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M08.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M09.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M09.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M10.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M10.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M11.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M11.h5; expected (236, 3856).
# [ERROR] /explore/nobackup/people/spotter5/anna_v/v2/L4_SM_NRv11-4_40N+_soil_moisture/L4_SM_NRv11-4_40N+_soil_moisture_Y2023M12.h5: Unexpected array shape (289, 3856) in L4_SM_NRv11-4_40N+_soil_moisture_Y2023M12.h5; expected (236, 3856).
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3017351/1397083140.py in ?()
#     177     out_df.to_csv(OUT_CSV, index=False)
#     178     print(f"Saved: {OUT_CSV}  (rows={len(out_df)})")
#     179
#     180 if __name__ == "__main__":
# --> 181     main()
#
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3017351/1397083140.py in ?()
#     172                     "sm_rootzone": float(val_r) if np.isfinite(val_r) else np.nan
#     173                 })
#     174
#     175     out_df = pd.DataFrame.from_records(records)
# --> 176     out_df.sort_values(["site_reference", "year", "month"], inplace=True)
#     177     out_df.to_csv(OUT_CSV, index=False)
#     178     print(f"Saved: {OUT_CSV}  (rows={len(out_df)})")
#
# ~/.conda/envs/geo/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7175                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7176                 f" != length of by ({len(by)})"
#    7177             )
#    7178         if len(by) > 1:
# -> 7179             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7180
#    7181             # need to rewrap columns in Series to apply key function
#    7182             if key is not None:
#
# ~/.conda/envs/geo/lib/python3.10/site-packages/pandas/core/frame.py in ?(.0)
# -> 7179         ...     key=lambda x: np.argsort(index_natsorted(df["time"]))
#
# ~/.conda/envs/geo/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'site_reference'

# %%
df = pd.read_csv('/explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv')

df
# Out:
#                                    site_reference  year  month  sm_surface  \
# 0       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      1    0.538579
# 1       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      2    0.538579
# 2       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      3    0.538579
# 3       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      4    0.639189
# 4       APEX Beta_Active Margin_AMCH1_agg_chamber  2000      5    0.660515
# ...                                           ...   ...    ...         ...
# 617467                        Zotino_RU-Zot_tower  2023      8    0.226507
# 617468                        Zotino_RU-Zot_tower  2023      9    0.208362
# 617469                        Zotino_RU-Zot_tower  2023     10    0.234460
# 617470                        Zotino_RU-Zot_tower  2023     11    0.238286
# 617471                        Zotino_RU-Zot_tower  2023     12    0.238286
#
#         sm_rootzone
# 0          0.848821
# 1          0.848813
# 2          0.848805
# 3          0.881813
# 4          0.897082
# ...             ...
# 617467     0.151379
# 617468     0.137487
# 617469     0.144890
# 617470     0.152914
# 617471     0.152905
#
# [617472 rows x 5 columns]

# %%
df['sm_surface'].unique()
# Out:
# array([nan])
