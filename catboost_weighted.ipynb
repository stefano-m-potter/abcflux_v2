# %% [markdown]
# LOOSO NEE

# %%
import os
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy import stats
from scipy.special import inv_boxcox

# Suppress warnings
os.environ['PYTHONWARNINGS'] = 'ignore::FutureWarning'
warnings.filterwarnings("ignore", category=FutureWarning)
# warnings.filterwarnings("ignore", category=pd.core.common.SettingWithCopyWarning)


# 1. Load your dataset
file_path = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_alt_soil_lc_co2.csv"
df = pd.read_csv(file_path)

df = df[df['flux_method'] == 'EC']

# 2. Create tmean_C and date
df['tmean_C'] = df[['tmmn', 'tmmx']].mean(axis=1)
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))

# 3. Define predictors and target
feature_cols = [
    'EVI', 'NDVI', 'sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 
    'sur_refl_b07', 'NDWI', 'pdsi', 'srad', 'tmean_C', 'vap', 'vs',
    'bdod_0_100cm', 'cec_0_100cm', 'cfvo_0_100cm', 'clay_0_100cm',
    'nitrogen_0_100cm', 'ocd_0_100cm', 'phh2o_0_100cm', 'sand_0_100cm',
    'silt_0_100cm', 'soc_0_100cm', 'co2_cont', 'ALT',
    'land_cover', 'month' # Categorical features are now included directly
]
target_col = 'nee'
categorical_features = ['land_cover', 'month']

# Drop rows only if the target variable or site_reference is missing.
df = df.dropna(subset=['site_reference', target_col])

# Define output path for CSVs and create it
out_path = os.path.join("/explore/nobackup/people/spotter5/anna_v/v2/loocv", target_col)
os.makedirs(out_path, exist_ok=True)

# Define a separate output path for figures and create it
figures_path = os.path.join(out_path, "figures")
os.makedirs(figures_path, exist_ok=True)

# Prepare features (X) and target (y)
X = df[feature_cols]
y = df[target_col]
sites = df["site_reference"].unique()

# Convert categorical features to 'category' dtype for CatBoost
for col in categorical_features:
    X[col] = X[col].astype('category')

results = []
all_preds_df_list = []

# Leave-One-Site-Out CV
for test_site in sites:
    print(f"Processing site: {test_site}...")
    train_idx = df["site_reference"] != test_site
    test_idx = df["site_reference"] == test_site

    if test_idx.sum() < 1:
        continue

    X_train, y_train = X.loc[train_idx], y.loc[train_idx]
    X_test, y_test = X.loc[test_idx], y.loc[test_idx]
    dates_test = df.loc[test_idx, "date"]

    # --- NEW: Box-Cox Transformation ---
    # Box-Cox requires all data to be positive. We shift the data if necessary.
    shift_value = 0
    min_y_train = y_train.min()
    if min_y_train <= 0:
        # Add a small constant (1) to ensure all values are > 0
        shift_value = -min_y_train + 1
        y_train_shifted = y_train + shift_value
    else:
        y_train_shifted = y_train

    # Apply the Box-Cox transformation and find the optimal lambda
    y_train_transformed, lmbda = stats.boxcox(y_train_shifted)
    print(f"  Applied Box-Cox with lambda={lmbda:.4f} and shift={shift_value:.4f}")
    
    # Initialize and train the CatBoost model on the TRANSFORMED data
    model = CatBoostRegressor(
        iterations=1200, #1200, 8 is best
        learning_rate=0.01,
        depth=12,
        # subsample=0.7,
        l2_leaf_reg=0.1,
        random_state=42,
        cat_features=categorical_features,
        verbose=0, # Suppress verbose output
        allow_writing_files=False
    )
    # Fit the model on the transformed target variable
    model.fit(X_train, y_train_transformed)
    
    # Predict in the transformed space
    y_pred_transformed = model.predict(X_test)

    # --- NEW: Inverse Transformation ---
    # Reverse the Box-Cox transformation to get predictions back to the original scale
    if lmbda == 0:
        # Special case for lambda = 0, which corresponds to a log transform
        y_pred_inv = np.exp(y_pred_transformed)
    else:
        y_pred_inv = inv_boxcox(y_pred_transformed, lmbda)
    
    # Reverse the initial shift
    y_pred_orig_scale = y_pred_inv - shift_value
    
    # Use the correctly scaled prediction for metrics and plotting
    y_pred = y_pred_orig_scale
    # --- End of Transformation Logic ---

    site_df = pd.DataFrame({
        "Site": test_site,
        "Date": dates_test.values,
        "Observed": y_test.values,
        "Predicted": y_pred
    })
    all_preds_df_list.append(site_df)

    # Metrics
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    results.append({
        "Site": test_site,
        "RMSE": rmse,
        "MAE": mae,
        "R2": r2
    })

# Combine results
results_df = pd.DataFrame(results)
all_preds_df = pd.concat(all_preds_df_list, ignore_index=True)

# Save to disk with '_cat' suffix
results_csv_path = os.path.join(out_path, f'catboost_results_{target_col}_cat.csv')
predictions_csv_path = os.path.join(out_path, f'catboost_predictions_{target_col}_cat.csv')
results_df.to_csv(results_csv_path, index=False)
all_preds_df.to_csv(predictions_csv_path, index=False)
print(f"\nResults saved to: {results_csv_path}")
print(f"Predictions saved to: {predictions_csv_path}")


# Pooled metrics
rmse_all = np.sqrt(mean_squared_error(all_preds_df["Observed"], all_preds_df["Predicted"]))
r2_all = r2_score(all_preds_df["Observed"], all_preds_df["Predicted"])
mae_all = mean_absolute_error(all_preds_df["Observed"], all_preds_df["Predicted"])

print("\n--- Site-Specific Results ---")
print(results_df)
print("\n--- Pooled Metrics ---")
print(f"Pooled RMSE: {rmse_all:.4f}")
print(f"Pooled MAE:  {mae_all:.4f}")
print(f"Pooled R²:   {r2_all:.4f}")

# Median metrics across sites
if not results_df.empty:
    median_rmse = results_df["RMSE"].median()
    median_mae = results_df["MAE"].median()
    median_r2 = results_df["R2"].median()

    print("\n--- Median Metrics Across Sites ---")
    print(f"Median RMSE: {median_rmse:.4f}")
    print(f"Median MAE:  {median_mae:.4f}")
    print(f"Median R²:   {median_r2:.4f}")

# --- Plotting ---
unique_sites = all_preds_df["Site"].unique()
if not unique_sites.any():
    print("\nNo sites to plot.")
else:
    print("\nGenerating and saving individual site plots...")
    for site in unique_sites:
        fig, ax = plt.subplots(figsize=(12, 7))
        
        # Check if site exists in results_df before trying to access it
        if site in results_df["Site"].values:
            site_df_plot = all_preds_df[all_preds_df["Site"] == site].sort_values("Date")
            site_metrics = results_df[results_df["Site"] == site].iloc[0]
            rmse_val = round(site_metrics["RMSE"], 2)
            r2_val = round(site_metrics["R2"], 2)
            mae_val = round(site_metrics["MAE"], 2)

            ax.plot(site_df_plot["Date"], site_df_plot["Observed"], label="Observed", marker="o", linestyle='-', markersize=4)
            ax.plot(site_df_plot["Date"], site_df_plot["Predicted"], label="Predicted", marker="x", linestyle='--', markersize=4)
            ax.set_title(f"Observed vs. Predicted {target_col} for Site: {site} (with Box-Cox)")
            ax.set_xlabel("Date")
            ax.set_ylabel(target_col)
            ax.legend()
            ax.grid(True)
            fig.autofmt_xdate()

            textstr = f"RMSE: {rmse_val}\nMAE: {mae_val}\n$R^2$: {r2_val}"
            ax.text(
                0.97, 0.03, textstr,
                transform=ax.transAxes,
                fontsize=10,
                verticalalignment='bottom',
                horizontalalignment='right',
                bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7)
            )
            
            plot_filename = f'catboost_{target_col}_{site}_timeseries_cat.png'
            plot_path = os.path.join(figures_path, plot_filename)
            plt.savefig(plot_path, dpi=300, bbox_inches='tight')
        
        plt.close(fig) # Close the plot to free up memory
        
    print(f"All site plots saved to: {figures_path}")

out_path_model = '/explore/nobackup/people/spotter5/anna_v/v2/models'
os.makedirs(out_path_model, exist_ok = True)
model_filename = f'{target_col}.json'
model.save_model(os.path.join(out_path_model, model_filename))
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3373172/478807503.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].astype('category')
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3373172/478807503.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].astype('category')
# Processing site: Fyodorovskoye_RU-Fyo_tower...
#   Applied Box-Cox with lambda=2.6752 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower...
#   Applied Box-Cox with lambda=2.6106 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, Mature Jack Pine_CA-Ojp_tower...
#   Applied Box-Cox with lambda=2.6434 and shift=218.1562
# Processing site: Flakaliden_SE-Fla_tower...
#   Applied Box-Cox with lambda=2.4694 and shift=198.5322
# Processing site: Hyytiala_FI-Hyy_tower...
#   Applied Box-Cox with lambda=2.5877 and shift=218.1562
# Processing site: Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower...
#   Applied Box-Cox with lambda=2.6311 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower...
#   Applied Box-Cox with lambda=2.6327 and shift=218.1562
# Processing site: Kaamanen_FI-Kaa_tower...
#   Applied Box-Cox with lambda=2.6301 and shift=218.1562
# Processing site: Nelegel_RU-Nel_tower...
#   Applied Box-Cox with lambda=2.6393 and shift=218.1562
# Processing site: Neleger Burnt Forest_RU-NeB_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
# Processing site: Neleger larch forest_RU-NeF_tower...
#   Applied Box-Cox with lambda=2.6354 and shift=218.1562
# Processing site: Zackenberg Heath_GL-ZaH_tower...
#   Applied Box-Cox with lambda=2.6335 and shift=218.1562
# Processing site: Central Marsh_US-Cms_tower...
#   Applied Box-Cox with lambda=2.6329 and shift=218.1562
# Processing site: Yakutsk Spasskaya Pad larch_RU-SkP_tower...
#   Applied Box-Cox with lambda=2.6340 and shift=218.1562
# Processing site: Zotino; Central Siberia_RU-Zfw 2_tower...
#   Applied Box-Cox with lambda=2.6365 and shift=218.1562
# Processing site: Degero_SE-Deg_tower...
#   Applied Box-Cox with lambda=2.6320 and shift=218.1562
# Processing site: Sodankyla_FI-Sod_tower...
#   Applied Box-Cox with lambda=2.6252 and shift=218.1562
# Processing site: UCI-1964 burn site_CA-NS3_tower...
#   Applied Box-Cox with lambda=2.6353 and shift=218.1562
# Processing site: Neleger Cutover_RU-NeC_tower...
#   Applied Box-Cox with lambda=2.6420 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower...
#   Applied Box-Cox with lambda=2.6362 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower...
#   Applied Box-Cox with lambda=2.6453 and shift=218.1562
# Processing site: UCI-1998 burn site_CA-NS7_tower...
#   Applied Box-Cox with lambda=2.6342 and shift=218.1562
# Processing site: UCI-1930 burn site_CA-NS2_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
# Processing site: UCI-1981 burn site_CA-NS5_tower...
#   Applied Box-Cox with lambda=2.6354 and shift=218.1562
# Processing site: UCI-1989 burn site_CA-NS6_tower...
#   Applied Box-Cox with lambda=2.6349 and shift=218.1562
# Processing site: Delta Junction deciduous broadleaf forest_US-Bn1_tower...
#   Applied Box-Cox with lambda=2.6378 and shift=218.1562
# Processing site: Samoylov Island_RU-Sam_tower...
#   Applied Box-Cox with lambda=2.6396 and shift=218.1562
# Processing site: Zotino_RU-Zot_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
# Processing site: UCI-1850 burn site_CA-NS1_tower...
#   Applied Box-Cox with lambda=2.6375 and shift=218.1562
# Processing site: Hakasia 5yr_RU-Ha2_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
# Processing site: Hakasia Steppe_RU-Ha1_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
# Processing site: UCI-1964 burn site wet_CA-NS4_tower...
#   Applied Box-Cox with lambda=2.6372 and shift=218.1562
# Processing site: Norunda_SE-Nor_tower...
#   Applied Box-Cox with lambda=2.8675 and shift=218.1562
# Processing site: Delta Junction  evergreen conifer forest_US-Bn2_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
# Processing site: Kherlenbayan Ulaan_MN-Kbu_tower...
#   Applied Box-Cox with lambda=2.6450 and shift=218.1562
# Processing site: Southern Khentei Taiga_MN-Skt_tower...
#   Applied Box-Cox with lambda=2.6161 and shift=218.1562
# Processing site: University of Alaska, Fairbanks_US-Uaf_tower...
#   Applied Box-Cox with lambda=2.6355 and shift=218.1562
# Processing site: Kytalyk, Russia_RU-Cok_tower...
#   Applied Box-Cox with lambda=2.6378 and shift=218.1562
# Processing site: Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower...
#   Applied Box-Cox with lambda=2.6298 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, forest burned in 1977_CA-SF1_tower...
#   Applied Box-Cox with lambda=2.7274 and shift=218.1562
# Processing site: Alberta - Western Peatland - LaBiche River,Black Spruce,Larch Fen_CA-WP1_tower...
#   Applied Box-Cox with lambda=2.6318 and shift=218.1562
# Processing site: Quebec - Eastern Boreal, Mature Black Spruce_CA-Qfo_tower...
#   Applied Box-Cox with lambda=2.6337 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, Jack Pine harvested in 1975_CA-SJ3_tower...
#   Applied Box-Cox with lambda=2.6379 and shift=218.1562
# Processing site: Skyttorp 2_SE-Sk2_tower...
#   Applied Box-Cox with lambda=2.6372 and shift=218.1562
# Processing site: HJP02 Jack Pine_CA-HJP02_tower...
#   Applied Box-Cox with lambda=2.6350 and shift=218.1562
# Processing site: HJP94 Jack Pine_CA-HJP94_tower...
#   Applied Box-Cox with lambda=2.6371 and shift=218.1562
# Processing site: Saskatchewan - Western Boreal, Jack Pine harvested in 2002_CA-SJ2_tower...
#   Applied Box-Cox with lambda=2.6319 and shift=218.1562
# Processing site: Hakasia 10 yr_RU-Ha3_tower...
#   Applied Box-Cox with lambda=2.6387 and shift=218.1562
# Processing site: Alberta - Western Peatland - Poor Fen (Sphagnum moss)_CA-WP2_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
# Processing site: Alberta - Western Peatland - Rich Fen  (Carex)_CA-WP3_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
# Processing site: HJP75 Jack Pine_CA-HJP75_tower...
#   Applied Box-Cox with lambda=2.6387 and shift=218.1562
# Processing site: Ivotuk_US-Ivo_tower...
#   Applied Box-Cox with lambda=2.6327 and shift=218.1562
# Processing site: Yakutsk Spasskaya Pad Pine_RU-Sk2_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
# Processing site: Atqasuk_US-Atq_tower...
#   Applied Box-Cox with lambda=2.6305 and shift=218.1562
# Processing site: Daring Lake_CA-DL1_tower...
#   Applied Box-Cox with lambda=2.6370 and shift=218.1562
# Processing site: Tura_RU-Tur_tower...
#   Applied Box-Cox with lambda=2.6428 and shift=218.1562
# Processing site: Kalevansuo_FI-Kns_tower...
#   Applied Box-Cox with lambda=2.6313 and shift=218.1562
# Processing site: Skyttorp 1_SE-Sk1_tower...
#   Applied Box-Cox with lambda=2.6338 and shift=218.1562
# Processing site: Siikaneva_FI-Sii_tower...
#   Applied Box-Cox with lambda=2.6286 and shift=218.1562
# Processing site: Barrow-BES_US-Bes_tower...
#   Applied Box-Cox with lambda=2.6344 and shift=218.1562
# Processing site: Faejemyr_SE-Faj_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
# Processing site: Knottasen_SE-Kno_tower...
#   Applied Box-Cox with lambda=2.6608 and shift=218.1562
# Processing site: Salmisuo_FI-Salm_tower...
#   Applied Box-Cox with lambda=2.6376 and shift=218.1562
# Processing site: Lompolojankka_FI-Lom_tower...
#   Applied Box-Cox with lambda=2.6310 and shift=218.1562
# Processing site: Churchill Fen Site 1_CA-CF1_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
# Processing site: Imnavait Creek Watershed Tussock Tundra_US-ICt_tower...
#   Applied Box-Cox with lambda=2.6261 and shift=218.1562
# Processing site: Imnavait Creek Watershed Heath Tundra_US-ICh_tower...
#   Applied Box-Cox with lambda=2.6244 and shift=218.1562
# Processing site: Imnavait Creek Watershed Wet Sedge Tundra_US-ICs_tower...
#   Applied Box-Cox with lambda=2.6239 and shift=218.1562
# Processing site: Quebec - 1975 Harvested Black Spruce_CA-Qc2_tower...
#   Applied Box-Cox with lambda=2.6403 and shift=218.1562
# Processing site: Eight Mile Lake_US-EML_tower...
#   Applied Box-Cox with lambda=2.6315 and shift=218.1562
# Processing site: Tervalamminsuo_Wet_tower...
#   Applied Box-Cox with lambda=2.6375 and shift=218.1562
# Processing site: NGEE Arctic Barrow_US-NGB_tower...
#   Applied Box-Cox with lambda=2.6381 and shift=218.1562
# Processing site: Cherskii disturbed forest_RU-Eusk_cher2_tower...
#   Applied Box-Cox with lambda=2.6339 and shift=218.1562
# Processing site: Disko_GL-Dsk_tower...
#   Applied Box-Cox with lambda=2.6305 and shift=218.1562
# Processing site: Havikpak Creek_CA-HPC_tower...
#   Applied Box-Cox with lambda=2.6346 and shift=218.1562
# Processing site: Scotty Creek Landscape_CA-SCC_tower...
#   Applied Box-Cox with lambda=2.6333 and shift=218.1562
# Processing site: ZOTTO Bog_RU-Zo1_tower...
#   Applied Box-Cox with lambda=2.6389 and shift=218.1562
# Processing site: ZOTTO Forest_RU-Zo2_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
# Processing site: Trail Valley Creek_CA-TVC_tower...
#   Applied Box-Cox with lambda=2.6310 and shift=218.1562
# Processing site: Cherskii reference_RU-Ch2_tower...
#   Applied Box-Cox with lambda=2.6274 and shift=218.1562
# Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower...
#   Applied Box-Cox with lambda=2.6390 and shift=218.1562
# Processing site: Barrow-CMDL_US-Brw_tower...
#   Applied Box-Cox with lambda=2.6291 and shift=218.1562
# Processing site: Svartberget_SE-Svb_tower...
#   Applied Box-Cox with lambda=2.6267 and shift=218.1562
# Processing site: Scotty Creek Bog_CA-SCB_tower...
#   Applied Box-Cox with lambda=2.6320 and shift=218.1562
# Processing site: Stordalen Palsa Bog_SE-Sto_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
# Processing site: Barrow-BEO_US-Beo_tower...
#   Applied Box-Cox with lambda=2.6339 and shift=218.1562
# Processing site: Council, Alaska_US-KOC_tower...
#   Applied Box-Cox with lambda=2.6402 and shift=218.1562
# Processing site: Rosinedal-3_SE-Ros_tower...
#   Applied Box-Cox with lambda=2.6309 and shift=218.1562
# Processing site: ARM-NSA-Oliktok_US-A03_tower...
#   Applied Box-Cox with lambda=2.6427 and shift=218.1562
# Processing site: Hyltemossa_SE-Htm_tower...
#   Applied Box-Cox with lambda=2.6296 and shift=218.1562
# Processing site: Bibai bog_JP-Bby_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
# Processing site: Fyodorovskoye2_RU-Fy2_tower...
#   Applied Box-Cox with lambda=2.6473 and shift=218.1562
# Processing site: Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower...
#   Applied Box-Cox with lambda=2.6383 and shift=218.1562
# Processing site: Mukhrino_Mukhrino_RHC_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
# Processing site: Nalaikh grassland_MN-Nkh_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
# Processing site: Wolf_creek_Buckbrush_CA-WCBB_tower...
#   Applied Box-Cox with lambda=2.6304 and shift=218.1562
# Processing site: Wolf_creek_SparseShrub_CA-WCPLT_tower...
#   Applied Box-Cox with lambda=2.6304 and shift=218.1562
# Processing site: Hustai grassland_MN-Hst_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
# Processing site: Igarka_RU-Iga_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
# Processing site: Wolf_creek_forest_CA-WCF_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
# Processing site: Umiujaq_tower...
#   Applied Box-Cox with lambda=2.6360 and shift=218.1562
# Processing site: Fish Island_FI-NWT_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
# Processing site: Smith Creek_CA-SMC_tower...
#   Applied Box-Cox with lambda=2.6336 and shift=218.1562
# Processing site: NGEE Arctic Council_US-NGC_tower...
#   Applied Box-Cox with lambda=2.6373 and shift=218.1562
# Processing site: NEON Delta Junction (DEJU)_US-xDJ_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
# Processing site: Bonanza Creek Old Thermokarst Bog_US-BZo_tower...
#   Applied Box-Cox with lambda=2.6364 and shift=218.1562
# Processing site: NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
# Processing site: NEON Healy (HEAL)_US-xHE_tower...
#   Applied Box-Cox with lambda=2.6346 and shift=218.1562
# Processing site: Bouleau peatland_CA-BOU_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
# Processing site: Bernard spruce-moss valley_tower...
#   Applied Box-Cox with lambda=2.6347 and shift=218.1562
# Processing site: Iskoras_NO-Isk-fen_tower...
#   Applied Box-Cox with lambda=2.6382 and shift=218.1562
# Processing site: Iskoras_NO-Isk-palsa_tower...
#   Applied Box-Cox with lambda=2.6350 and shift=218.1562
# Processing site: Iskoras_NO-Isk_tower...
#   Applied Box-Cox with lambda=2.6365 and shift=218.1562
# Processing site: Finse west_NO-Fns_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
# Processing site: NEON Barrow Environmental Observatory (BARR)_US-xBA_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
# Processing site: YKD (unburned)_US-YK2_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
# Processing site: Ljusdal_HY_HY_tower...
#   Applied Box-Cox with lambda=2.6356 and shift=218.1562
# Processing site: YKD (burned)_US-YK1_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
# Processing site: Ranskalankorpi_FI-Ran forestry treatment_tower...
#   Applied Box-Cox with lambda=2.6691 and shift=218.1562
# Processing site: Ranskalankorpi_FI-Ran_tower...
#   Applied Box-Cox with lambda=2.7806 and shift=218.1562
# Processing site: Stortjarn_SE-Srj_tower...
#   Applied Box-Cox with lambda=2.6364 and shift=218.1562
# Processing site: Wolf_creek_upper_forest_CA-WCUF_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
# Processing site: Halmyran_SE-Hmr_tower...
#   Applied Box-Cox with lambda=2.6370 and shift=218.1562
# Processing site: Halsingfors mire_SE-HfM_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
# Processing site: Tombstone_slavin_CA-TWOSL_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
# Processing site: Ljusdal_SLM_SLM_tower...
#   Applied Box-Cox with lambda=2.6359 and shift=218.1562
# Processing site: Steen River_CA-STR_tower...
#   Applied Box-Cox with lambda=2.6330 and shift=218.1562
# Processing site: Lily Lake Fen_US-KPL_tower...
#   Applied Box-Cox with lambda=2.6376 and shift=218.1562
# Processing site: Abisko Stordalen birch forest_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
# Processing site: North Star Yedoma_US-NSY_tower...
#   Applied Box-Cox with lambda=2.6484 and shift=218.1562
# Processing site: Lutose_CA-LUT_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
# Processing site: Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
# Processing site: Cambridge Bay - Mesic_CB-mesic_tower...
#   Applied Box-Cox with lambda=2.6383 and shift=218.1562
# Processing site: Iqaluit Tundra_CA-IQ1_tower...
#   Applied Box-Cox with lambda=2.6391 and shift=218.1562
# Processing site: Churchill Fen 3_CA-CF3_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
# Processing site: Pitsalu_tower...
#   Applied Box-Cox with lambda=2.6369 and shift=218.1562
# Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower...
#   Applied Box-Cox with lambda=2.6393 and shift=218.1562
# Processing site: Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower...
#   Applied Box-Cox with lambda=2.6375 and shift=218.1562
# Processing site: Resolute Bay Polar Desert_CA-RSB_tower...
#   Applied Box-Cox with lambda=2.6379 and shift=218.1562
# Processing site: Council Alaska Tundra_US-CAK_tower...
#   Applied Box-Cox with lambda=2.6381 and shift=218.1562
# /home/spotter5/.conda/envs/xgboost_gpu/lib/python3.9/site-packages/sklearn/metrics/_regression.py:1211: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Processing site: Zotino; Central Siberia_RU-Zfw 1_tower...
#   Applied Box-Cox with lambda=2.6379 and shift=218.1562
# Processing site: Gunnarsholt_IS-Gun_tower...
#   Applied Box-Cox with lambda=2.6344 and shift=218.1562
# Processing site: Happy Valley Wet Sedge Tundra_US-HVs_tower...
#   Applied Box-Cox with lambda=2.6383 and shift=218.1562
# Processing site: Happy Valley_US-HVa_tower...
#   Applied Box-Cox with lambda=2.6386 and shift=218.1562
# Processing site: Sag River_US-Sag_tower...
#   Applied Box-Cox with lambda=2.6386 and shift=218.1562
#
# Results saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee/catboost_results_nee_cat.csv
# Predictions saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee/catboost_predictions_nee_cat.csv
#
# --- Site-Specific Results ---
#                                                   Site       RMSE        MAE  \
# 0                           Fyodorovskoye_RU-Fyo_tower  28.513420  20.163252
# 1    Saskatchewan - Western Boreal, Mature Aspen_CA...  55.743138  40.858003
# 2    Saskatchewan - Western Boreal, Mature Jack Pin...  23.766998  17.692360
# 3                              Flakaliden_SE-Fla_tower  37.113016  22.749483
# 4                                Hyytiala_FI-Hyy_tower  38.517271  28.566534
# ..                                                 ...        ...        ...
# 180             Zotino; Central Siberia_RU-Zfw 1_tower   4.049353   3.788390
# 181                           Gunnarsholt_IS-Gun_tower  74.532785  59.450185
# 182         Happy Valley Wet Sedge Tundra_US-HVs_tower  13.819028  12.923534
# 183                          Happy Valley_US-HVa_tower  14.886613  12.990840
# 184                             Sag River_US-Sag_tower   5.517784   4.796226
#
#            R2
# 0    0.251300
# 1    0.252027
# 2    0.139147
# 3    0.389760
# 4    0.307152
# ..        ...
# 180 -0.724575
# 181 -1.713038
# 182  0.663727
# 183  0.545321
# 184  0.802400
#
# [185 rows x 4 columns]
#
# --- Pooled Metrics ---
# Pooled RMSE: 22.4244
# Pooled MAE:  14.1025
# Pooled R²:   0.4828
#
# --- Median Metrics Across Sites ---
# Median RMSE: 14.9158
# Median MAE:  12.1310
# Median R²:   0.4591
#
# Generating and saving individual site plots...
# All site plots saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures

# %%
import os
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy import stats
from scipy.special import inv_boxcox

# Suppress warnings
os.environ['PYTHONWARNINGS'] = 'ignore::FutureWarning'
warnings.filterwarnings("ignore", category=FutureWarning)
# warnings.filterwarnings("ignore", category=pd.core.common.SettingWithCopyWarning)

# 1. Load your dataset
file_path = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_alt_soil_lc_co2.csv"
df = pd.read_csv(file_path)

df = df[df['flux_method'] == 'EC']

# 2. Create tmean_C and date
df['tmean_C'] = df[['tmmn', 'tmmx']].mean(axis=1)
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))

# 3. Define predictors and target
feature_cols = [
    'EVI', 'NDVI', 'sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 
    'sur_refl_b07', 'NDWI', 'pdsi', 'srad', 'tmean_C', 'vap', 'vs',
    'bdod_0_100cm', 'cec_0_100cm', 'cfvo_0_100cm', 'clay_0_100cm',
    'nitrogen_0_100cm', 'ocd_0_100cm', 'phh2o_0_100cm', 'sand_0_100cm',
    'silt_0_100cm', 'soc_0_100cm', 'co2_cont', 'ALT',
    'land_cover', 'month' # Original categorical features
]
target_col = 'nee'
categorical_features = ['land_cover', 'month']

# Feature Engineering Section
print("Performing feature engineering...")
df['month_sin'] = np.sin(2 * np.pi * df['month']/12)
df['month_cos'] = np.cos(2 * np.pi * df['month']/12)
df['EVI_x_srad'] = df['EVI'] * df['srad']
df['NDVI_x_tmean'] = df['NDVI'] * df['tmean_C']
feature_cols.extend(['month_sin', 'month_cos', 'EVI_x_srad', 'NDVI_x_tmean'])
feature_cols.remove('month')
categorical_features.remove('month')

# Drop rows only if the target variable or site_reference is missing.
df = df.dropna(subset=['site_reference', target_col])

# Check if target variable needs shifting for Box-Cox
if df[target_col].min() <= 0:
    print("Target variable contains non-positive values. A shift will be applied for Box-Cox transformation.")

# Define output path for CSVs and create it
out_path = os.path.join("/explore/nobackup/people/spotter5/anna_v/v2/loocv", target_col + "_improved_boxcox")
os.makedirs(out_path, exist_ok=True)
figures_path = os.path.join(out_path, "figures")
os.makedirs(figures_path, exist_ok=True)

# Prepare features (X) and target (y)
X = df[feature_cols]
y = df[target_col]
sites = df["site_reference"].unique()

for col in categorical_features:
    X[col] = X[col].astype('category')

results = []
all_preds_df_list = []

# Leave-One-Site-Out CV
for test_site in sites:
    print(f"Processing site: {test_site}...")
    train_idx = df["site_reference"] != test_site
    test_idx = df["site_reference"] == test_site

    if test_idx.sum() < 20:
        print(f"  Skipping site {test_site} due to insufficient data ({test_idx.sum()} points).")
        continue

    X_train_full, y_train_full = X.loc[train_idx], y.loc[train_idx]
    X_test, y_test = X.loc[test_idx], y.loc[test_idx]
    dates_test = df.loc[test_idx, "date"]

    # --- NEW: Box-Cox Transformation of the target variable ---
    shift_value = 0
    min_y_train = y_train_full.min()
    if min_y_train <= 0:
        shift_value = -min_y_train + 1 # Add 1 to ensure all values are > 0
        y_train_shifted = y_train_full + shift_value
    else:
        y_train_shifted = y_train_full

    # Apply Box-Cox transformation on the shifted training data to find the best lambda
    y_train_transformed, lmbda = stats.boxcox(y_train_shifted)
    y_train_transformed = pd.Series(y_train_transformed, index=y_train_full.index)
    print(f"  Applied Box-Cox with lambda={lmbda:.4f} and shift={shift_value:.4f}")

    # The model will now be trained on this transformed data.
    # We split the transformed data for training and early stopping.
    X_train, X_eval, y_train_trans, y_eval_trans = train_test_split(
        X_train_full, y_train_transformed, test_size=0.15, random_state=42
    )

    model = CatBoostRegressor(
        learning_rate=0.05,
        iterations=3000,
        depth=8,
        l2_leaf_reg=1,
        random_state=42,
        cat_features=categorical_features,
        verbose=0,
        allow_writing_files=False,
        early_stopping_rounds=50
    )
    
    # Train the model on the TRANSFORMED data
    model.fit(
        X_train, y_train_trans,
        eval_set=(X_eval, y_eval_trans),
        use_best_model=True 
    )
    
    print(f"  Trained for {model.get_best_iteration()} iterations.")
    # Predict in the transformed space
    y_pred_transformed = model.predict(X_test)

    # --- NEW: Inverse Transformation to get predictions back to the original scale ---
    if lmbda == 0:
        # Handle lambda = 0 case (logarithmic transformation)
        y_pred_inv = np.exp(y_pred_transformed)
    else:
        y_pred_inv = inv_boxcox(y_pred_transformed, lmbda)
    
    # Reverse the initial shift
    y_pred_orig_scale = y_pred_inv - shift_value
    
    # Use this final, original-scale prediction for evaluation
    y_pred = y_pred_orig_scale

    # --- The rest of the script now uses the correctly scaled predictions ---
    site_df = pd.DataFrame({
        "Site": test_site,
        "Date": dates_test.values,
        "Observed": y_test.values,
        "Predicted": y_pred
    })
    all_preds_df_list.append(site_df)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    results.append({"Site": test_site, "RMSE": rmse, "MAE": mae, "R2": r2})

# Combine and save results
results_df = pd.DataFrame(results)
all_preds_df = pd.concat(all_preds_df_list, ignore_index=True)
results_csv_path = os.path.join(out_path, f'catboost_results_{target_col}_cat.csv')
predictions_csv_path = os.path.join(out_path, f'catboost_predictions_{target_col}_cat.csv')
results_df.to_csv(results_csv_path, index=False)
all_preds_df.to_csv(predictions_csv_path, index=False)
print(f"\nResults saved to: {results_csv_path}")
print(f"Predictions saved to: {predictions_csv_path}")

# Pooled and Median Metrics Calculation
rmse_all = np.sqrt(mean_squared_error(all_preds_df["Observed"], all_preds_df["Predicted"]))
r2_all = r2_score(all_preds_df["Observed"], all_preds_df["Predicted"])
mae_all = mean_absolute_error(all_preds_df["Observed"], all_preds_df["Predicted"])

print("\n--- Site-Specific Results ---")
print(results_df)
print("\n--- Pooled Metrics ---")
print(f"Pooled RMSE: {rmse_all:.4f}")
print(f"Pooled MAE:  {mae_all:.4f}")
print(f"Pooled R²:   {r2_all:.4f}")

if not results_df.empty:
    median_rmse = results_df["RMSE"].median()
    median_mae = results_df["MAE"].median()
    median_r2 = results_df["R2"].median()
    print("\n--- Median Metrics Across Sites ---")
    print(f"Median RMSE: {median_rmse:.4f}")
    print(f"Median MAE:  {median_mae:.4f}")
    print(f"Median R²:   {median_r2:.4f}")

# Plotting
unique_sites = all_preds_df["Site"].unique()
if not unique_sites.any():
    print("\nNo sites to plot.")
else:
    print("\nGenerating and saving individual site plots...")
    for site in unique_sites:
        fig, ax = plt.subplots(figsize=(12, 7))
        site_df_plot = all_preds_df[all_preds_df["Site"] == site].sort_values("Date")
        site_metrics = results_df[results_df["Site"] == site].iloc[0]
        rmse_val, r2_val, mae_val = site_metrics["RMSE"], site_metrics["R2"], site_metrics["MAE"]
        ax.plot(site_df_plot["Date"], site_df_plot["Observed"], label="Observed", marker="o", linestyle='-', markersize=4)
        ax.plot(site_df_plot["Date"], site_df_plot["Predicted"], label="Predicted", marker="x", linestyle='--', markersize=4)
        ax.set_title(f"Observed vs. Predicted {target_col} for Site: {site} (with Box-Cox)")
        ax.set_xlabel("Date")
        ax.set_ylabel(target_col)
        ax.legend()
        ax.grid(True)
        fig.autofmt_xdate()
        textstr = f"RMSE: {rmse_val:.2f}\nMAE: {mae_val:.2f}\n$R^2$: {r2_val:.2f}"
        ax.text(0.97, 0.03, textstr, transform=ax.transAxes, fontsize=10, verticalalignment='bottom', horizontalalignment='right', bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7))
        plot_filename = f'catboost_{target_col}_{site}_timeseries_cat.png'
        plot_path = os.path.join(figures_path, plot_filename)
        plt.savefig(plot_path, dpi=300, bbox_inches='tight')
        plt.close(fig)
    print(f"All site plots saved to: {figures_path}")

# Save the final model
out_path_model = '/explore/nobackup/people/spotter5/anna_v/v2/models'
os.makedirs(out_path_model, exist_ok = True)
model_filename = f'{target_col}_improved_boxcox.json'
# model.save_model(os.path.join(out_path_model, model_filename))
print(f"\nFinal model from last fold saved to: {os.path.join(out_path_model, model_filename)}")
# Out:
# Performing feature engineering...
# Target variable contains non-positive values. A shift will be applied for Box-Cox transformation.
# Processing site: Fyodorovskoye_RU-Fyo_tower...
#   Applied Box-Cox with lambda=2.6752 and shift=218.1562
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_3373172/3709591351.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col].astype('category')
#   Trained for 1015 iterations.
# Processing site: Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower...
#   Applied Box-Cox with lambda=2.6106 and shift=218.1562
#   Trained for 1477 iterations.
# Processing site: Saskatchewan - Western Boreal, Mature Jack Pine_CA-Ojp_tower...
#   Applied Box-Cox with lambda=2.6434 and shift=218.1562
#   Trained for 1340 iterations.
# Processing site: Flakaliden_SE-Fla_tower...
#   Applied Box-Cox with lambda=2.4694 and shift=198.5322
#   Trained for 1013 iterations.
# Processing site: Hyytiala_FI-Hyy_tower...
#   Applied Box-Cox with lambda=2.5877 and shift=218.1562
#   Trained for 781 iterations.
# Processing site: Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower...
#   Applied Box-Cox with lambda=2.6311 and shift=218.1562
#   Trained for 1093 iterations.
# Processing site: Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower...
#   Applied Box-Cox with lambda=2.6327 and shift=218.1562
#   Trained for 1065 iterations.
# Processing site: Kaamanen_FI-Kaa_tower...
#   Applied Box-Cox with lambda=2.6301 and shift=218.1562
#   Trained for 1351 iterations.
# Processing site: Nelegel_RU-Nel_tower...
#   Applied Box-Cox with lambda=2.6393 and shift=218.1562
#   Trained for 822 iterations.
# Processing site: Neleger Burnt Forest_RU-NeB_tower...
#   Skipping site Neleger Burnt Forest_RU-NeB_tower due to insufficient data (6 points).
# Processing site: Neleger larch forest_RU-NeF_tower...
#   Applied Box-Cox with lambda=2.6354 and shift=218.1562
#   Trained for 886 iterations.
# Processing site: Zackenberg Heath_GL-ZaH_tower...
#   Applied Box-Cox with lambda=2.6335 and shift=218.1562
#   Trained for 1315 iterations.
# Processing site: Central Marsh_US-Cms_tower...
#   Applied Box-Cox with lambda=2.6329 and shift=218.1562
#   Trained for 791 iterations.
# Processing site: Yakutsk Spasskaya Pad larch_RU-SkP_tower...
#   Applied Box-Cox with lambda=2.6340 and shift=218.1562
#   Trained for 1745 iterations.
# Processing site: Zotino; Central Siberia_RU-Zfw 2_tower...
#   Skipping site Zotino; Central Siberia_RU-Zfw 2_tower due to insufficient data (3 points).
# Processing site: Degero_SE-Deg_tower...
#   Applied Box-Cox with lambda=2.6320 and shift=218.1562
#   Trained for 1497 iterations.
# Processing site: Sodankyla_FI-Sod_tower...
#   Applied Box-Cox with lambda=2.6252 and shift=218.1562
#   Trained for 1007 iterations.
# Processing site: UCI-1964 burn site_CA-NS3_tower...
#   Applied Box-Cox with lambda=2.6353 and shift=218.1562
#   Trained for 1146 iterations.
# Processing site: Neleger Cutover_RU-NeC_tower...
#   Applied Box-Cox with lambda=2.6420 and shift=218.1562
#   Trained for 614 iterations.
# Processing site: Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower...
#   Applied Box-Cox with lambda=2.6362 and shift=218.1562
#   Trained for 909 iterations.
# Processing site: Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower...
#   Applied Box-Cox with lambda=2.6453 and shift=218.1562
#   Trained for 1069 iterations.
# Processing site: UCI-1998 burn site_CA-NS7_tower...
#   Applied Box-Cox with lambda=2.6342 and shift=218.1562
#   Trained for 704 iterations.
# Processing site: UCI-1930 burn site_CA-NS2_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
#   Trained for 908 iterations.
# Processing site: UCI-1981 burn site_CA-NS5_tower...
#   Applied Box-Cox with lambda=2.6354 and shift=218.1562
#   Trained for 1529 iterations.
# Processing site: UCI-1989 burn site_CA-NS6_tower...
#   Applied Box-Cox with lambda=2.6349 and shift=218.1562
#   Trained for 956 iterations.
# Processing site: Delta Junction deciduous broadleaf forest_US-Bn1_tower...
#   Skipping site Delta Junction deciduous broadleaf forest_US-Bn1_tower due to insufficient data (3 points).
# Processing site: Samoylov Island_RU-Sam_tower...
#   Applied Box-Cox with lambda=2.6396 and shift=218.1562
#   Trained for 1361 iterations.
# Processing site: Zotino_RU-Zot_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
#   Trained for 1220 iterations.
# Processing site: UCI-1850 burn site_CA-NS1_tower...
#   Applied Box-Cox with lambda=2.6375 and shift=218.1562
#   Trained for 771 iterations.
# Processing site: Hakasia 5yr_RU-Ha2_tower...
#   Skipping site Hakasia 5yr_RU-Ha2_tower due to insufficient data (9 points).
# Processing site: Hakasia Steppe_RU-Ha1_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
#   Trained for 1242 iterations.
# Processing site: UCI-1964 burn site wet_CA-NS4_tower...
#   Applied Box-Cox with lambda=2.6372 and shift=218.1562
#   Trained for 1079 iterations.
# Processing site: Norunda_SE-Nor_tower...
#   Applied Box-Cox with lambda=2.8675 and shift=218.1562
#   Trained for 956 iterations.
# Processing site: Delta Junction  evergreen conifer forest_US-Bn2_tower...
#   Skipping site Delta Junction  evergreen conifer forest_US-Bn2_tower due to insufficient data (3 points).
# Processing site: Kherlenbayan Ulaan_MN-Kbu_tower...
#   Applied Box-Cox with lambda=2.6450 and shift=218.1562
#   Trained for 800 iterations.
# Processing site: Southern Khentei Taiga_MN-Skt_tower...
#   Applied Box-Cox with lambda=2.6161 and shift=218.1562
#   Trained for 953 iterations.
# Processing site: University of Alaska, Fairbanks_US-Uaf_tower...
#   Applied Box-Cox with lambda=2.6355 and shift=218.1562
#   Trained for 821 iterations.
# Processing site: Kytalyk, Russia_RU-Cok_tower...
#   Applied Box-Cox with lambda=2.6378 and shift=218.1562
#   Trained for 923 iterations.
# Processing site: Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower...
#   Applied Box-Cox with lambda=2.6298 and shift=218.1562
#   Trained for 1140 iterations.
# Processing site: Saskatchewan - Western Boreal, forest burned in 1977_CA-SF1_tower...
#   Applied Box-Cox with lambda=2.7274 and shift=218.1562
#   Trained for 1009 iterations.
# Processing site: Alberta - Western Peatland - LaBiche River,Black Spruce,Larch Fen_CA-WP1_tower...
#   Applied Box-Cox with lambda=2.6318 and shift=218.1562
#   Trained for 916 iterations.
# Processing site: Quebec - Eastern Boreal, Mature Black Spruce_CA-Qfo_tower...
#   Applied Box-Cox with lambda=2.6337 and shift=218.1562
#   Trained for 569 iterations.
# Processing site: Saskatchewan - Western Boreal, Jack Pine harvested in 1975_CA-SJ3_tower...
#   Applied Box-Cox with lambda=2.6379 and shift=218.1562
#   Trained for 1101 iterations.
# Processing site: Skyttorp 2_SE-Sk2_tower...
#   Skipping site Skyttorp 2_SE-Sk2_tower due to insufficient data (12 points).
# Processing site: HJP02 Jack Pine_CA-HJP02_tower...
#   Applied Box-Cox with lambda=2.6350 and shift=218.1562
#   Trained for 985 iterations.
# Processing site: HJP94 Jack Pine_CA-HJP94_tower...
#   Applied Box-Cox with lambda=2.6371 and shift=218.1562
#   Trained for 868 iterations.
# Processing site: Saskatchewan - Western Boreal, Jack Pine harvested in 2002_CA-SJ2_tower...
#   Applied Box-Cox with lambda=2.6319 and shift=218.1562
#   Trained for 903 iterations.
# Processing site: Hakasia 10 yr_RU-Ha3_tower...
#   Skipping site Hakasia 10 yr_RU-Ha3_tower due to insufficient data (8 points).
# Processing site: Alberta - Western Peatland - Poor Fen (Sphagnum moss)_CA-WP2_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
#   Trained for 1224 iterations.
# Processing site: Alberta - Western Peatland - Rich Fen  (Carex)_CA-WP3_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
#   Trained for 960 iterations.
# Processing site: HJP75 Jack Pine_CA-HJP75_tower...
#   Applied Box-Cox with lambda=2.6387 and shift=218.1562
#   Trained for 1012 iterations.
# Processing site: Ivotuk_US-Ivo_tower...
#   Applied Box-Cox with lambda=2.6327 and shift=218.1562
#   Trained for 946 iterations.
# Processing site: Yakutsk Spasskaya Pad Pine_RU-Sk2_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
#   Trained for 660 iterations.
# Processing site: Atqasuk_US-Atq_tower...
#   Applied Box-Cox with lambda=2.6305 and shift=218.1562
#   Trained for 1066 iterations.
# Processing site: Daring Lake_CA-DL1_tower...
#   Applied Box-Cox with lambda=2.6370 and shift=218.1562
#   Trained for 1199 iterations.
# Processing site: Tura_RU-Tur_tower...
#   Applied Box-Cox with lambda=2.6428 and shift=218.1562
#   Trained for 1360 iterations.
# Processing site: Kalevansuo_FI-Kns_tower...
#   Applied Box-Cox with lambda=2.6313 and shift=218.1562
#   Trained for 1334 iterations.
# Processing site: Skyttorp 1_SE-Sk1_tower...
#   Applied Box-Cox with lambda=2.6338 and shift=218.1562
#   Trained for 1065 iterations.
# Processing site: Siikaneva_FI-Sii_tower...
#   Applied Box-Cox with lambda=2.6286 and shift=218.1562
#   Trained for 810 iterations.
# Processing site: Barrow-BES_US-Bes_tower...
#   Applied Box-Cox with lambda=2.6344 and shift=218.1562
#   Trained for 840 iterations.
# Processing site: Faejemyr_SE-Faj_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
#   Trained for 1244 iterations.
# Processing site: Knottasen_SE-Kno_tower...
#   Applied Box-Cox with lambda=2.6608 and shift=218.1562
#   Trained for 901 iterations.
# Processing site: Salmisuo_FI-Salm_tower...
#   Applied Box-Cox with lambda=2.6376 and shift=218.1562
#   Trained for 1053 iterations.
# Processing site: Lompolojankka_FI-Lom_tower...
#   Applied Box-Cox with lambda=2.6310 and shift=218.1562
#   Trained for 1163 iterations.
# Processing site: Churchill Fen Site 1_CA-CF1_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
#   Trained for 971 iterations.
# Processing site: Imnavait Creek Watershed Tussock Tundra_US-ICt_tower...
#   Applied Box-Cox with lambda=2.6261 and shift=218.1562
#   Trained for 1014 iterations.
# Processing site: Imnavait Creek Watershed Heath Tundra_US-ICh_tower...
#   Applied Box-Cox with lambda=2.6244 and shift=218.1562
#   Trained for 1345 iterations.
# Processing site: Imnavait Creek Watershed Wet Sedge Tundra_US-ICs_tower...
#   Applied Box-Cox with lambda=2.6239 and shift=218.1562
#   Trained for 1120 iterations.
# Processing site: Quebec - 1975 Harvested Black Spruce_CA-Qc2_tower...
#   Applied Box-Cox with lambda=2.6403 and shift=218.1562
#   Trained for 810 iterations.
# Processing site: Eight Mile Lake_US-EML_tower...
#   Applied Box-Cox with lambda=2.6315 and shift=218.1562
#   Trained for 967 iterations.
# Processing site: Lac Le Caron peatland, an ombrotrophic bog_CA-LLC_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
#   Trained for 982 iterations.
# Processing site: Anaktuvuk River Moderate Burn_US-An2_tower...
#   Applied Box-Cox with lambda=2.6427 and shift=218.1562
#   Trained for 928 iterations.
# Processing site: Anaktuvuk River Severe Burn_US-An1_tower...
#   Applied Box-Cox with lambda=2.6408 and shift=218.1562
#   Trained for 1170 iterations.
# Processing site: Anaktuvuk River Unburned_US-An3_tower...
#   Applied Box-Cox with lambda=2.6470 and shift=218.1562
#   Trained for 700 iterations.
# Processing site: Cape Bounty_CA-CB_tower...
#   Skipping site Cape Bounty_CA-CB_tower due to insufficient data (12 points).
# Processing site: Nuuk Fen_GL-NuF_tower...
#   Applied Box-Cox with lambda=2.6376 and shift=218.1562
#   Trained for 1055 iterations.
# Processing site: Rylekaerene_tower...
#   Skipping site Rylekaerene_tower due to insufficient data (8 points).
# Processing site: Seida_RU-Vrk_tower...
#   Skipping site Seida_RU-Vrk_tower due to insufficient data (12 points).
# Processing site: Zackenberg Fen_GL-ZaF_tower...
#   Applied Box-Cox with lambda=2.6303 and shift=218.1562
#   Trained for 795 iterations.
# Processing site: Andoya_NO-And_tower...
#   Applied Box-Cox with lambda=2.6342 and shift=218.1562
#   Trained for 1167 iterations.
# Processing site: Bayelva, Spitsbergen_SJ-Blv_tower...
#   Applied Box-Cox with lambda=2.6371 and shift=218.1562
#   Trained for 1159 iterations.
# Processing site: Iqaluit_CA-Iqa_tower...
#   Skipping site Iqaluit_CA-Iqa_tower due to insufficient data (1 points).
# Processing site: Pond Inlet_CA-Pin_tower...
#   Skipping site Pond Inlet_CA-Pin_tower due to insufficient data (1 points).
# Processing site: Poker Flat Research Range: Succession from fire scar to deciduous forest_US-Rpf_tower...
#   Applied Box-Cox with lambda=2.6184 and shift=218.1562
#   Trained for 1189 iterations.
# Processing site: Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower...
#   Skipping site Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower due to insufficient data (4 points).
# Processing site: Samoylov Island_RU-Sam (open)_tower...
#   Applied Box-Cox with lambda=2.6367 and shift=218.1562
#   Trained for 1642 iterations.
# Processing site: Lettosuo_FI-Let_tower...
#   Applied Box-Cox with lambda=2.6418 and shift=218.1562
#   Trained for 834 iterations.
# Processing site: Udleg practice forest_MN-Udg_tower...
#   Applied Box-Cox with lambda=2.6363 and shift=218.1562
#   Trained for 700 iterations.
# Processing site: Daring Lake_CA-DL3_tower...
#   Applied Box-Cox with lambda=2.6399 and shift=218.1562
#   Trained for 756 iterations.
# Processing site: Elgeeii forest station_RU-Ege_tower...
#   Applied Box-Cox with lambda=2.6325 and shift=218.1562
#   Trained for 1623 iterations.
# Processing site: Bonanza Creek Black Spruce_US-BZS_tower...
#   Applied Box-Cox with lambda=2.6317 and shift=218.1562
#   Trained for 1473 iterations.
# Processing site: Daring Lake_CA-DL4_tower...
#   Applied Box-Cox with lambda=2.6391 and shift=218.1562
#   Trained for 628 iterations.
# Processing site: Tiksi_RU-Tks_tower...
#   Applied Box-Cox with lambda=2.6391 and shift=218.1562
#   Trained for 995 iterations.
# Processing site: Samoylov Island_RU-Sam (closed)_tower...
#   Applied Box-Cox with lambda=2.6367 and shift=218.1562
#   Trained for 1304 iterations.
# Processing site: Attawapiskat River Fen_CA-ARF_tower...
#   Applied Box-Cox with lambda=2.6360 and shift=218.1562
#   Trained for 1435 iterations.
# Processing site: Bonanza Creek Thermokarst Bog_US-BZB_tower...
#   Applied Box-Cox with lambda=2.6321 and shift=218.1562
#   Trained for 1154 iterations.
# Processing site: Poker Flat Research Range Black Spruce Forest_US-Prr_tower...
#   Applied Box-Cox with lambda=2.6389 and shift=218.1562
#   Trained for 1226 iterations.
# Processing site: Attawapiskat River Bog_CA-ARB_tower...
#   Applied Box-Cox with lambda=2.6385 and shift=218.1562
#   Trained for 1061 iterations.
# Processing site: Bonanza Creek Rich Fen_US-BZF_tower...
#   Applied Box-Cox with lambda=2.6227 and shift=218.1562
#   Trained for 988 iterations.
# Processing site: Cascaden Ridge Fire Scar_US-Fcr_tower...
#   Applied Box-Cox with lambda=2.6357 and shift=218.1562
#   Trained for 828 iterations.
# Processing site: Siikaneva2_FI-Si2_tower...
#   Applied Box-Cox with lambda=2.6340 and shift=218.1562
#   Trained for 1238 iterations.
# Processing site: Cherskii ecotone_RU-Eusk_cher1_tower...
#   Applied Box-Cox with lambda=2.6346 and shift=218.1562
#   Trained for 819 iterations.
# Processing site: Kenttarova_FI-Ken_tower...
#   Applied Box-Cox with lambda=2.6378 and shift=218.1562
#   Trained for 753 iterations.
# Processing site: Sammaltunturi fell_FI-SamFell_tower...
#   Skipping site Sammaltunturi fell_FI-SamFell_tower due to insufficient data (12 points).
# Processing site: Varrio_FI-Var_tower...
#   Applied Box-Cox with lambda=2.6289 and shift=218.1562
#   Trained for 859 iterations.
# Processing site: ARM-NSA-Barrow_US-A10_tower...
#   Applied Box-Cox with lambda=2.6392 and shift=218.1562
#   Trained for 934 iterations.
# Processing site: Adventdalen_SJ-Adv_tower...
#   Applied Box-Cox with lambda=2.6356 and shift=218.1562
#   Trained for 1066 iterations.
# Processing site: Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower...
#   Skipping site Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower due to insufficient data (2 points).
# Processing site: Stordalen Fen_SE-St1_tower...
#   Applied Box-Cox with lambda=2.6247 and shift=218.1562
#   Trained for 1074 iterations.
# Processing site: Tervalamminsuo_Dry_tower...
#   Applied Box-Cox with lambda=2.6318 and shift=218.1562
#   Trained for 1821 iterations.
# Processing site: Tervalamminsuo_Wet_tower...
#   Applied Box-Cox with lambda=2.6375 and shift=218.1562
#   Trained for 1492 iterations.
# Processing site: NGEE Arctic Barrow_US-NGB_tower...
#   Applied Box-Cox with lambda=2.6381 and shift=218.1562
#   Trained for 868 iterations.
# Processing site: Cherskii disturbed forest_RU-Eusk_cher2_tower...
#   Applied Box-Cox with lambda=2.6339 and shift=218.1562
#   Trained for 956 iterations.
# Processing site: Disko_GL-Dsk_tower...
#   Applied Box-Cox with lambda=2.6305 and shift=218.1562
#   Trained for 1074 iterations.
# Processing site: Havikpak Creek_CA-HPC_tower...
#   Applied Box-Cox with lambda=2.6346 and shift=218.1562
#   Trained for 1133 iterations.
# Processing site: Scotty Creek Landscape_CA-SCC_tower...
#   Applied Box-Cox with lambda=2.6333 and shift=218.1562
#   Trained for 1022 iterations.
# Processing site: ZOTTO Bog_RU-Zo1_tower...
#   Skipping site ZOTTO Bog_RU-Zo1_tower due to insufficient data (11 points).
# Processing site: ZOTTO Forest_RU-Zo2_tower...
#   Skipping site ZOTTO Forest_RU-Zo2_tower due to insufficient data (15 points).
# Processing site: Trail Valley Creek_CA-TVC_tower...
#   Applied Box-Cox with lambda=2.6310 and shift=218.1562
#   Trained for 820 iterations.
# Processing site: Cherskii reference_RU-Ch2_tower...
#   Applied Box-Cox with lambda=2.6274 and shift=218.1562
#   Trained for 1468 iterations.
# Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower...
#   Skipping site Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower due to insufficient data (9 points).
# Processing site: Barrow-CMDL_US-Brw_tower...
#   Applied Box-Cox with lambda=2.6291 and shift=218.1562
#   Trained for 1211 iterations.
# Processing site: Svartberget_SE-Svb_tower...
#   Applied Box-Cox with lambda=2.6267 and shift=218.1562
#   Trained for 891 iterations.
# Processing site: Scotty Creek Bog_CA-SCB_tower...
#   Applied Box-Cox with lambda=2.6320 and shift=218.1562
#   Trained for 1534 iterations.
# Processing site: Stordalen Palsa Bog_SE-Sto_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
#   Trained for 733 iterations.
# Processing site: Barrow-BEO_US-Beo_tower...
#   Applied Box-Cox with lambda=2.6339 and shift=218.1562
#   Trained for 1177 iterations.
# Processing site: Council, Alaska_US-KOC_tower...
#   Applied Box-Cox with lambda=2.6402 and shift=218.1562
#   Trained for 801 iterations.
# Processing site: Rosinedal-3_SE-Ros_tower...
#   Applied Box-Cox with lambda=2.6309 and shift=218.1562
#   Trained for 1173 iterations.
# Processing site: ARM-NSA-Oliktok_US-A03_tower...
#   Applied Box-Cox with lambda=2.6427 and shift=218.1562
#   Trained for 1124 iterations.
# Processing site: Hyltemossa_SE-Htm_tower...
#   Applied Box-Cox with lambda=2.6296 and shift=218.1562
#   Trained for 1053 iterations.
# Processing site: Bibai bog_JP-Bby_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
#   Trained for 1173 iterations.
# Processing site: Fyodorovskoye2_RU-Fy2_tower...
#   Applied Box-Cox with lambda=2.6473 and shift=218.1562
#   Trained for 1321 iterations.
# Processing site: Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower...
#   Skipping site Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower due to insufficient data (15 points).
# Processing site: Mukhrino_Mukhrino_RHC_tower...
#   Skipping site Mukhrino_Mukhrino_RHC_tower due to insufficient data (4 points).
# Processing site: Nalaikh grassland_MN-Nkh_tower...
#   Applied Box-Cox with lambda=2.6380 and shift=218.1562
#   Trained for 1407 iterations.
# Processing site: Wolf_creek_Buckbrush_CA-WCBB_tower...
#   Applied Box-Cox with lambda=2.6304 and shift=218.1562
#   Trained for 898 iterations.
# Processing site: Wolf_creek_SparseShrub_CA-WCPLT_tower...
#   Applied Box-Cox with lambda=2.6304 and shift=218.1562
#   Trained for 766 iterations.
# Processing site: Hustai grassland_MN-Hst_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
#   Trained for 732 iterations.
# Processing site: Igarka_RU-Iga_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
#   Trained for 1770 iterations.
# Processing site: Wolf_creek_forest_CA-WCF_tower...
#   Applied Box-Cox with lambda=2.6395 and shift=218.1562
#   Trained for 1322 iterations.
# Processing site: Umiujaq_tower...
#   Applied Box-Cox with lambda=2.6360 and shift=218.1562
#   Trained for 939 iterations.
# Processing site: Fish Island_FI-NWT_tower...
#   Skipping site Fish Island_FI-NWT_tower due to insufficient data (2 points).
# Processing site: Smith Creek_CA-SMC_tower...
#   Applied Box-Cox with lambda=2.6336 and shift=218.1562
#   Trained for 708 iterations.
# Processing site: NGEE Arctic Council_US-NGC_tower...
#   Applied Box-Cox with lambda=2.6373 and shift=218.1562
#   Trained for 762 iterations.
# Processing site: NEON Delta Junction (DEJU)_US-xDJ_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
#   Trained for 1295 iterations.
# Processing site: Bonanza Creek Old Thermokarst Bog_US-BZo_tower...
#   Applied Box-Cox with lambda=2.6364 and shift=218.1562
#   Trained for 1251 iterations.
# Processing site: NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower...
#   Applied Box-Cox with lambda=2.6361 and shift=218.1562
#   Trained for 1598 iterations.
# Processing site: NEON Healy (HEAL)_US-xHE_tower...
#   Applied Box-Cox with lambda=2.6346 and shift=218.1562
#   Trained for 1323 iterations.
# Processing site: Bouleau peatland_CA-BOU_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
#   Trained for 725 iterations.
# Processing site: Bernard spruce-moss valley_tower...
#   Applied Box-Cox with lambda=2.6347 and shift=218.1562
#   Trained for 1079 iterations.
# Processing site: Iskoras_NO-Isk-fen_tower...
#   Applied Box-Cox with lambda=2.6382 and shift=218.1562
#   Trained for 1259 iterations.
# Processing site: Iskoras_NO-Isk-palsa_tower...
#   Applied Box-Cox with lambda=2.6350 and shift=218.1562
#   Trained for 1837 iterations.
# Processing site: Iskoras_NO-Isk_tower...
#   Applied Box-Cox with lambda=2.6365 and shift=218.1562
#   Trained for 1443 iterations.
# Processing site: Finse west_NO-Fns_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
#   Trained for 1678 iterations.
# Processing site: NEON Barrow Environmental Observatory (BARR)_US-xBA_tower...
#   Applied Box-Cox with lambda=2.6358 and shift=218.1562
#   Trained for 895 iterations.
# Processing site: YKD (unburned)_US-YK2_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
#   Trained for 1084 iterations.
# Processing site: Ljusdal_HY_HY_tower...
#   Applied Box-Cox with lambda=2.6356 and shift=218.1562
#   Trained for 878 iterations.
# Processing site: YKD (burned)_US-YK1_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
#   Trained for 918 iterations.
# Processing site: Ranskalankorpi_FI-Ran forestry treatment_tower...
#   Applied Box-Cox with lambda=2.6691 and shift=218.1562
#   Trained for 1484 iterations.
# Processing site: Ranskalankorpi_FI-Ran_tower...
#   Applied Box-Cox with lambda=2.7806 and shift=218.1562
#   Trained for 1678 iterations.
# Processing site: Stortjarn_SE-Srj_tower...
#   Applied Box-Cox with lambda=2.6364 and shift=218.1562
#   Trained for 676 iterations.
# Processing site: Wolf_creek_upper_forest_CA-WCUF_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
#   Trained for 1333 iterations.
# Processing site: Halmyran_SE-Hmr_tower...
#   Applied Box-Cox with lambda=2.6370 and shift=218.1562
#   Trained for 824 iterations.
# Processing site: Halsingfors mire_SE-HfM_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
#   Trained for 1130 iterations.
# Processing site: Tombstone_slavin_CA-TWOSL_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
#   Trained for 1599 iterations.
# Processing site: Ljusdal_SLM_SLM_tower...
#   Applied Box-Cox with lambda=2.6359 and shift=218.1562
#   Trained for 864 iterations.
# Processing site: Steen River_CA-STR_tower...
#   Applied Box-Cox with lambda=2.6330 and shift=218.1562
#   Trained for 883 iterations.
# Processing site: Lily Lake Fen_US-KPL_tower...
#   Applied Box-Cox with lambda=2.6376 and shift=218.1562
#   Trained for 1114 iterations.
# Processing site: Abisko Stordalen birch forest_tower...
#   Applied Box-Cox with lambda=2.6351 and shift=218.1562
#   Trained for 1120 iterations.
# Processing site: North Star Yedoma_US-NSY_tower...
#   Applied Box-Cox with lambda=2.6484 and shift=218.1562
#   Trained for 1303 iterations.
# Processing site: Lutose_CA-LUT_tower...
#   Applied Box-Cox with lambda=2.6377 and shift=218.1562
#   Trained for 956 iterations.
# Processing site: Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower...
#   Skipping site Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower due to insufficient data (6 points).
# Processing site: Cambridge Bay - Mesic_CB-mesic_tower...
#   Skipping site Cambridge Bay - Mesic_CB-mesic_tower due to insufficient data (5 points).
# Processing site: Iqaluit Tundra_CA-IQ1_tower...
#   Skipping site Iqaluit Tundra_CA-IQ1_tower due to insufficient data (11 points).
# Processing site: Churchill Fen 3_CA-CF3_tower...
#   Applied Box-Cox with lambda=2.6368 and shift=218.1562
#   Trained for 579 iterations.
# Processing site: Pitsalu_tower...
#   Skipping site Pitsalu_tower due to insufficient data (13 points).
# Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower...
#   Skipping site Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower due to insufficient data (9 points).
# Processing site: Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower...
#   Skipping site Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower due to insufficient data (4 points).
# Processing site: Resolute Bay Polar Desert_CA-RSB_tower...
#   Skipping site Resolute Bay Polar Desert_CA-RSB_tower due to insufficient data (2 points).
# Processing site: Council Alaska Tundra_US-CAK_tower...
#   Skipping site Council Alaska Tundra_US-CAK_tower due to insufficient data (1 points).
# Processing site: Zotino; Central Siberia_RU-Zfw 1_tower...
#   Skipping site Zotino; Central Siberia_RU-Zfw 1_tower due to insufficient data (3 points).
# Processing site: Gunnarsholt_IS-Gun_tower...
#   Applied Box-Cox with lambda=2.6344 and shift=218.1562
#   Trained for 1193 iterations.
# Processing site: Happy Valley Wet Sedge Tundra_US-HVs_tower...
#   Skipping site Happy Valley Wet Sedge Tundra_US-HVs_tower due to insufficient data (5 points).
# Processing site: Happy Valley_US-HVa_tower...
#   Skipping site Happy Valley_US-HVa_tower due to insufficient data (7 points).
# Processing site: Sag River_US-Sag_tower...
#   Skipping site Sag River_US-Sag_tower due to insufficient data (3 points).
#
# Results saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee_improved_boxcox/catboost_results_nee_cat.csv
# Predictions saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee_improved_boxcox/catboost_predictions_nee_cat.csv
#
# --- Site-Specific Results ---
#                                                   Site       RMSE        MAE  \
# 0                           Fyodorovskoye_RU-Fyo_tower  28.632637  20.319825
# 1    Saskatchewan - Western Boreal, Mature Aspen_CA...  50.405230  38.941185
# 2    Saskatchewan - Western Boreal, Mature Jack Pin...  25.841897  18.188234
# 3                              Flakaliden_SE-Fla_tower  35.052279  21.128232
# 4                                Hyytiala_FI-Hyy_tower  39.989232  29.491072
# ..                                                 ...        ...        ...
# 147                Abisko Stordalen birch forest_tower  18.719545  14.767785
# 148                     North Star Yedoma_US-NSY_tower  38.522450  29.699523
# 149                                Lutose_CA-LUT_tower   7.324130   5.693127
# 150                       Churchill Fen 3_CA-CF3_tower  14.639283  13.016160
# 151                           Gunnarsholt_IS-Gun_tower  78.982775  65.751867
#
#            R2
# 0    0.245026
# 1    0.388419
# 2   -0.017722
# 3    0.455647
# 4    0.253185
# ..        ...
# 147  0.235868
# 148 -0.382374
# 149  0.795925
# 150 -1.663926
# 151 -2.046674
#
# [152 rows x 4 columns]
#
# --- Pooled Metrics ---
# Pooled RMSE: 22.4732
# Pooled MAE:  14.3620
# Pooled R²:   0.4806
#
# --- Median Metrics Across Sites ---
# Median RMSE: 16.0440
# Median MAE:  12.2057
# Median R²:   0.4665
#
# Generating and saving individual site plots...
# All site plots saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee_improved_boxcox/figures
#
# Final model from last fold saved to: /explore/nobackup/people/spotter5/anna_v/v2/models/nee_improved_boxcox.json
