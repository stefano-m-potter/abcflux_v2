# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings

# Ignore routine warnings for cleaner output
warnings.filterwarnings('ignore')

# ---------------- Font size defaults ----------------
FS_TITLE   = 26   # suptitle
FS_AXLABEL = 22   # x/y axis labels
FS_TICKS   = 18   # x/y tick labels
FS_LEGEND  = 20   # legend text
FS_SUBTITLE = 22  # per-panel title

# 1. Load your dataset
print("--- 📂 Loading dataset ---")
try:
    df_new = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_final.csv")
    df_new = df_new[df_new['flux_method'] == 'EC']

    # --- UNITS CONVERSION and FEATURE ENGINEERING ---
    df_new['tmean_C'] = df_new[['tmmn', 'tmmx']].mean(axis=1)
    df_new['date'] = pd.to_datetime(df_new[['year', 'month']].assign(day=1))
    
except FileNotFoundError as e:
    print(f"Error: The data file was not found.\n{e}")
    raise
except KeyError as e:
    print(f"Error: A required column is missing: {e}")
    raise

# 2. Define output path and get site list
comparison_plot_path = os.path.join(
    "/explore/nobackup/people/spotter5/anna_v/v2/exploration", 
    "variable_comparisons_methane"
)
os.makedirs(comparison_plot_path, exist_ok=True)
print(f"Plots will be saved to: {comparison_plot_path}")

all_sites = df_new['site_reference'].dropna().unique()
print(f"Found {len(all_sites)} unique sites to process.")

# --- helper plotting function ---
def create_comparison_plot(ax, site_data, var_name, var_unit, var_color):
    ax_twin = ax.twinx()

    # CH4 on primary axis
    line_ch4 = ax.plot(
        site_data['date'], site_data['ch4_flux_total'],
        color='lightgray', label='CH4', linewidth=2.5, zorder=1
    )
    ax.set_ylabel('CH4', color='gray', fontsize=FS_AXLABEL)
    ax.tick_params(axis='y', labelcolor='gray', labelsize=FS_TICKS)
    ax.grid(True, linestyle='--', alpha=0.5)

    # Variable on secondary axis
    line_var = ax_twin.plot(
        site_data['date'], site_data[var_name],
        color=var_color, linestyle='-', label=var_name, zorder=3
    )
    ax_twin.set_ylabel(f'{var_name} ({var_unit})', color=var_color, fontsize=FS_AXLABEL)
    ax_twin.tick_params(axis='y', labelcolor=var_color, labelsize=FS_TICKS)

    ax.set_title(f'CH4 vs. {var_name}', fontsize=FS_SUBTITLE, fontweight='bold')

    # Combined legend
    all_handles = line_ch4 + line_var
    all_labels = [h.get_label() for h in all_handles]
    ax.legend(all_handles, all_labels, loc='upper left', fontsize=FS_LEGEND)

# --- variables to plot ---
plots = [
    ('NDVI',        'unitless',  'forestgreen'),
    ('pr',          'mm',        'dodgerblue'),
    ('tmean_C',     '°C',        'indianred'),
    ('snow_depth',  'meters',    'saddlebrown'),
    ('sm_surface',  'Volumetric','purple'),
    ('sm_rootzone', 'Volumetric','darkorange'),
]

# --- plotting loop ---
for site in all_sites:
    site_df = (
        df_new[df_new['site_reference'] == site]
        .dropna(subset=['ch4_flux_total'])
        .sort_values('date')
    )

    if site_df.empty:
        print(f" -> Skipping site: {site} (No valid CH4 observations)")
        continue

    print(f" -> Processing site: {site}")

    # 3x2 figure
    fig, axes = plt.subplots(3, 2, figsize=(30, 20), sharex=True)
    fig.suptitle(f"Site: {site} - Variable Comparison with CH4",
                 fontsize=FS_TITLE, fontweight='bold')

    ax_list = axes.flat
    for ax, (vname, vunit, vcolor) in zip(ax_list, plots):
        if vname not in site_df.columns:
            ax.text(0.5, 0.5, f"Missing: {vname}", ha='center', va='center', fontsize=FS_SUBTITLE)
            ax.set_axis_off()
            continue
        create_comparison_plot(ax, site_df, vname, vunit, vcolor)

    # common x-axis formatting
    for ax in ax_list:
        ax.set_xlabel('Date', fontsize=FS_AXLABEL)
        ax.tick_params(axis='x', labelsize=FS_TICKS)

    fig.tight_layout(rect=[0, 0, 1, 0.96])
    plt.savefig(os.path.join(comparison_plot_path, f"{site}.png"), dpi=150)
    plt.close(fig)

print("\n--- ✅ Finished plotting. All site comparison plots are saved. ---")
# Out:
# --- 📂 Loading dataset ---
# Plots will be saved to: /explore/nobackup/people/spotter5/anna_v/v2/exploration/variable_comparisons_methane
# Found 188 unique sites to process.
#  -> Skipping site: Skyttorp 2_SE-Sk2_tower (No valid CH4 observations)
#  -> Skipping site: Wolf_creek_forest_CA-WCF_tower (No valid CH4 observations)
#  -> Skipping site: Alberta - Western Peatland - LaBiche River,Black Spruce,Larch Fen_CA-WP1_tower (No valid CH4 observations)
#  -> Skipping site: Elgeeii forest station_RU-Ege_tower (No valid CH4 observations)
#  -> Skipping site: Faejemyr_SE-Faj_tower (No valid CH4 observations)
#  -> Processing site: Fyodorovskoye2_RU-Fy2_tower
#  -> Skipping site: Fyodorovskoye_RU-Fyo_tower (No valid CH4 observations)
#  -> Skipping site: Gunnarsholt_IS-Gun_tower (No valid CH4 observations)
#  -> Skipping site: HJP02 Jack Pine_CA-HJP02_tower (No valid CH4 observations)
#  -> Skipping site: HJP75 Jack Pine_CA-HJP75_tower (No valid CH4 observations)
#  -> Skipping site: HJP94 Jack Pine_CA-HJP94_tower (No valid CH4 observations)
#  -> Skipping site: Hakasia 10 yr_RU-Ha3_tower (No valid CH4 observations)
#  -> Skipping site: Hakasia 5yr_RU-Ha2_tower (No valid CH4 observations)
#  -> Skipping site: Hakasia Steppe_RU-Ha1_tower (No valid CH4 observations)
#  -> Skipping site: Hustai grassland_MN-Hst_tower (No valid CH4 observations)
#  -> Skipping site: Hyltemossa_SE-Htm_tower (No valid CH4 observations)
#  -> Skipping site: Kherlenbayan Ulaan_MN-Kbu_tower (No valid CH4 observations)
#  -> Skipping site: Norunda_SE-Nor_tower (No valid CH4 observations)
#  -> Skipping site: Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower (No valid CH4 observations)
#  -> Processing site: Pitsalu_tower
#  -> Skipping site: Pond Inlet_CA-Pin_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, Jack Pine harvested in 1975_CA-SJ3_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, Jack Pine harvested in 2002_CA-SJ2_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, Mature Jack Pine_CA-Ojp_tower (No valid CH4 observations)
#  -> Skipping site: Skyttorp 1_SE-Sk1_tower (No valid CH4 observations)
#  -> Skipping site: Southern Khentei Taiga_MN-Skt_tower (No valid CH4 observations)
#  -> Skipping site: Udleg practice forest_MN-Udg_tower (No valid CH4 observations)
#  -> Skipping site: Alberta - Western Peatland - Poor Fen (Sphagnum moss)_CA-WP2_tower (No valid CH4 observations)
#  -> Skipping site: Alberta - Western Peatland - Rich Fen  (Carex)_CA-WP3_tower (No valid CH4 observations)
#  -> Skipping site: Attawapiskat River Bog_CA-ARB_tower (No valid CH4 observations)
#  -> Skipping site: Attawapiskat River Fen_CA-ARF_tower (No valid CH4 observations)
#  -> Processing site: Bibai bog_JP-Bby_tower
#  -> Processing site: Bonanza Creek Black Spruce_US-BZS_tower
#  -> Skipping site: Bonanza Creek Old Thermokarst Bog_US-BZo_tower (No valid CH4 observations)
#  -> Processing site: Bonanza Creek Rich Fen_US-BZF_tower
#  -> Processing site: Bonanza Creek Thermokarst Bog_US-BZB_tower
#  -> Processing site: Degero_SE-Deg_tower
#  -> Skipping site: Delta Junction  evergreen conifer forest_US-Bn2_tower (No valid CH4 observations)
#  -> Skipping site: Delta Junction deciduous broadleaf forest_US-Bn1_tower (No valid CH4 observations)
#  -> Skipping site: Flakaliden_SE-Fla_tower (No valid CH4 observations)
#  -> Processing site: Halmyran_SE-Hmr_tower
#  -> Processing site: Halsingfors mire_SE-HfM_tower
#  -> Processing site: Hyytiala_FI-Hyy_tower
#  -> Skipping site: Kalevansuo_FI-Kns_tower (No valid CH4 observations)
#  -> Skipping site: Knottasen_SE-Kno_tower (No valid CH4 observations)
#  -> Skipping site: Lettosuo_FI-Let_tower (No valid CH4 observations)
#  -> Processing site: Lily Lake Fen_US-KPL_tower
#  -> Skipping site: Ljusdal_HY_HY_tower (No valid CH4 observations)
#  -> Skipping site: Ljusdal_SLM_SLM_tower (No valid CH4 observations)
#  -> Skipping site: Lutose_CA-LUT_tower (No valid CH4 observations)
#  -> Skipping site: Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower (No valid CH4 observations)
#  -> Skipping site: Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower (No valid CH4 observations)
#  -> Skipping site: Mukhrino_Mukhrino_RHC_tower (No valid CH4 observations)
#  -> Skipping site: NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower (No valid CH4 observations)
#  -> Skipping site: NEON Delta Junction (DEJU)_US-xDJ_tower (No valid CH4 observations)
#  -> Skipping site: Nalaikh grassland_MN-Nkh_tower (No valid CH4 observations)
#  -> Processing site: North Star Yedoma_US-NSY_tower
#  -> Skipping site: Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower (No valid CH4 observations)
#  -> Skipping site: Poker Flat Research Range Black Spruce Forest_US-Prr_tower (No valid CH4 observations)
#  -> Skipping site: Poker Flat Research Range: Succession from fire scar to deciduous forest_US-Rpf_tower (No valid CH4 observations)
#  -> Skipping site: Quebec - Eastern Boreal, Mature Black Spruce_CA-Qfo_tower (No valid CH4 observations)
#  -> Skipping site: Ranskalankorpi_FI-Ran forestry treatment_tower (No valid CH4 observations)
#  -> Skipping site: Ranskalankorpi_FI-Ran_tower (No valid CH4 observations)
#  -> Skipping site: Rosinedal-3_SE-Ros_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, forest burned in 1977_CA-SF1_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower (No valid CH4 observations)
#  -> Skipping site: Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower (No valid CH4 observations)
#  -> Processing site: Scotty Creek Bog_CA-SCB_tower
#  -> Processing site: Scotty Creek Landscape_CA-SCC_tower
#  -> Processing site: Siikaneva2_FI-Si2_tower
#  -> Processing site: Siikaneva_FI-Sii_tower
#  -> Processing site: Smith Creek_CA-SMC_tower
#  -> Skipping site: Steen River_CA-STR_tower (No valid CH4 observations)
#  -> Processing site: Stortjarn_SE-Srj_tower
#  -> Skipping site: Svartberget_SE-Svb_tower (No valid CH4 observations)
#  -> Skipping site: Tervalamminsuo_Dry_tower (No valid CH4 observations)
#  -> Skipping site: Tervalamminsuo_Wet_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1850 burn site_CA-NS1_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1930 burn site_CA-NS2_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1964 burn site wet_CA-NS4_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1964 burn site_CA-NS3_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1981 burn site_CA-NS5_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1989 burn site_CA-NS6_tower (No valid CH4 observations)
#  -> Skipping site: UCI-1998 burn site_CA-NS7_tower (No valid CH4 observations)
#  -> Processing site: University of Alaska, Fairbanks_US-Uaf_tower
#  -> Skipping site: Yakutsk Spasskaya Pad larch_RU-SkP_tower (No valid CH4 observations)
#  -> Skipping site: Abisko Stordalen birch forest_tower (No valid CH4 observations)
#  -> Skipping site: Andoya_NO-And_tower (No valid CH4 observations)
#  -> Processing site: Bernard spruce-moss valley_tower
#  -> Processing site: Bouleau peatland_CA-BOU_tower
#  -> Skipping site: Cascaden Ridge Fire Scar_US-Fcr_tower (No valid CH4 observations)
#  -> Skipping site: Cherskii disturbed forest_RU-Eusk_cher2_tower (No valid CH4 observations)
#  -> Skipping site: Cherskii ecotone_RU-Eusk_cher1_tower (No valid CH4 observations)
#  -> Processing site: Cherskii reference_RU-Ch2_tower
#  -> Skipping site: Council, Alaska_US-KOC_tower (No valid CH4 observations)
#  -> Skipping site: Igarka_RU-Iga_tower (No valid CH4 observations)
#  -> Processing site: Iskoras_NO-Isk-fen_tower
#  -> Processing site: Iskoras_NO-Isk-palsa_tower
#  -> Processing site: Iskoras_NO-Isk_tower
#  -> Skipping site: Kaamanen_FI-Kaa_tower (No valid CH4 observations)
#  -> Skipping site: Kenttarova_FI-Ken_tower (No valid CH4 observations)
#  -> Skipping site: Lac Le Caron peatland, an ombrotrophic bog_CA-LLC_tower (No valid CH4 observations)
#  -> Skipping site: Lompolojankka_FI-Lom_tower (No valid CH4 observations)
#  -> Skipping site: NEON Healy (HEAL)_US-xHE_tower (No valid CH4 observations)
#  -> Skipping site: Nelegel_RU-Nel_tower (No valid CH4 observations)
#  -> Skipping site: Neleger Burnt Forest_RU-NeB_tower (No valid CH4 observations)
#  -> Skipping site: Neleger Cutover_RU-NeC_tower (No valid CH4 observations)
#  -> Skipping site: Neleger larch forest_RU-NeF_tower (No valid CH4 observations)
#  -> Skipping site: Quebec - 1975 Harvested Black Spruce_CA-Qc2_tower (No valid CH4 observations)
#  -> Skipping site: Salmisuo_FI-Salm_tower (No valid CH4 observations)
#  -> Skipping site: Sammaltunturi fell_FI-SamFell_tower (No valid CH4 observations)
#  -> Skipping site: Samoylov Island_RU-Sam (closed)_tower (No valid CH4 observations)
#  -> Skipping site: Samoylov Island_RU-Sam (open)_tower (No valid CH4 observations)
#  -> Skipping site: Samoylov Island_RU-Sam_tower (No valid CH4 observations)
#  -> Processing site: Seida_RU-Vrk_tower
#  -> Skipping site: Sodankyla_FI-Sod_tower (No valid CH4 observations)
#  -> Processing site: Stordalen Fen_SE-St1_tower
#  -> Processing site: Stordalen Palsa Bog_SE-Sto_tower
#  -> Skipping site: Tombstone_slavin_CA-TWOSL_tower (No valid CH4 observations)
#  -> Skipping site: Tura_RU-Tur_tower (No valid CH4 observations)
#  -> Skipping site: Varrio_FI-Var_tower (No valid CH4 observations)
#  -> Skipping site: Wolf_creek_Buckbrush_CA-WCBB_tower (No valid CH4 observations)
#  -> Processing site: YKD (burned)_US-YK1_tower
#  -> Processing site: YKD (unburned)_US-YK2_tower
#  -> Skipping site: Yakutsk Spasskaya Pad Pine_RU-Sk2_tower (No valid CH4 observations)
#  -> Skipping site: ZOTTO Bog_RU-Zo1_tower (No valid CH4 observations)
#  -> Skipping site: ZOTTO Forest_RU-Zo2_tower (No valid CH4 observations)
#  -> Skipping site: Zotino; Central Siberia_RU-Zfw 1_tower (No valid CH4 observations)
#  -> Skipping site: Zotino; Central Siberia_RU-Zfw 2_tower (No valid CH4 observations)
#  -> Skipping site: Zotino_RU-Zot_tower (No valid CH4 observations)
#  -> Processing site: ARM-NSA-Oliktok_US-A03_tower
#  -> Skipping site: Adventdalen_SJ-Adv_tower (No valid CH4 observations)
#  -> Skipping site: Anaktuvuk River Moderate Burn_US-An2_tower (No valid CH4 observations)
#  -> Skipping site: Anaktuvuk River Severe Burn_US-An1_tower (No valid CH4 observations)
#  -> Skipping site: Anaktuvuk River Unburned_US-An3_tower (No valid CH4 observations)
#  -> Processing site: Atqasuk_US-Atq_tower
#  -> Processing site: Barrow-BEO_US-Beo_tower
#  -> Processing site: Barrow-BES_US-Bes_tower
#  -> Skipping site: Cambridge Bay - Mesic_CB-mesic_tower (No valid CH4 observations)
#  -> Skipping site: Cape Bounty_CA-CB_tower (No valid CH4 observations)
#  -> Processing site: Churchill Fen 3_CA-CF3_tower
#  -> Skipping site: Churchill Fen Site 1_CA-CF1_tower (No valid CH4 observations)
#  -> Processing site: Churchill Fen Site 2_CA-CF2_tower
#  -> Processing site: Council Alaska Tundra_US-CAK_tower
#  -> Skipping site: Daring Lake_CA-DL1_tower (No valid CH4 observations)
#  -> Skipping site: Daring Lake_CA-DL3_tower (No valid CH4 observations)
#  -> Skipping site: Daring Lake_CA-DL4_tower (No valid CH4 observations)
#  -> Skipping site: Disko_GL-Dsk_tower (No valid CH4 observations)
#  -> Processing site: Eight Mile Lake_US-EML_tower
#  -> Processing site: Fish Island_FI-NWT_tower
#  -> Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower
#  -> Processing site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower
#  -> Skipping site: Happy Valley Wet Sedge Tundra_US-HVs_tower (No valid CH4 observations)
#  -> Processing site: Happy Valley_US-HVa_tower
#  -> Processing site: Havikpak Creek_CA-HPC_tower
#  -> Skipping site: Illisarvik_IL-NWT_tower (No valid CH4 observations)
#  -> Skipping site: Imnavait Creek Watershed Heath Tundra_US-ICh_tower (No valid CH4 observations)
#  -> Skipping site: Imnavait Creek Watershed Tussock Tundra_US-ICt_tower (No valid CH4 observations)
#  -> Processing site: Imnavait Creek Watershed Wet Sedge Tundra_US-ICs_tower
#  -> Skipping site: Iqaluit Tundra_CA-IQ1_tower (No valid CH4 observations)
#  -> Skipping site: Iqaluit_CA-Iqa_tower (No valid CH4 observations)
#  -> Processing site: Ivotuk_US-Ivo_tower
#  -> Processing site: Kytalyk, Russia_RU-Cok_tower
#  -> Skipping site: Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower (No valid CH4 observations)
#  -> Skipping site: Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower (No valid CH4 observations)
#  -> Processing site: Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower
#  -> Skipping site: NEON Barrow Environmental Observatory (BARR)_US-xBA_tower (No valid CH4 observations)
#  -> Processing site: NGEE Arctic Barrow_US-NGB_tower
#  -> Processing site: NGEE Arctic Council_US-NGC_tower
#  -> Skipping site: Nuuk Fen_GL-NuF_tower (No valid CH4 observations)
#  -> Processing site: Resolute Bay Polar Desert_CA-RSB_tower
#  -> Processing site: Rylekaerene_tower
#  -> Processing site: Sag River_US-Sag_tower
#  -> Processing site: Stordalen, Sweden_Stordalen_tower
#  -> Skipping site: Tiksi_RU-Tks_tower (No valid CH4 observations)
#  -> Processing site: Trail Valley Creek_CA-TVC_tower
#  -> Skipping site: Umiujaq_tower (No valid CH4 observations)
#  -> Skipping site: Wolf_creek_SparseShrub_CA-WCPLT_tower (No valid CH4 observations)
#  -> Skipping site: Wolf_creek_upper_forest_CA-WCUF_tower (No valid CH4 observations)
#  -> Skipping site: Zackenberg Fen_GL-ZaF_tower (No valid CH4 observations)
#  -> Skipping site: Zackenberg Heath_GL-ZaH_tower (No valid CH4 observations)
#  -> Processing site: ARM-NSA-Barrow_US-A10_tower
#  -> Processing site: Barrow-CMDL_US-Brw_tower
#  -> Skipping site: Bayelva, Spitsbergen_SJ-Blv_tower (No valid CH4 observations)
#  -> Processing site: Central Marsh_US-Cms_tower
#  -> Skipping site: Finse west_NO-Fns_tower (No valid CH4 observations)
#
# --- ✅ Finished plotting. All site comparison plots are saved. ---

# %% [markdown]
# Now make heat maps

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
Correlation heatmaps: predictors vs ch4_flux_total

- Monthly (per site): rows = months 1..12, cols = predictors
- Seasonal (per site): rows = Winter/Spring/Summer/Autumn, cols = predictors
- Annual (ALL SITES TOGETHER): rows = sites, cols = predictors

Outputs (under OUT_DIR):
  /monthly/<site>_corr_monthly.csv
  /monthly/<site>_corr_heatmap_monthly.png
  /seasonal/<site>_corr_seasonal.csv
  /seasonal/<site>_corr_heatmap_seasonal.png
  /annual/annual_corr_by_site.csv
  /annual/annual_corr_heatmap_by_site.png
"""

import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# ----------------- Config -----------------
IN_CSV  = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_final.csv"
OUT_DIR = "/explore/nobackup/people/spotter5/anna_v/v2/corr_heatmaps_ch4"

PREDICTORS = [
    'EVI', 'NDVI', 'sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03',
    'sur_refl_b07', 'NDWI', 'pdsi', 'srad', 'tmean_C', 'vap', 'vs',
    'co2_cont', 'ALT',
    'lai', 'fpar', 'Percent_NonTree_Vegetation',
    'Percent_NonVegetated', 'Percent_Tree_Cover',
    'sm_surface', 'sm_rootzone', 'snow_cover', 'snow_depth'
]

TARGET = "ch4_flux_total"
MIN_PAIRS = 12       # min (x,y) pairs required for Pearson r
ROT_X = 90           # rotate predictor labels for readability

# ----------------- Helpers -----------------
def corr_with_min_pairs(x: pd.Series, y: pd.Series, min_pairs=MIN_PAIRS) -> float:
    v = pd.DataFrame({"x": x, "y": y}).dropna()
    if len(v) < min_pairs:
        return np.nan
    return v["x"].corr(v["y"])

def season_label(month: int) -> str:
    if month in (12, 1, 2):   return "Winter"
    if month in (3, 4, 5):    return "Spring"
    if month in (6, 7, 8):    return "Summer"
    return "Autumn"

def ensure_numeric(df: pd.DataFrame, cols: list) -> pd.DataFrame:
    for c in cols:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    return df

def plot_heatmap_annotated(matrix_df: pd.DataFrame, title: str, out_file: Path, annotate=True):
    """Blue→Red heatmap with optional r annotations in each cell."""
    n_rows, n_cols = matrix_df.shape
    fig_w = max(10, min(3 + 0.5 * n_cols, 40))
    fig_h = max(6,  2 + 0.45 * n_rows)
    fig, ax = plt.subplots(figsize=(fig_w, fig_h))

    im = ax.imshow(matrix_df.values, cmap="bwr", vmin=-1, vmax=1,
                   origin="upper", aspect="auto")

    cbar = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    cbar.set_label("Pearson r (predictor vs CH4)", fontsize=11)

    ax.set_xticks(np.arange(n_cols))
    ax.set_yticks(np.arange(n_rows))
    ax.set_xticklabels(matrix_df.columns, fontsize=11, rotation=ROT_X, ha="right")
    ax.set_yticklabels(matrix_df.index, fontsize=12)

    ax.set_xlabel("Predictor variable", fontsize=12)
    ax.set_ylabel("Group", fontsize=12)
    ax.set_title(title, fontsize=14, pad=12)

    # annotate
    if annotate:
        # turn off annotations if matrix is huge to keep files readable
        if n_rows * n_cols > 2200:
            annotate = False
        # smaller text if large but still within limit
        fz = 9 if n_rows <= 40 else 7

    if annotate:
        for i in range(n_rows):
            for j in range(n_cols):
                val = matrix_df.iloc[i, j]
                if pd.notna(val):
                    ax.text(j, i, f"{val:.2f}", ha="center", va="center",
                            color="black", fontsize=fz)

    fig.tight_layout()
    out_file.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(out_file, dpi=200)
    plt.close(fig)

# ----------------- Main -----------------
def main():
    print(f"Reading: {IN_CSV}")
    df = pd.read_csv(IN_CSV)

    if "flux_method" in df.columns:
        df = df[df["flux_method"] == "EC"].copy()

    required = ["site_reference", "year", "month", TARGET]
    missing_req = [c for c in required if c not in df.columns]
    if missing_req:
        raise ValueError(f"Missing required columns: {missing_req}")

    df["year"]  = pd.to_numeric(df["year"], errors="coerce").astype("Int64")
    df["month"] = pd.to_numeric(df["month"], errors="coerce").astype("Int64")
    df = df.dropna(subset=["site_reference", "year", "month"])
    df = df[(df["month"] >= 1) & (df["month"] <= 12)].copy()

    # keep predictors that actually exist
    preds_present = [p for p in PREDICTORS if p in df.columns]
    if not preds_present:
        raise ValueError("None of the specified predictors are present in the input CSV.")
    if len(preds_present) < len(PREDICTORS):
        print("Warning: missing predictors (ignored):",
              sorted(set(PREDICTORS) - set(preds_present)))

    df = ensure_numeric(df, [TARGET] + preds_present)
    df["season"] = df["month"].apply(season_label)

    # sites
    sites = df["site_reference"].dropna().unique()
    sites = sorted(sites, key=lambda x: str(x).lower())
    print(f"Found {len(sites)} sites.")

    # output dirs
    out_monthly  = Path(OUT_DIR) / "monthly"
    out_seasonal = Path(OUT_DIR) / "seasonal"
    out_annual   = Path(OUT_DIR) / "annual"
    for p in (out_monthly, out_seasonal, out_annual):
        p.mkdir(parents=True, exist_ok=True)

    # ---- Per-site monthly & seasonal ----
    for site in sites:
        sd = df[df["site_reference"] == site].copy()

        if sd[TARGET].dropna().shape[0] < MIN_PAIRS:
            print(f" -> Skipping {site}: insufficient {TARGET} data.")
            continue

        # Monthly (12 x predictors)
        months = list(range(1, 13))
        mon_mat = pd.DataFrame(index=months, columns=preds_present, dtype=float)
        for m in months:
            sub = sd[sd["month"] == m]
            for p in preds_present:
                mon_mat.loc[m, p] = corr_with_min_pairs(sub[p], sub[TARGET])
        mon_mat.index.name = "Month"
        mon_csv = out_monthly / f"{site}_corr_monthly.csv"
        mon_png = out_monthly / f"{site}_corr_heatmap_monthly.png"
        mon_mat.to_csv(mon_csv, float_format="%.4f")
        plot_heatmap_annotated(mon_mat, f"{site} — Monthly correlation (Predictors vs CH4)", mon_png)

        # Seasonal (4 x predictors)
        seasons = ["Winter", "Spring", "Summer", "Autumn"]
        sea_mat = pd.DataFrame(index=seasons, columns=preds_present, dtype=float)
        for s in seasons:
            sub = sd[sd["season"] == s]
            for p in preds_present:
                sea_mat.loc[s, p] = corr_with_min_pairs(sub[p], sub[TARGET])
        sea_mat.index.name = "Season"
        sea_csv = out_seasonal / f"{site}_corr_seasonal.csv"
        sea_png = out_seasonal / f"{site}_corr_heatmap_seasonal.png"
        sea_mat.to_csv(sea_csv, float_format="%.4f")
        plot_heatmap_annotated(sea_mat, f"{site} — Seasonal correlation (Predictors vs CH4)", sea_png)

        print(f" -> Saved monthly/seasonal heatmaps for {site}")

    # ---- Annual (ALL SITES TOGETHER): rows = sites, cols = predictors ----
    ann_rows = []
    valid_sites = []
    for site in sites:
        sd = df[df["site_reference"] == site].copy()
        if sd[TARGET].dropna().shape[0] < MIN_PAIRS:
            continue
        row = {}
        for p in preds_present:
            row[p] = corr_with_min_pairs(sd[p], sd[TARGET])
        ann_rows.append(row)
        valid_sites.append(site)

    if ann_rows:
        ann_mat = pd.DataFrame(ann_rows, index=valid_sites, columns=preds_present)
        ann_mat.index.name = "site_reference"
        ann_csv = out_annual / "annual_corr_by_site.csv"
        ann_png = out_annual / "annual_corr_heatmap_by_site.png"
        ann_mat.to_csv(ann_csv, float_format="%.4f")

        # annotate only if not too huge
        annotate = (ann_mat.shape[0] * ann_mat.shape[1] <= 2200)
        plot_heatmap_annotated(
            ann_mat,
            "Annual correlation (Predictors vs CH4) — rows = sites",
            ann_png,
            annotate=annotate
        )
        print(f" -> Saved combined annual matrix: {ann_csv}")
    else:
        print("No sites had sufficient data for the annual matrix.")

    print(f"\nDone. Results under:\n  {out_monthly}\n  {out_seasonal}\n  {out_annual}")

if __name__ == "__main__":
    main()
# Out:
# Reading: /explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_final.csv
# Warning: missing predictors (ignored): ['tmean_C']
# Found 188 sites.
#  -> Skipping Abisko Stordalen birch forest_tower: insufficient ch4_flux_total data.
#  -> Skipping Adventdalen_SJ-Adv_tower: insufficient ch4_flux_total data.
#  -> Skipping Alberta - Western Peatland - LaBiche River,Black Spruce,Larch Fen_CA-WP1_tower: insufficient ch4_flux_total data.
#  -> Skipping Alberta - Western Peatland - Poor Fen (Sphagnum moss)_CA-WP2_tower: insufficient ch4_flux_total data.
#  -> Skipping Alberta - Western Peatland - Rich Fen  (Carex)_CA-WP3_tower: insufficient ch4_flux_total data.
#  -> Skipping Anaktuvuk River Moderate Burn_US-An2_tower: insufficient ch4_flux_total data.
#  -> Skipping Anaktuvuk River Severe Burn_US-An1_tower: insufficient ch4_flux_total data.
#  -> Skipping Anaktuvuk River Unburned_US-An3_tower: insufficient ch4_flux_total data.
#  -> Skipping Andoya_NO-And_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for ARM-NSA-Barrow_US-A10_tower
#  -> Skipping ARM-NSA-Oliktok_US-A03_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Atqasuk_US-Atq_tower
#  -> Skipping Attawapiskat River Bog_CA-ARB_tower: insufficient ch4_flux_total data.
#  -> Skipping Attawapiskat River Fen_CA-ARF_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Barrow-BEO_US-Beo_tower
#  -> Saved monthly/seasonal heatmaps for Barrow-BES_US-Bes_tower
#  -> Saved monthly/seasonal heatmaps for Barrow-CMDL_US-Brw_tower
#  -> Skipping Bayelva, Spitsbergen_SJ-Blv_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Bernard spruce-moss valley_tower
#  -> Saved monthly/seasonal heatmaps for Bibai bog_JP-Bby_tower
#  -> Skipping Bonanza Creek Black Spruce_US-BZS_tower: insufficient ch4_flux_total data.
#  -> Skipping Bonanza Creek Old Thermokarst Bog_US-BZo_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Bonanza Creek Rich Fen_US-BZF_tower
#  -> Saved monthly/seasonal heatmaps for Bonanza Creek Thermokarst Bog_US-BZB_tower
#  -> Saved monthly/seasonal heatmaps for Bouleau peatland_CA-BOU_tower
#  -> Skipping Cambridge Bay - Mesic_CB-mesic_tower: insufficient ch4_flux_total data.
#  -> Skipping Cape Bounty_CA-CB_tower: insufficient ch4_flux_total data.
#  -> Skipping Cascaden Ridge Fire Scar_US-Fcr_tower: insufficient ch4_flux_total data.
#  -> Skipping Central Marsh_US-Cms_tower: insufficient ch4_flux_total data.
#  -> Skipping Cherskii disturbed forest_RU-Eusk_cher2_tower: insufficient ch4_flux_total data.
#  -> Skipping Cherskii ecotone_RU-Eusk_cher1_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Cherskii reference_RU-Ch2_tower
#  -> Saved monthly/seasonal heatmaps for Churchill Fen 3_CA-CF3_tower
#  -> Skipping Churchill Fen Site 1_CA-CF1_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Churchill Fen Site 2_CA-CF2_tower
#  -> Skipping Council Alaska Tundra_US-CAK_tower: insufficient ch4_flux_total data.
#  -> Skipping Council, Alaska_US-KOC_tower: insufficient ch4_flux_total data.
#  -> Skipping Daring Lake_CA-DL1_tower: insufficient ch4_flux_total data.
#  -> Skipping Daring Lake_CA-DL3_tower: insufficient ch4_flux_total data.
#  -> Skipping Daring Lake_CA-DL4_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Degero_SE-Deg_tower
#  -> Skipping Delta Junction  evergreen conifer forest_US-Bn2_tower: insufficient ch4_flux_total data.
#  -> Skipping Delta Junction deciduous broadleaf forest_US-Bn1_tower: insufficient ch4_flux_total data.
#  -> Skipping Disko_GL-Dsk_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Eight Mile Lake_US-EML_tower
#  -> Skipping Elgeeii forest station_RU-Ege_tower: insufficient ch4_flux_total data.
#  -> Skipping Faejemyr_SE-Faj_tower: insufficient ch4_flux_total data.
#  -> Skipping Finse west_NO-Fns_tower: insufficient ch4_flux_total data.
#  -> Skipping Fish Island_FI-NWT_tower: insufficient ch4_flux_total data.
#  -> Skipping Flakaliden_SE-Fla_tower: insufficient ch4_flux_total data.
#  -> Skipping Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower: insufficient ch4_flux_total data.
#  -> Skipping Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Fyodorovskoye2_RU-Fy2_tower
#  -> Skipping Fyodorovskoye_RU-Fyo_tower: insufficient ch4_flux_total data.
#  -> Skipping Gunnarsholt_IS-Gun_tower: insufficient ch4_flux_total data.
#  -> Skipping Hakasia 10 yr_RU-Ha3_tower: insufficient ch4_flux_total data.
#  -> Skipping Hakasia 5yr_RU-Ha2_tower: insufficient ch4_flux_total data.
#  -> Skipping Hakasia Steppe_RU-Ha1_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Halmyran_SE-Hmr_tower
#  -> Saved monthly/seasonal heatmaps for Halsingfors mire_SE-HfM_tower
#  -> Skipping Happy Valley Wet Sedge Tundra_US-HVs_tower: insufficient ch4_flux_total data.
#  -> Skipping Happy Valley_US-HVa_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Havikpak Creek_CA-HPC_tower
#  -> Skipping HJP02 Jack Pine_CA-HJP02_tower: insufficient ch4_flux_total data.
#  -> Skipping HJP75 Jack Pine_CA-HJP75_tower: insufficient ch4_flux_total data.
#  -> Skipping HJP94 Jack Pine_CA-HJP94_tower: insufficient ch4_flux_total data.
#  -> Skipping Hustai grassland_MN-Hst_tower: insufficient ch4_flux_total data.
#  -> Skipping Hyltemossa_SE-Htm_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Hyytiala_FI-Hyy_tower
#  -> Skipping Igarka_RU-Iga_tower: insufficient ch4_flux_total data.
#  -> Skipping Illisarvik_IL-NWT_tower: insufficient ch4_flux_total data.
#  -> Skipping Imnavait Creek Watershed Heath Tundra_US-ICh_tower: insufficient ch4_flux_total data.
#  -> Skipping Imnavait Creek Watershed Tussock Tundra_US-ICt_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Imnavait Creek Watershed Wet Sedge Tundra_US-ICs_tower
#  -> Skipping Iqaluit Tundra_CA-IQ1_tower: insufficient ch4_flux_total data.
#  -> Skipping Iqaluit_CA-Iqa_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Iskoras_NO-Isk-fen_tower
#  -> Saved monthly/seasonal heatmaps for Iskoras_NO-Isk-palsa_tower
#  -> Saved monthly/seasonal heatmaps for Iskoras_NO-Isk_tower
#  -> Saved monthly/seasonal heatmaps for Ivotuk_US-Ivo_tower
#  -> Skipping Kaamanen_FI-Kaa_tower: insufficient ch4_flux_total data.
#  -> Skipping Kalevansuo_FI-Kns_tower: insufficient ch4_flux_total data.
#  -> Skipping Kenttarova_FI-Ken_tower: insufficient ch4_flux_total data.
#  -> Skipping Kherlenbayan Ulaan_MN-Kbu_tower: insufficient ch4_flux_total data.
#  -> Skipping Knottasen_SE-Kno_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Kytalyk, Russia_RU-Cok_tower
#  -> Skipping Lac Le Caron peatland, an ombrotrophic bog_CA-LLC_tower: insufficient ch4_flux_total data.
#  -> Skipping Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower: insufficient ch4_flux_total data.
#  -> Skipping Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower: insufficient ch4_flux_total data.
#  -> Skipping Lettosuo_FI-Let_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Lily Lake Fen_US-KPL_tower
#  -> Skipping Ljusdal_HY_HY_tower: insufficient ch4_flux_total data.
#  -> Skipping Ljusdal_SLM_SLM_tower: insufficient ch4_flux_total data.
#  -> Skipping Lompolojankka_FI-Lom_tower: insufficient ch4_flux_total data.
#  -> Skipping Lutose_CA-LUT_tower: insufficient ch4_flux_total data.
#  -> Skipping Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower: insufficient ch4_flux_total data.
#  -> Skipping Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower: insufficient ch4_flux_total data.
#  -> Skipping Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower: insufficient ch4_flux_total data.
#  -> Skipping Mukhrino_Mukhrino_RHC_tower: insufficient ch4_flux_total data.
#  -> Skipping Nalaikh grassland_MN-Nkh_tower: insufficient ch4_flux_total data.
#  -> Skipping Nelegel_RU-Nel_tower: insufficient ch4_flux_total data.
#  -> Skipping Neleger Burnt Forest_RU-NeB_tower: insufficient ch4_flux_total data.
#  -> Skipping Neleger Cutover_RU-NeC_tower: insufficient ch4_flux_total data.
#  -> Skipping Neleger larch forest_RU-NeF_tower: insufficient ch4_flux_total data.
#  -> Skipping NEON Barrow Environmental Observatory (BARR)_US-xBA_tower: insufficient ch4_flux_total data.
#  -> Skipping NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower: insufficient ch4_flux_total data.
#  -> Skipping NEON Delta Junction (DEJU)_US-xDJ_tower: insufficient ch4_flux_total data.
#  -> Skipping NEON Healy (HEAL)_US-xHE_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for NGEE Arctic Barrow_US-NGB_tower
#  -> Saved monthly/seasonal heatmaps for NGEE Arctic Council_US-NGC_tower
#  -> Saved monthly/seasonal heatmaps for North Star Yedoma_US-NSY_tower
#  -> Skipping Norunda_SE-Nor_tower: insufficient ch4_flux_total data.
#  -> Skipping Nuuk Fen_GL-NuF_tower: insufficient ch4_flux_total data.
#  -> Skipping Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Pitsalu_tower
#  -> Skipping Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower: insufficient ch4_flux_total data.
#  -> Skipping Poker Flat Research Range Black Spruce Forest_US-Prr_tower: insufficient ch4_flux_total data.
#  -> Skipping Poker Flat Research Range: Succession from fire scar to deciduous forest_US-Rpf_tower: insufficient ch4_flux_total data.
#  -> Skipping Pond Inlet_CA-Pin_tower: insufficient ch4_flux_total data.
#  -> Skipping Quebec - 1975 Harvested Black Spruce_CA-Qc2_tower: insufficient ch4_flux_total data.
#  -> Skipping Quebec - Eastern Boreal, Mature Black Spruce_CA-Qfo_tower: insufficient ch4_flux_total data.
#  -> Skipping Ranskalankorpi_FI-Ran forestry treatment_tower: insufficient ch4_flux_total data.
#  -> Skipping Ranskalankorpi_FI-Ran_tower: insufficient ch4_flux_total data.
#  -> Skipping Resolute Bay Polar Desert_CA-RSB_tower: insufficient ch4_flux_total data.
#  -> Skipping Rosinedal-3_SE-Ros_tower: insufficient ch4_flux_total data.
#  -> Skipping Rylekaerene_tower: insufficient ch4_flux_total data.
#  -> Skipping Sag River_US-Sag_tower: insufficient ch4_flux_total data.
#  -> Skipping Salmisuo_FI-Salm_tower: insufficient ch4_flux_total data.
#  -> Skipping Sammaltunturi fell_FI-SamFell_tower: insufficient ch4_flux_total data.
#  -> Skipping Samoylov Island_RU-Sam (closed)_tower: insufficient ch4_flux_total data.
#  -> Skipping Samoylov Island_RU-Sam (open)_tower: insufficient ch4_flux_total data.
#  -> Skipping Samoylov Island_RU-Sam_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, forest burned in 1977_CA-SF1_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, Jack Pine harvested in 1975_CA-SJ3_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, Jack Pine harvested in 2002_CA-SJ2_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower: insufficient ch4_flux_total data.
#  -> Skipping Saskatchewan - Western Boreal, Mature Jack Pine_CA-Ojp_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Scotty Creek Bog_CA-SCB_tower
#  -> Saved monthly/seasonal heatmaps for Scotty Creek Landscape_CA-SCC_tower
#  -> Skipping Seida_RU-Vrk_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Siikaneva2_FI-Si2_tower
#  -> Saved monthly/seasonal heatmaps for Siikaneva_FI-Sii_tower
#  -> Skipping Skyttorp 1_SE-Sk1_tower: insufficient ch4_flux_total data.
#  -> Skipping Skyttorp 2_SE-Sk2_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Smith Creek_CA-SMC_tower
#  -> Skipping Sodankyla_FI-Sod_tower: insufficient ch4_flux_total data.
#  -> Skipping Southern Khentei Taiga_MN-Skt_tower: insufficient ch4_flux_total data.
#  -> Skipping Steen River_CA-STR_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Stordalen Fen_SE-St1_tower
#  -> Saved monthly/seasonal heatmaps for Stordalen Palsa Bog_SE-Sto_tower
#  -> Skipping Stordalen, Sweden_Stordalen_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Stortjarn_SE-Srj_tower
#  -> Skipping Svartberget_SE-Svb_tower: insufficient ch4_flux_total data.
#  -> Skipping Tervalamminsuo_Dry_tower: insufficient ch4_flux_total data.
#  -> Skipping Tervalamminsuo_Wet_tower: insufficient ch4_flux_total data.
#  -> Skipping Tiksi_RU-Tks_tower: insufficient ch4_flux_total data.
#  -> Skipping Tombstone_slavin_CA-TWOSL_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for Trail Valley Creek_CA-TVC_tower
#  -> Skipping Tura_RU-Tur_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1850 burn site_CA-NS1_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1930 burn site_CA-NS2_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1964 burn site wet_CA-NS4_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1964 burn site_CA-NS3_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1981 burn site_CA-NS5_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1989 burn site_CA-NS6_tower: insufficient ch4_flux_total data.
#  -> Skipping UCI-1998 burn site_CA-NS7_tower: insufficient ch4_flux_total data.
#  -> Skipping Udleg practice forest_MN-Udg_tower: insufficient ch4_flux_total data.
#  -> Skipping Umiujaq_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for University of Alaska, Fairbanks_US-Uaf_tower
#  -> Skipping Varrio_FI-Var_tower: insufficient ch4_flux_total data.
#  -> Skipping Wolf_creek_Buckbrush_CA-WCBB_tower: insufficient ch4_flux_total data.
#  -> Skipping Wolf_creek_forest_CA-WCF_tower: insufficient ch4_flux_total data.
#  -> Skipping Wolf_creek_SparseShrub_CA-WCPLT_tower: insufficient ch4_flux_total data.
#  -> Skipping Wolf_creek_upper_forest_CA-WCUF_tower: insufficient ch4_flux_total data.
#  -> Skipping Yakutsk Spasskaya Pad larch_RU-SkP_tower: insufficient ch4_flux_total data.
#  -> Skipping Yakutsk Spasskaya Pad Pine_RU-Sk2_tower: insufficient ch4_flux_total data.
#  -> Saved monthly/seasonal heatmaps for YKD (burned)_US-YK1_tower
#  -> Saved monthly/seasonal heatmaps for YKD (unburned)_US-YK2_tower
#  -> Skipping Zackenberg Fen_GL-ZaF_tower: insufficient ch4_flux_total data.
#  -> Skipping Zackenberg Heath_GL-ZaH_tower: insufficient ch4_flux_total data.
#  -> Skipping Zotino; Central Siberia_RU-Zfw 1_tower: insufficient ch4_flux_total data.
#  -> Skipping Zotino; Central Siberia_RU-Zfw 2_tower: insufficient ch4_flux_total data.
#  -> Skipping Zotino_RU-Zot_tower: insufficient ch4_flux_total data.
#  -> Skipping ZOTTO Bog_RU-Zo1_tower: insufficient ch4_flux_total data.
#  -> Skipping ZOTTO Forest_RU-Zo2_tower: insufficient ch4_flux_total data.
#  -> Saved combined annual matrix: /explore/nobackup/people/spotter5/anna_v/v2/corr_heatmaps_ch4/annual/annual_corr_by_site.csv
#
# Done. Results under:
#   /explore/nobackup/people/spotter5/anna_v/v2/corr_heatmaps_ch4/monthly
#   /explore/nobackup/people/spotter5/anna_v/v2/corr_heatmaps_ch4/seasonal
#   /explore/nobackup/people/spotter5/anna_v/v2/corr_heatmaps_ch4/annual
