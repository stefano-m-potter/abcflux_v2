# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import pandas as pd
from pathlib import Path

# --------- Paths ---------
IN_CSV  = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv"
SOIL    = "/explore/nobackup/people/spotter5/anna_v/v2/integrated_soil_data_1km_v2_sites.csv"
LC      = "/explore/nobackup/people/spotter5/anna_v/v2/extracted_landcover_values_v2.csv"
SM      = "/explore/nobackup/people/spotter5/anna_v/v2/soil_moisture_by_site_monthly_2000_2023.csv"
CO2     = "/explore/nobackup/people/spotter5/anna_v/v2/co2_cont.csv"
ALT     = "/explore/nobackup/people/spotter5/anna_v/v2/ALT_by_site.csv"

OUT_CSV = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_v4_lagged.csv"

# --------- Helper: context builder for ONE site ---------
def build_ctx_for_site(df_site: pd.DataFrame) -> pd.DataFrame:
    """
    Apply seasonal/context logic to ONE site's data and return df with 6 *_ctx columns added.
    Rules:
      - Summer obs (JJA): temp/pr = mean(Dec(prev)–Apr(curr)), snow = mean(Dec(prev)–Mar(curr)), ndvi = current NDVI
      - Fall (SON):       temp/pr/ndvi = same-year JJA means; snow = mean(Dec(prev)–Mar(curr))
      - Winter (DJFM):    temp/pr/ndvi = previous-year JJA means; snow = current month (original)
      - Spring (AM):      temp/pr/ndvi = previous-year JJA means; snow = current month (original)
      - Fill remaining NaNs using original values, then same-month means (within site), then site means.
    """
    need = ['year','month','tmmn','tmmx','pr','NDVI','snow_cover','snow_depth','NDSI_snow_cover']
    miss = [c for c in need if c not in df_site.columns]
    if miss:
        raise ValueError(f"Missing columns for context logic: {miss}")

    df = df_site.copy()
    df['tmean_C'] = df[['tmmn','tmmx']].mean(axis=1)
    df['year']  = pd.to_numeric(df['year'], errors='coerce').astype(int)
    df['month'] = pd.to_numeric(df['month'], errors='coerce').astype(int)

    # Monthly means (within site) for building aggregates
    monthly = (
        df.groupby(['year','month'], as_index=False)
          .agg({'tmean_C':'mean','pr':'mean','NDVI':'mean',
                'snow_cover':'mean','snow_depth':'mean','NDSI_snow_cover':'mean'})
          .sort_values(['year','month'])
    )

    # JJA per year (same-year)
    summer = (
        monthly[monthly['month'].isin([6,7,8])]
        .groupby('year', as_index=False)
        .agg({'tmean_C':'mean','pr':'mean','NDVI':'mean'})
        .rename(columns={'tmean_C':'summer_tmean','pr':'summer_pr','NDVI':'summer_ndvi'})
    )

    # Dec(prev)–Apr(curr) mapped to curr year (for JJA temp/pr)
    win_DecApr = monthly[monthly['month'].isin([12,1,2,3,4])].copy()
    win_DecApr['target_year'] = win_DecApr['year'] + (win_DecApr['month'] == 12).astype(int)
    win_DecApr = (
        win_DecApr.groupby('target_year', as_index=False)
                  .agg({'tmean_C':'mean','pr':'mean'})
                  .rename(columns={'target_year':'year',
                                   'tmean_C':'Decprev_to_Apr_tmean',
                                   'pr':'Decprev_to_Apr_pr'})
    )

    # Dec(prev)–Mar(curr) mapped to curr year (for JJA & Fall snow)
    win_DecMar = monthly[monthly['month'].isin([12,1,2,3])].copy()
    win_DecMar['target_year'] = win_DecMar['year'] + (win_DecMar['month'] == 12).astype(int)
    win_DecMar = (
        win_DecMar.groupby('target_year', as_index=False)
                  .agg({'snow_cover':'mean','snow_depth':'mean','NDSI_snow_cover':'mean'})
                  .rename(columns={'target_year':'year',
                                   'snow_cover':'Decprev_to_Mar_snow_cover',
                                   'snow_depth':'Decprev_to_Mar_snow_depth',
                                   'NDSI_snow_cover':'Decprev_to_Mar_NDSI'})
    )

    out = df.copy()
    for c in ['temp_ctx','pr_ctx','ndvi_ctx',
              'snow_cover_ctx','snow_depth_ctx','ndsi_snow_cover_ctx']:
        out[c] = pd.NA

    is_summer  = out['month'].isin([6,7,8])      # JJA
    is_fall    = out['month'].isin([9,10,11])    # SON
    is_winter  = out['month'].isin([12,1,2,3])   # DJFM
    is_spring  = out['month'].isin([4,5])        # AM

    # A) Summer rows
    tmp = out.loc[is_summer, ['year','month']].merge(win_DecApr, on='year', how='left')
    out.loc[is_summer, 'temp_ctx'] = tmp['Decprev_to_Apr_tmean'].values
    out.loc[is_summer, 'pr_ctx']   = tmp['Decprev_to_Apr_pr'].values
    tmp = out.loc[is_summer, ['year','month']].merge(win_DecMar, on='year', how='left')
    out.loc[is_summer, 'snow_cover_ctx']      = tmp['Decprev_to_Mar_snow_cover'].values
    out.loc[is_summer, 'snow_depth_ctx']      = tmp['Decprev_to_Mar_snow_depth'].values
    out.loc[is_summer, 'ndsi_snow_cover_ctx'] = tmp['Decprev_to_Mar_NSI'].values if 'Decprev_to_Mar_NSI' in tmp.columns else tmp['Decprev_to_Mar_NDSI'].values
    out.loc[is_summer, 'ndvi_ctx'] = out.loc[is_summer, 'NDVI'].values

    # B) Fall rows (same-year JJA for temp/pr/ndvi; Decprev–Mar for snow)
    tmp = out.loc[is_fall, ['year','month']].merge(summer, on='year', how='left')
    out.loc[is_fall, 'temp_ctx'] = tmp['summer_tmean'].values
    out.loc[is_fall, 'pr_ctx']   = tmp['summer_pr'].values
    out.loc[is_fall, 'ndvi_ctx'] = tmp['summer_ndvi'].values
    tmp = out.loc[is_fall, ['year','month']].merge(win_DecMar, on='year', how='left')
    out.loc[is_fall, 'snow_cover_ctx']      = tmp['Decprev_to_Mar_snow_cover'].values
    out.loc[is_fall, 'snow_depth_ctx']      = tmp['Decprev_to_Mar_snow_depth'].values
    out.loc[is_fall, 'ndsi_snow_cover_ctx'] = tmp['Decprev_to_Mar_NDSI'].values

    # C) Winter rows (prev-year JJA for temp/pr/ndvi; snow = original)
    prev = out.loc[is_winter, ['year','month']].copy()
    prev = prev.merge(summer.rename(columns={'year':'key_year'}),
                      left_on=(prev['year'] - 1), right_on='key_year', how='left')
    out.loc[is_winter, 'temp_ctx'] = prev['summer_tmean'].values
    out.loc[is_winter, 'pr_ctx']   = prev['summer_pr'].values
    out.loc[is_winter, 'ndvi_ctx'] = prev['summer_ndvi'].values
    out.loc[is_winter, 'snow_cover_ctx']      = out.loc[is_winter, 'snow_cover'].values
    out.loc[is_winter, 'snow_depth_ctx']      = out.loc[is_winter, 'snow_depth'].values
    out.loc[is_winter, 'ndsi_snow_cover_ctx'] = out.loc[is_winter, 'NDSI_snow_cover'].values

    # D) Spring rows (prev-year JJA for temp/pr/ndvi; snow = original)
    prev = out.loc[is_spring, ['year','month']].copy()
    prev = prev.merge(summer.rename(columns={'year':'key_year'}),
                      left_on=(prev['year'] - 1), right_on='key_year', how='left')
    out.loc[is_spring, 'temp_ctx'] = prev['summer_tmean'].values
    out.loc[is_spring, 'pr_ctx']   = prev['summer_pr'].values
    out.loc[is_spring, 'ndvi_ctx'] = prev['summer_ndvi'].values
    out.loc[is_spring, 'snow_cover_ctx']      = out.loc[is_spring, 'snow_cover'].values
    out.loc[is_spring, 'snow_depth_ctx']      = out.loc[is_spring, 'snow_depth'].values
    out.loc[is_spring, 'ndsi_snow_cover_ctx'] = out.loc[is_spring, 'NDSI_snow_cover'].values

    # No-NaN fallbacks (within site)
    out['temp_ctx'] = out['temp_ctx'].fillna(out['tmean_C'])
    out['pr_ctx']   = out['pr_ctx'].fillna(out['pr'])
    out['ndvi_ctx'] = out['ndvi_ctx'].fillna(out['NDVI'])
    out['snow_cover_ctx']      = out['snow_cover_ctx'].fillna(out['snow_cover'])
    out['snow_depth_ctx']      = out['snow_depth_ctx'].fillna(out['snow_depth'])
    out['ndsi_snow_cover_ctx'] = out['ndsi_snow_cover_ctx'].fillna(out['NDSI_snow_cover'])

    # same-month means within site
    month_means = (
        out.groupby('month')[['temp_ctx','pr_ctx','ndvi_ctx',
                              'snow_cover_ctx','snow_depth_ctx','ndsi_snow_cover_ctx']]
          .transform('mean')
    )
    for col in ['temp_ctx','pr_ctx','ndvi_ctx',
                'snow_cover_ctx','snow_depth_ctx','ndsi_snow_cover_ctx']:
        out[col] = out[col].fillna(month_means[col])

    # site overall means last
    for col in ['temp_ctx','pr_ctx','ndvi_ctx',
                'snow_cover_ctx','snow_depth_ctx','ndsi_snow_cover_ctx']:
        out[col] = out[col].fillna(out[col].mean())

    return out

# --------- 1) Build context (all sites) ---------
input_data = pd.read_csv(IN_CSV)

# Keep EC only, valid site_reference, and years >= 2001 (as in your merge script)
input_data = input_data[(input_data['flux_method'] == 'EC') &
                        (input_data['year'] >= 2001)].copy()
input_data = input_data.dropna(subset=['site_reference'])

# Apply per-site context logic, then recombine
parts = []
for site, g in input_data.groupby('site_reference', group_keys=False):
    parts.append(build_ctx_for_site(g))
ctx_all = pd.concat(parts, ignore_index=True)

# --------- 2) Merge additional datasets ---------
soil       = pd.read_csv(SOIL)
landcover  = pd.read_csv(LC)[['site_refer','land_cover_code']]
sm         = pd.read_csv(SM)
cont       = pd.read_csv(CO2)
alt        = pd.read_csv(ALT)

# Normalize types
for df in [ctx_all, alt, sm]:
    if 'site_reference' in df.columns:
        df['site_reference'] = df['site_reference'].astype(str)
for df in [soil, landcover]:
    if 'site_refer' in df.columns:
        df['site_refer'] = df['site_refer'].astype(str)

for df in [ctx_all, alt, sm, cont]:
    if 'year' in df.columns:
        df['year'] = pd.to_numeric(df['year'], errors='coerce').astype('Int64')
    if 'month' in df.columns:
        df['month'] = pd.to_numeric(df['month'], errors='coerce').astype('Int64')

# Deduplicate on merge keys
ctx_all   = ctx_all.drop_duplicates(subset=['site_reference','year','month'])
soil      = soil.drop_duplicates(subset=['site_refer'])
landcover = landcover.drop_duplicates(subset=['site_refer'])
alt       = alt.drop_duplicates(subset=['site_reference','year'])
sm        = sm.drop_duplicates(subset=['site_reference','year','month'])

# Soil (static); keep only 100cm cols
soil_100 = soil.filter(regex='100cm$').copy()
soil_100['site_reference'] = soil['site_refer'].values
ctx_all = ctx_all.merge(soil_100, on="site_reference", how="left", validate="m:1")

# Land cover (static)
landcover = landcover.rename(columns={'site_refer':'site_reference',
                                      'land_cover_code':'land_cover'})
landcover = landcover[['site_reference','land_cover']]
ctx_all = ctx_all.merge(landcover, on="site_reference", how="left", validate="m:1")

# CO2 (year/month)
co2_to_merge = cont[['year','month','value']].drop_duplicates(subset=['year','month']).rename(columns={'value':'co2_cont'})
ctx_all = ctx_all.merge(co2_to_merge, on=['year','month'], how='left', validate="m:1")

# ALT (site/year)
alt_to_merge = alt[['site_reference','year','ALT']].drop_duplicates(subset=['site_reference','year'])
ctx_all = ctx_all.merge(alt_to_merge, on=['site_reference','year'], how='left', validate="m:1")

# Soil moisture (site/year/month)
needed_cols = {'site_reference','year','month','sm_surface','sm_rootzone'}
missing = needed_cols.difference(set(sm.columns))
if missing:
    raise ValueError(f"Soil moisture CSV missing columns: {missing}")
ctx_all = ctx_all.merge(
    sm[['site_reference','year','month','sm_surface','sm_rootzone']],
    on=['site_reference','year','month'], how='left', validate='m:1'
)

# Land cover type cast
if 'land_cover' in ctx_all.columns:
    ctx_all['land_cover'] = ctx_all['land_cover'].fillna(-9999).astype(int)

# --------- Save ---------
Path(OUT_CSV).parent.mkdir(parents=True, exist_ok=True)
ctx_all.to_csv(OUT_CSV, index=False)

print("Saved:", OUT_CSV)
print(ctx_all[['site_reference','year','month','tmmn','tmmx','tmean_C','pr','NDVI',
               'temp_ctx','pr_ctx','ndvi_ctx',
               'snow_cover','snow_cover_ctx',
               'snow_depth','snow_depth_ctx',
               'NDSI_snow_cover','ndsi_snow_cover_ctx']].head(12))
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_2878948/3434667788.py:155: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   input_data = pd.read_csv(IN_CSV)
# Saved: /explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_v4_lagged.csv
#                  site_reference  year  month  tmmn  tmmx  tmean_C    pr  \
# 0   ARM-NSA-Barrow_US-A10_tower  2001      7   0.8   7.6     4.20  36.0
# 1   ARM-NSA-Barrow_US-A10_tower  2001      8   0.1   5.3     2.70  33.0
# 2   ARM-NSA-Barrow_US-A10_tower  2002      7   1.0   8.3     4.65   2.0
# 3   ARM-NSA-Barrow_US-A10_tower  2002      8   0.4   5.9     3.15  23.0
# 4   ARM-NSA-Barrow_US-A10_tower  2002      9   0.3   4.7     2.50  51.0
# 5   ARM-NSA-Barrow_US-A10_tower  2003      7   1.6   8.7     5.15  24.0
# 6   ARM-NSA-Barrow_US-A10_tower  2003      8   0.7   5.3     3.00  23.0
# 7   ARM-NSA-Barrow_US-A10_tower  2003      9  -1.2   2.0     0.40  35.0
# 8   ARM-NSA-Barrow_US-A10_tower  2004      7   2.9  10.4     6.65  38.0
# 9   ARM-NSA-Barrow_US-A10_tower  2004      8   4.4  10.1     7.25  22.0
# 10  ARM-NSA-Barrow_US-A10_tower  2004      9  -1.2   2.6     0.70  34.0
# 11  ARM-NSA-Barrow_US-A10_tower  2005      7   1.6   7.6     4.60  18.0
#
#        NDVI   temp_ctx     pr_ctx  ndvi_ctx  snow_cover  snow_cover_ctx  \
# 0   0.27390 -21.587500   2.500000  0.273900    0.590437       98.447266
# 1   0.34500 -21.587500   2.500000  0.345000    1.989337       98.447266
# 2   0.54780 -23.030000   2.600000  0.547800    1.012882       98.447266
# 3   0.54260 -23.030000   2.600000  0.542600    3.026446       98.447266
# 4   0.44260   3.150000  13.000000  0.545200    5.878448       98.447266
# 5   0.39735 -21.380000   2.000000  0.397350    0.133902       98.447266
# 6   0.33410 -21.380000   2.000000  0.334100    2.076954       98.447266
# 7   0.33410   3.516667  16.666667  0.365725   20.770985       98.447266
# 8   0.30090 -23.920000   2.600000  0.300900    0.197906       98.447266
# 9   0.60690 -23.920000   2.600000  0.606900    0.025191       98.447266
# 10  0.59520   6.100000  27.333333  0.453900   24.242128       98.447266
# 11  0.59455 -22.220000   3.400000  0.594550    0.217582       98.447266
#
#       snow_depth  snow_depth_ctx  NDSI_snow_cover  ndsi_snow_cover_ctx
# 0   5.237210e-04        0.510701          -9999.0              -9999.0
# 1   1.971501e-03        0.510701          -9999.0              -9999.0
# 2   1.026441e-03        0.339531          -9999.0              -9999.0
# 3   3.076697e-03        0.339531          -9999.0              -9999.0
# 4   5.916341e-03        0.339531          -9999.0              -9999.0
# 5   1.194451e-04        0.440187          -9999.0              -9999.0
# 6   2.085696e-03        0.440187          -9999.0              -9999.0
# 7   2.115885e-02        0.440187          -9999.0              -9999.0
# 8   1.706359e-04        0.519635          -9999.0              -9999.0
# 9  -7.345365e-24        0.519635          -9999.0              -9999.0
# 10  3.131646e-02        0.519635          -9999.0              -9999.0
# 11  1.929498e-04        0.513267          -9999.0              -9999.0

# %%
import pandas as pd

df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")

df0.columns

df0 = df0[df0['year'] >= 2001]
site_ref = 'ARM-NSA-Barrow_US-A10_tower'
#'Zackenberg Heath_GL-ZaH_tower'
df0 = df0[df0['site_reference'] == site_ref]


df0['tmean_C'] = df0[['tmmn', 'tmmx']].mean(axis=1)
df0 = df0[['year', 'month', 'nee', 'tmean_C', 'pr', 'NDVI', 'snow_cover', 'snow_depth', 'NDSI_snow_cover']]
df0['year'] = df0['year'].astype(int)
df0['month'] = df0['month'].astype(int)

# # Collapse duplicates to monthly means (if duplicates exist for a month)
monthly = (
    df0.groupby(['year', 'month'], as_index=False)
       .agg({'tmean_C':'mean', 'pr':'mean'})
       .sort_values(['year','month'])
)

df0
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_2878948/4179303193.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")
#         year  month  nee  tmean_C    pr    NDVI  snow_cover  snow_depth  \
# 16079   2001      7  NaN     4.20  36.0  0.2739    0.590437    0.000524
# 18223   2001      8  NaN     2.70  33.0  0.3450    1.989337    0.001972
# 28529   2002      7  NaN     4.65   2.0  0.5478    1.012882    0.001026
# 30673   2002      8  NaN     3.15  23.0  0.5426    3.026446    0.003077
# 32816   2002      9  NaN     2.50  51.0  0.4426    5.878448    0.005916
# ...      ...    ...  ...      ...   ...     ...         ...         ...
# 637713  2024      3  NaN   -24.95   3.0     NaN   98.447266    0.646442
# 639362  2024      4  NaN   -16.70   7.0     NaN   98.447266    0.596106
# 640335  2024      5  NaN    -6.00   5.0     NaN   98.256988    0.391686
# 641744  2024     11  NaN   -12.55  11.0     NaN   98.447266    0.207726
# 643540  2024     12  NaN   -21.25   2.0     NaN   98.447266    0.306049
#
#         NDSI_snow_cover
# 16079           -9999.0
# 18223           -9999.0
# 28529           -9999.0
# 30673           -9999.0
# 32816           -9999.0
# ...                 ...
# 637713          -9999.0
# 639362          -9999.0
# 640335          -9999.0
# 641744          -9999.0
# 643540          -9999.0
#
# [288 rows x 9 columns]

# %%
df0['NDSI_snow_cover'].unique()
# Out:
# array([-9999.])

# %%
import pandas as pd

df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")

df0.columns

df0 = df0[df0['year'] >= 2001]
site_ref = 'ARM-NSA-Barrow_US-A10_tower'
#'Zackenberg Heath_GL-ZaH_tower'
# site_ref = 'Iskoras_NO-Isk-fen_tower'
site_ref = 'Bonanza Creek Rich Fen_US-BZF_tower'
df0 = df0[df0['site_reference'] == site_ref]


df0['tmean_C'] = df0[['tmmn', 'tmmx']].mean(axis=1)
df0 = df0[['year', 'month', 'ch4_flux_total', 'tmean_C', 'pr', 'NDVI', 'Percent_Tree_Cover', 
           'Percent_NonVegetated', 'Percent_NonTree_Vegetation', 'snow_cover', 'snow_depth', 'NDSI_snow_cover']]
df0['year'] = df0['year'].astype(int)
df0['month'] = df0['month'].astype(int)

df0 = df0.dropna(subset = 'ch4_flux_total')
# # Collapse duplicates to monthly means (if duplicates exist for a month)
# monthly = (
#     df0.groupby(['year', 'month'], as_index=False)
#        .agg({'tmean_C':'mean', 'pr':'mean'})
#        .sort_values(['year','month'])
# )


df0
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_2878948/770507582.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")
#         year  month  ch4_flux_total  tmean_C     pr     NDVI  \
# 187696  2014      5        0.421803     9.95    6.0  0.49430
# 189322  2014      6        0.757250    13.55   89.0  0.56935
# 191416  2014      7        1.292764    15.50  125.0  0.66165
# 193559  2014      8        1.838523    14.25   57.0  0.62225
# 195703  2014      9        1.398056     7.60   77.0  0.57570
# 197765  2014     10        0.921675    -4.10    8.0  0.36470
# 201654  2015      5        1.794251    12.15    7.0  0.53970
# 203155  2015      6        2.748907    15.45   26.0  0.50020
# 205163  2015      7        2.448837    16.20   73.0  0.58475
# 207306  2015      8        1.927717    12.65   68.0  0.70090
# 209416  2015      9        1.508864     5.75   81.0  0.44545
# 217384  2016      6        1.839695    15.50   53.0  0.62775
# 219495  2016      7        2.965410    17.25   82.0  0.59385
# 221639  2016      8        3.640687    15.45   44.0  0.60300
# 223774  2016      9        2.248460     7.90   51.0  0.45080
# 225888  2016     10        2.304456    -3.40    4.0  0.36675
#
#         Percent_Tree_Cover  Percent_NonVegetated  Percent_NonTree_Vegetation  \
# 187696                 0.0                 100.0                         0.0
# 189322                 0.0                 100.0                         0.0
# 191416                 0.0                 100.0                         0.0
# 193559                 0.0                 100.0                         0.0
# 195703                 0.0                 100.0                         0.0
# 197765                 0.0                 100.0                         0.0
# 201654                 0.0                 100.0                         0.0
# 203155                 0.0                 100.0                         0.0
# 205163                 0.0                 100.0                         0.0
# 207306                 0.0                 100.0                         0.0
# 209416                 0.0                 100.0                         0.0
# 217384                 0.0                 100.0                         0.0
# 219495                 0.0                 100.0                         0.0
# 221639                 0.0                 100.0                         0.0
# 223774                 0.0                 100.0                         0.0
# 225888                 0.0                 100.0                         0.0
#
#         snow_cover    snow_depth  NDSI_snow_cover
# 187696    0.026060  2.493910e-05         0.000000
# 189322    0.000000 -7.345365e-24         0.000000
# 191416    0.000000 -7.345365e-24         1.533333
# 193559    0.000000 -7.345365e-24         0.000000
# 195703    0.168362  1.641168e-04         0.611111
# 197765   61.337468  6.136330e-02        37.416667
# 201654    0.015916 -7.345365e-24         0.000000
# 203155    0.000000 -7.345365e-24         0.153846
# 205163    0.000000 -7.345365e-24         0.333333
# 207306    0.000000 -7.345365e-24         2.888889
# 209416    9.306920  1.157227e-02         0.000000
# 217384    0.000000 -7.345365e-24         0.000000
# 219495    0.000000 -7.345365e-24         0.000000
# 221639    0.000000 -7.345365e-24         4.187500
# 223774    0.002165 -7.345365e-24         0.823529
# 225888    2.809644  2.673734e-03         4.136364

# %%
df0['Percent_Tree_Cover'].unique()
# Out:
# array([0.])

# %%
df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")
df0['site_reference'].unique()
# Out:
# /explore/nobackup/people/spotter5/temp_dir/ipykernel_2878948/3876992393.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_data_v4.csv")
# array(['Bonanza Creek Experimental Forest_FP1A-Sandbar_chamber',
#        'Bonanza Creek Experimental Forest_FP2A-Alder-Poplar_chamber',
#        'Bonanza Creek Experimental Forest_FP3A-Poplar_chamber', ...,
#        'Kolyma River Floodplain_Kolyma_chamber', 'Tiksi_TD_chamber',
#        'Tiksi_TW_chamber'], dtype=object)

# %%
for i in df0['site_reference'].unique():
    print(i)
# Out:
# Bonanza Creek Experimental Forest_FP1A-Sandbar_chamber
# Bonanza Creek Experimental Forest_FP2A-Alder-Poplar_chamber
# Bonanza Creek Experimental Forest_FP3A-Poplar_chamber
# Bonanza Creek Experimental Forest_FP4A-White Spruce_chamber
# Bonanza Creek Experimental Forest_FP5A- Black Spruce_chamber
# Bonanza Creek Experimental Forest_UP1A- Burn Site_chamber
# Bonanza Creek Experimental Forest_UP3A- White Spruce_chamber
# Esro West_EW_chamber
# Fox CRREL Uplands_Fox_chamber
# Lutose_CA-LUT-MB_chamber
# Lutose_CA-LUT-PE_chamber
# Lutose_CA-LUT-P_chamber
# Lutose_CA-LUT-YB_chamber
# Lutose_intermediate bog_chamber
# Lutose_mature bog_chamber
# Lutose_poor fen_chamber
# Lutose_rich fen_chamber
# Lutose_young bog_chamber
# Skyttorp 2_SE-Sk2_tower
# Southwest Sweden_Well-drained forest floor (dry)_chamber
# Southwest Sweden_Wet forest floor_chamber
# Wolf_creek_forest_CA-WCF_tower
# Alberta - Western Peatland - LaBiche River,Black Spruce,Larch Fen_CA-WP1_tower
# Borgarnes_BORG_LI7820_bareground_chamber
# Borgarnes_BORG_LI7820_biocrust_chamber
# Borgarnes_BORG_LI7820_mixedveg_chamber
# Carmon Creek 2_Bog_Line_Lichen/Rhododendron_chamber
# Carmon Creek 2_Bog_Line_Rhododendron_chamber
# Carmon Creek 2_Bog_Line_Sphagnum/Rhododendron_chamber
# Carmon Creek 2_Bog_Natural_Feathermoss/Rhododendron_chamber
# Carmon Creek 2_Bog_Natural_Sphagnum/Rhododendron_chamber
# Carmon Creek_Bog_Line_Lichen/Rhododendron_chamber
# Carmon Creek_Bog_Line_Sphagnum/Rhododendron_chamber
# Carmon Creek_Bog_Line_Sphagnum_chamber
# Carmon Creek_Bog_Natural_Feathermoss/Rhododendron_chamber
# Carmon Creek_Bog_Natural_Lichen/Rhododendron_chamber
# Carmon Creek_Bog_Natural_Sphagnum/Rhododendron_chamber
# Elgeeii forest station_RU-Ege_tower
# Faejemyr_SE-Faj_tower
# Fyodorovskoye2_RU-Fy2_tower
# Fyodorovskoye_RU-Fyo_tower
# Gunnarsholt_IS-Gun_tower
# HJP02 Jack Pine_CA-HJP02_tower
# HJP75 Jack Pine_CA-HJP75_tower
# HJP94 Jack Pine_CA-HJP94_tower
# Hakasia 10 yr_RU-Ha3_tower
# Hakasia 5yr_RU-Ha2_tower
# Hakasia Steppe_RU-Ha1_tower
# Hustai grassland_MN-Hst_tower
# Hyltemossa_SE-Htm_tower
# IPAD_Fen_Line_Carex/Salix_chamber
# IPAD_Fen_Line_Carex_chamber
# IPAD_Fen_Natural_Feathermoss/Rhododendron_chamber
# IPAD_Fen_Natural_Feathermoss/Salix_chamber
# IPAD_Fen_Natural_Feathermoss_chamber
# Kherlenbayan Ulaan_MN-Kbu_tower
# Lunsen Burnt_Polytrichum burnt_chamber
# Lunsen Burnt_Sedge burnt_chamber
# Lunsen Burnt_Sphagnum burnt_chamber
# Lunsen Burnt_Water burnt_chamber
# Lunsend Unburnt_Sedge umburned_chamber
# Lunsend Unburnt_Sphagnum unburnt_chamber
# Lunsend Unburnt_Water unburned_chamber
# Mackenzie Valley, Anzac, Mid-Boreal - Peat Plateau_mid boreal - peat plateau_chamber
# Mannikjarve_Mannikjarve-mixopeat_chamber
# Mature_Mature_C1_chamber
# Mature_Mature_C2_chamber
# Mature_Mature_C3_chamber
# Mt. St. Hilaire_Basin swamp_chamber
# Norunda_SE-Nor_tower
# Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower
# Pitsalu_tower
# Pond Inlet_CA-Pin_tower
# Poplar Fen_Hollow_Moderately burned_chamber
# Poplar Fen_Hollow_Severely burned_chamber
# Poplar Fen_Hollow_Unburned_chamber
# Poplar Fen_Hummock_Moderately burned_chamber
# Poplar Fen_Hummock_Severely burned_chamber
# Poplar Fen_Hummock_Unburned_chamber
# Saskatchewan - Western Boreal, Jack Pine harvested in 1975_CA-SJ3_tower
# Saskatchewan - Western Boreal, Jack Pine harvested in 2002_CA-SJ2_tower
# Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower
# Saskatchewan - Western Boreal, Mature Jack Pine_CA-Ojp_tower
# Skyttorp 1_SE-Sk1_tower
# Southern Khentei Taiga_MN-Skt_tower
# St. Bruno_Basin swamp_chamber
# St. Bruno_Domed bog- centre_chamber
# St. Bruno_Domed bog- margin_chamber
# Udleg practice forest_MN-Udg_tower
# Vanda_chamber
# APEX Beta_Active Margin_AMCH1_agg_chamber
# APEX Beta_Active Margin_AMCH2_agg_chamber
# APEX Beta_Active Margin_AMCH3_agg_chamber
# APEX Beta_Permafrost Plateau_PPC1_agg_chamber
# APEX Beta_Permafrost Plateau_PPC2_agg_chamber
# APEX Beta_Permafrost Plateau_PPC3_agg_chamber
# APEX Beta_Permafrost Plateau_PPC4_agg_chamber
# APEX Beta_Permafrost Plateau_PPCH1_agg_chamber
# APEX Beta_Permafrost Plateau_PPCH2_agg_chamber
# APEX Beta_Permafrost Plateau_PPCH3_agg_chamber
# APEX Beta_Permafrost Plateau_PPCH4_agg_chamber
# Ahvensalo_Hollows Site_chamber
# Ahvensalo_Hummocks Site_chamber
# Ahvensalo_Sphagnum angustifolium Site_chamber
# Ahvensalo_Sphagnum fuscum Site_chamber
# Alaska_peatland 1, point B. ALP1BST_chamber
# Alaska_peatland 1, point F. ALP1FST_chamber
# Alaska_peatland 4, point A. ALP4AST_chamber
# Alaska_peatland 4, point B. ALP4BST_chamber
# Alaska_peatland 4, point C. ALP4CST_chamber
# Alaska_peatland 4, point E. ALP4EST_chamber
# Alaska_peatland 4, point F. ALP4FSB_chamber
# Alaska_soil 1, point B. ALS1BST_chamber
# Alaska_soil 2, point A. ALS2AST_chamber
# Alaska_soil 2, point B. ALS2BST_chamber
# Alberta - Western Peatland - Poor Fen (Sphagnum moss)_CA-WP2_tower
# Alberta - Western Peatland - Rich Fen  (Carex)_CA-WP3_tower
# Amanita_AA_chamber
# Attawapiskat River Bog_CA-ARB_tower
# Attawapiskat River Fen_CA-ARF_tower
# BOREAS NSA_89Burn_Spruce_chamber
# BOREAS NSA_89Burn_moss_chamber
# BOREAS NSA_Gillam_aspen_chamber
# BOREAS NSA_Gillam_pine_chamber
# BOREAS NSA_Gillam_spruce_chamber
# BOREAS NSA_OBS_Aspen_chamber
# BOREAS NSA_OBS_Spruce_chamber
# BOREAS NSA_Palsa_birch_chamber
# BOREAS NSA_Palsa_lichen_chamber
# BOREAS NSA_YJP_D_chamber
# BOREAS NSA_YJP_W_chamber
# Barkchar_Fen_chamber
# Barkchar_RHC Hallow_chamber
# Barkchar_RHC Ridge_chamber
# Barkchar_Ryam_chamber
# Bibai bog_JP-Bby_tower
# Bonanza Creek Black Spruce_US-BZS_tower
# Bonanza Creek Old Thermokarst Bog_US-BZo_tower
# Bonanza Creek Rich Fen_US-BZF_tower
# Bonanza Creek Thermokarst Bog_US-BZB_tower
# Bonanza Creek_Sphagnum bog_Other
# Bonanza Creek_thermokarst wetland TW_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_10E_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_10N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_10S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_10W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_11E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_11N_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_11S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_11W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_12E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_12N_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_12S_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_12W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_13E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_13N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_13S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_13W_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_14E_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_14N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_14S_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_14W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_15E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_15N_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_15S_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_15W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_1E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_1N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_1S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_1W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_2E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_2N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_2S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_2W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_3E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_3N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_3S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_3W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_4E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_4N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_4S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_4W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_5E_agg_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_5N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_5S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_5W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_6E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_6N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_6S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_6W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_7E_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_7N_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_7S_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_7W_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_8A_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_8B_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_9A_chamber
# Boreal forest-fen mosaic north of Big Trail Lake, Fairbanks, AK_9B_chamber
# Caribou-Poker Creek_deep_moss_chamber
# Caribou-Poker Creek_lichen_chamber
# Caribou-Poker Creek_mosaic_chamber
# Clear-cut_Clear-cut_C1_chamber
# Clear-cut_Clear-cut_C2_chamber
# Clear-cut_Clear-cut_C3_chamber
# Coastal Fen_CF_chamber
# Coastal Marsh_CM_chamber
# CrippleCreek_CC_chamber
# Degero Stormyr_oligotrophic minerogenic mire complex_chamber
# Degero_SE-Deg_chamber
# Degero_SE-Deg_tower
# Delta Junction  evergreen conifer forest_US-Bn2_tower
# Delta Junction deciduous broadleaf forest_US-Bn1_tower
# Dorohovo_For_1_1_agg_chamber
# Dorohovo_For_1_2_agg_chamber
# Dorohovo_sw_1_1_agg_chamber
# Dorohovo_sw_1_2_agg_chamber
# Dorohovo_sw_1_3_agg_chamber
# Dorohovo_sw_1_4_agg_chamber
# Dorohovo_sw_1_5.2_agg_chamber
# Dorohovo_sw_1_5_agg_chamber
# Dorohovo_sw_1_6_agg_chamber
# Dorohovo_sw_1_7_agg_chamber
# Eastview-Bennett_EB_chamber
# Esro East_EE_chamber
# Fairbanks_Bog1_chamber
# Fairbanks_Bog2_chamber
# Fairbanks_Marsh_chamber
# Fairbanks_permbog1_chamber
# Fairbanks_permbog2_chamber
# Flakaliden_SE-Fla_tower
# Halmyran_SE-Hmr_tower
# Halsingfors mire_SE-HfM_tower
# Haustovo_Bog_1_1_agg_chamber
# Haustovo_Sw_2_1_agg_chamber
# Heritage Hills_HH_chamber
# Hurdal_Hurdal_C1_chamber
# Hurdal_Hurdal_C2_chamber
# Hurdal_Hurdal_C3_chamber
# Hyytiala_FI-Hyy_tower
# Interior Fen_IF_chamber
# Isabella_IS_chamber
# Kalevansuo_FI-Kns_tower
# Kinosheo Lake_KL1_chamber
# Kinosheo Lake_KL2_chamber
# Kinosheo Lake_KL3_chamber
# Kinosheo Lake_KL4_chamber
# Knottasen_SE-Kno_tower
# Lakkasuo peatland complex_Wet subsite (control)_chamber
# Lakkasuo_Drained_chamber
# Lakkasuo_Natural_chamber
# Lettosuo_FI-Let_tower
# Lettosuo_H1_chamber
# Lettosuo_H2_chamber
# Lettosuo_H3_chamber
# Lettosuo_H4_chamber
# Lettosuo_H5_chamber
# Lettosuo_H6_chamber
# Lily Lake Fen_US-KPL_tower
# Lindig Farm Bear Trail_LF-b_chamber
# Lindig Farm East_LF-a_chamber
# Lindig Farm Field_LF-c_chamber
# Ljusdal_HY_HY_tower
# Ljusdal_SLM_SLM_tower
# Lutose_CA-LUT-B07_chamber
# Lutose_CA-LUT_tower
# Lutose_extreme-rich fen_chamber
# Mackenzie Valley, Fort Simpson, High Boreal - Peat Plateau_boreal forest - peat plateau_chamber
# Mackenzie Valley, Normal Wells, Low Sub-Arctic - Peat Plateau_low subarctic - peat plateau_chamber
# Mackenzie Valley, Norman Wells, Low Sub-Arctic - Upland_low subarctic - upland_chamber
# Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower
# McKee Farm_MK_chamber
# Middle Taiga Zone_large hollow_chamber
# Middle Taiga Zone_small ridge_chamber
# Moosonee Fen_MF_chamber
# Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh-hollow_chamber
# Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh-ridge_chamber
# Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower
# Mukhrino_Ira_Hol1_chamber
# Mukhrino_Ira_Hol2_chamber
# Mukhrino_Ira_Hol3_chamber
# Mukhrino_Ira_Hol4_chamber
# Mukhrino_Ira_Ridge_chamber
# Mukhrino_Ira_WetHol1_chamber
# Mukhrino_Ira_WetHol2_chamber
# Mukhrino_Mukhrino_RHC_tower
# Mukhrino_bog_E.hollow_1_agg_chamber
# Mukhrino_bog_E.hollow_2_agg_chamber
# Mukhrino_bog_Open_bog_1_agg_chamber
# Mukhrino_bog_Open_bog_2_agg_chamber
# Mukhrino_bog_Ridge_1_agg_chamber
# Mukhrino_bog_Ridge_2_agg_chamber
# Mukhrino_bog_Ryam_1_agg_chamber
# Mukhrino_bog_Ryam_2_agg_chamber
# Mukhrino_bog_S.hollow_1_agg_chamber
# Mukhrino_bog_S.hollow_2_agg_chamber
# Mukhrino_bog_Tall_ryam_1_agg_chamber
# Mukhrino_bog_Tall_ryam_2_agg_chamber
# NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower
# NEON Delta Junction (DEJU)_US-xDJ_tower
# Nalaikh grassland_MN-Nkh_tower
# Near-natural_Near-natural_C1_chamber
# Near-natural_Near-natural_C2_chamber
# Near-natural_Near-natural_C3_chamber
# North Star Yedoma-Regrowth_NSY-R_chamber
# North Star Yedoma_NSY_chamber
# North Star Yedoma_US-NSY_tower
# Old Steese_OS_chamber
# Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower
# Poker Flat Research Range Black Spruce Forest_US-Prr_tower
# Poker Flat Research Range: Succession from fire scar to deciduous forest_US-Rpf_tower
# Quebec - Eastern Boreal, Mature Black Spruce_CA-Qfo_tower
# RAS Experimental Field Station_Forest_Biocenosis_chamber
# Ranskalankorpi_FI-Ran forestry treatment_tower
# Ranskalankorpi_FI-Ran_tower
# Rosinedal-3_SE-Ros_tower
# Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower
# Saskatchewan - Western Boreal, forest burned in 1977_CA-SF1_tower
# Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower
# Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower
# Scotty Creek Bog_CA-SCB_tower
# Scotty Creek Landscape_CA-SCC_tower
# Scotty Creek_CA-SCC-MatureBog_chamber
# Scotty Creek_CA-SCC-PeatPlateau_chamber
# Scotty Creek_CA-SCC-PlateauEdge_chamber
# Scotty Creek_CA-SCC-YoungBog_chamber
# Shapsha_Aspen_chamber
# Shapsha_Mixed_chamber
# Shapsha_Siberian Pine_chamber
# Siikaneva2_A3_chamber
# Siikaneva2_A4_chamber
# Siikaneva2_A5_chamber
# Siikaneva2_A6_chamber
# Siikaneva2_B3_chamber
# Siikaneva2_B4_chamber
# Siikaneva2_B5_chamber
# Siikaneva2_B6_chamber
# Siikaneva2_C3_chamber
# Siikaneva2_C4_chamber
# Siikaneva2_C5_chamber
# Siikaneva2_C6_chamber
# Siikaneva2_FI-Si2_tower
# Siikaneva2_HHU1 ch4_chamber
# Siikaneva2_HHU1 nee_chamber
# Siikaneva2_HHU1 reco_chamber
# Siikaneva2_HHU2 ch4_chamber
# Siikaneva2_HHU2 nee_chamber
# Siikaneva2_HHU2 reco_chamber
# Siikaneva2_HHU3 ch4_chamber
# Siikaneva2_HHU3 nee_chamber
# Siikaneva2_HHU3 reco_chamber
# Siikaneva2_HL1 ch4_chamber
# Siikaneva2_HL1 nee_chamber
# Siikaneva2_HL1 reco_chamber
# Siikaneva2_HL2 ch4_chamber
# Siikaneva2_HL2 nee_chamber
# Siikaneva2_HL2 reco_chamber
# Siikaneva2_HL3 ch4_chamber
# Siikaneva2_HL3 nee_chamber
# Siikaneva2_HL3 reco_chamber
# Siikaneva2_HO1 ch4_chamber
# Siikaneva2_HO1 nee_chamber
# Siikaneva2_HO1 reco_chamber
# Siikaneva2_HO2 ch4_chamber
# Siikaneva2_HO2 nee_chamber
# Siikaneva2_HO2 reco_chamber
# Siikaneva2_HO3 ch4_chamber
# Siikaneva2_HO3 nee_chamber
# Siikaneva2_HO3 reco_chamber
# Siikaneva2_HU1 ch4_chamber
# Siikaneva2_HU1 nee_chamber
# Siikaneva2_HU1 reco_chamber
# Siikaneva2_HU2 ch4_chamber
# Siikaneva2_HU2 nee_chamber
# Siikaneva2_HU2 reco_chamber
# Siikaneva2_HU3 ch4_chamber
# Siikaneva2_HU3 nee_chamber
# Siikaneva2_HU3 reco_chamber
# Siikaneva2_L1 ch4_chamber
# Siikaneva2_L1 nee_chamber
# Siikaneva2_L1 reco_chamber
# Siikaneva2_L2 ch4_chamber
# Siikaneva2_L2 nee_chamber
# Siikaneva2_L2 reco_chamber
# Siikaneva2_L3 ch4_chamber
# Siikaneva2_L3 nee_chamber
# Siikaneva2_L3 reco_chamber
# Siikaneva2_MB1 ch4_chamber
# Siikaneva2_MB1 nee_chamber
# Siikaneva2_MB1 reco_chamber
# Siikaneva2_MB2 ch4_chamber
# Siikaneva2_MB2 nee_chamber
# Siikaneva2_MB2 reco_chamber
# Siikaneva2_MB3 ch4_chamber
# Siikaneva2_MB3 nee_chamber
# Siikaneva2_MB3 reco_chamber
# Siikaneva_FI-Sii_tower
# Siikaneva_Siikaneva-mixopeat_chamber
# Smith Creek_CA-SMC-MB_chamber
# Smith Creek_CA-SMC-PE_chamber
# Smith Creek_CA-SMC-P_chamber
# Smith Creek_CA-SMC-YB_chamber
# Smith Creek_CA-SMC_tower
# Steen River_CA-STR-B19_chamber
# Steen River_CA-STR_tower
# Stortjarn_SE-Srj_tower
# Svartberget_SE-Svb_tower
# Tanana_River_Burned Spruce Forest_chamber
# Tanana_River_Moat_chamber
# Tanana_River_Peatland_chamber
# Tervalamminsuo_Dry_tower
# Tervalamminsuo_Wet_tower
# Thinned_Thinned_C1_chamber
# Thinned_Thinned_C2_chamber
# Thinned_Thinned_C3_chamber
# Thoreau_TH_chamber
# Trice Grasto Graminoid_TG_chamber
# Trice Grasto Spruce Forest_TF_chamber
# UAF Bicycle Bumps - low elevation_UAF-BB-b_chamber
# UAF Bicycle Bumps_UAF-BB-a_chamber
# UAF Groomers_UAF-G_chamber
# UAF Midnight Sun Loop_UAF-S_chamber
# UAF Murie_UAF-M_chamber
# UAF Potato Field_UAF-PF_chamber
# UCI-1850 burn site_CA-NS1_tower
# UCI-1930 burn site_CA-NS2_tower
# UCI-1964 burn site wet_CA-NS4_tower
# UCI-1964 burn site_CA-NS3_tower
# UCI-1981 burn site_CA-NS5_tower
# UCI-1989 burn site_CA-NS6_tower
# UCI-1998 burn site_CA-NS7_tower
# University of Alaska, Fairbanks_US-Uaf_tower
# Vasyuganie field station, Tomsk_RU-VAS-Ridge-hollow complex (Hollow)_chamber
# Vasyuganie field station, Tomsk_RU-VAS-Ridge-hollow complex (Ridge)_chamber
# Vasyuganie field station, Tomsk_RU-VAS-open bog_chamber
# Vasyuganie field station, Tomsk_RU-VAS-ryam_chamber
# Western Siberia_Borch Fen3_chamber
# Western Siberia_Borch Fen_chamber
# Western Siberia_Dun Fen 2_chamber
# Western Siberia_Dun Fen_chamber
# Western Siberia_Khob Fen_chamber
# Western Siberia_NovTr Fen2_chamber
# Western Siberia_NovTr Fen_chamber
# Western Siberia_Potyuk Fen_chamber
# Western Siberia_Vag Fen_chamber
# Yakutsk Spasskaya Pad larch_RU-SkP_tower
# Yakutsk_Alas_chamber
# Yakutsk_Dyede_chamber
# Abeille_Vegetated_Surface_chamber
# Abisko Stordalen birch forest_tower
# Abisko_Heath_Control_chamber
# Abisko_Wet NE-facing slope_chamber
# Abisko_chamber
# Abisko_control_chamber
# Abisko_dwarf shrub-dominated heath_chamber
# Abisko_heath control_chamber
# Abisko_heath_chamber
# Alaska_peatland 2, point B. ALP2BST_chamber
# Alaska_peatland 2, point C. ALP2CST_chamber
# Alaska_peatland 2, point E. ALP2EST_chamber
# Alaska_peatland 2, point F. ALP2FST_chamber
# Andoya_NO-And_tower
# Bernard spruce-moss valley_tower
# Bottemyra_Collapsed Palsa_chamber
# Bottemyra_Degrading Palsa_chamber
# Bottemyra_Thermokarst Pond_chamber
# Bouleau peatland_CA-BOU_tower
# Bouleau peatland_automatedchamber1_HummockLichen_chamber
# Bouleau peatland_automatedchamber2_HummockSphagnum_chamber
# Bouleau peatland_automatedchamber3_Lawn_chamber
# Bouleau peatland_automatedchamber4_Hollow_chamber
# Carling Lake_CL1_chamber
# Carling Lake_CL2_chamber
# Cascaden Ridge Fire Scar_US-Fcr_tower
# Cherskii disturbed forest_RU-Eusk_cher2_tower
# Cherskii ecotone_RU-Eusk_cher1_tower
# Cherskii reference_RU-Ch2_tower
# Cherskii_CG_chamber
# Cherskii_CW_chamber
# Council, Alaska_US-KOC_Ch1_chamber
# Council, Alaska_US-KOC_Ch2_chamber
# Council, Alaska_US-KOC_Ch3_chamber
# Council, Alaska_US-KOC_Ch4_chamber
# Council, Alaska_US-KOC_tower
# Duvanny Yar_Earlier thawed bare Yedoma, dry_chamber
# Duvanny Yar_Earlier thawed bare Yedoma, wet_chamber
# Duvanny Yar_Freshly thawed bare Yedoma_chamber
# Duvanny Yar_Vegetated Holocene cover_chamber
# Duvanny Yar_Yedoma revegetated with grasses_chamber
# Duvanny Yar_Yedoma revegetated with mosses_chamber
# Duvanny Yar_Yedoma revegetated with tall grasses_chamber
# E6 (Toolik)_EC_chamber
# Eight Mile Lake_extensive thaw_chamber
# Eight Mile Lake_minimal thaw_chamber
# Eight Mile Lake_moderate thaw_chamber
# Eight Mile Lake_moist acidic tundra_chamber
# Hess Creek_HC_chamber
# Hospitaldalen_chamber
# Igarka, Krasnoyarsk,  forest-tundra ecotone_P1_chamber
# Igarka, Krasnoyarsk,  forest-tundra ecotone_P3_chamber
# Igarka, Krasnoyarsk,  forest-tundra ecotone_P4_chamber
# Igarka, Krasnoyarsk,  forest-tundra ecotone_P6_chamber
# Igarka_RU-Iga Feathermoss cover_chamber
# Igarka_RU-Iga Lichen cover_chamber
# Igarka_RU-Iga_tower
# Igarka_peatland 1, point B. SIP1BST_chamber
# Igarka_peatland 1, point C. SIP1CST_chamber
# Igarka_peatland 1, point D. SIP1DST_chamber
# Igarka_peatland 1, point E. SIP1EST_chamber
# Igarka_peatland 1, point F. SIP1FST_chamber
# Igarka_peatland 2, point A. SIP2AST_chamber
# Igarka_peatland 2, point B. SIP2BST_chamber
# Igarka_peatland 2, point D. SIP2DST_chamber
# Igarka_peatland 2, point E. SIP2EST_chamber
# Igarka_peatland 2, point F. SIP2FST_chamber
# Igarka_peatland 3, point B. SIP3BST_chamber
# Igarka_peatland 3, point C. SIP3CST_chamber
# Igarka_peatland 4, point A. SIP4AST_chamber
# Igarka_peatland 4, point B. SIP4BST_chamber
# Igarka_peatland 4, point C. SIP4CST_chamber
# Igarka_peatland 4, point D. SIP4DST_chamber
# Igarka_peatland 5, point A. SIP5AST_chamber
# Igarka_peatland 5, point B. SIP5BST_chamber
# Igarka_peatland 5, point C. SIP5CST_chamber
# Igarka_peatland 5, point D. SIP5DST_chamber
# Igarka_soil 1, point A. SIS1AST_chamber
# Igarka_soil 1, point B. SIS1BST_chamber
# Igarka_soil 2, point A. SIS2AST_chamber
# Igarka_soil 2, point B. SIS2BST_chamber
# Innoko_Flats_Fen_chamber
# Innoko_Flats_Frozen Plateau_chamber
# Innoko_Flats_Intermediate Bog_chamber
# Innoko_Flats_Old Bog_chamber
# Innoko_Flats_Young Bog_chamber
# Iskoras_NO-Isk-fen_tower
# Iskoras_NO-Isk-palsa_tower
# Iskoras_NO-Isk_tower
# Kaamanen_FI-Kaa_tower
# Kaamanen_Flark_chamber
# Kaamanen_Lawn_chamber
# Kaamanen_String_chamber
# Kaamanen_chamber
# Kenttarova_FI-Ken_tower
# Kurungnakh_Bare sand_chamber
# Kurungnakh_Earlier thawed bare Yedoma_chamber
# Kurungnakh_Freshly thawed bare Yedoma_chamber
# Kurungnakh_Vegetated Holocene cover_chamber
# Kurungnakh_Yedoma revegetated with grasses_chamber
# Kurungnakh_Yedoma revegetated with mosses_chamber
# Lac Le Caron peatland, an ombrotrophic bog_CA-LLC_tower
# Lek Vorkuta_hummock_Other
# Lek Vorkuta_intermd lawn_Other
# Lek Vorkuta_intermed. Flark_Other
# Lek Vorkuta_wet flark_Other
# Lek Vorkuta_wet lawn_Other
# Lena River Delta_Dry tundra - polygon rim_chamber
# Lena River Delta_Wet tundra - polygon center_chamber
# Lena_polygon center_chamber
# Lena_polygon rim_chamber
# Lompolojankka_FI-Lom_tower
# Mackenzie Valley, Inuvik, High Sub-Arctic - Peat Plateau_high subarctic - peat plateau_chamber
# Mackenzie Valley, Inuvik, High Sub-Arctic - Upland_high subarctic - upland_chamber
# Montmorency_Forest_203_SnowDiffusion
# Montmorency_Forest_212_SnowDiffusion
# Montmorency_Forest_219_SnowDiffusion
# Montmorency_Forest_307_SnowDiffusion
# Montmorency_Forest_311_SnowDiffusion
# Montmorency_Forest_404_SnowDiffusion
# Montmorency_Forest_406_SnowDiffusion
# Montmorency_Forest_407_SnowDiffusion
# Montmorency_Forest_GPS_SnowDiffusion
# NEON Healy (HEAL)_US-xHE_tower
# Nelegel_RU-Nel_tower
# Neleger Burnt Forest_RU-NeB_tower
# Neleger Cutover_RU-NeC_tower
# Neleger larch forest_RU-NeF_tower
# Northeast Russia_bare peat_chamber
# Northeast Russia_peat plateau_chamber
# Northeast Russia_upland tundra_chamber
# Northern Finland_Forest: Birch forest_chamber
# Northern Finland_Forest: Lichen heath_chamber
# Northern Finland_Mire edge: Hummock_chamber
# Northern Finland_Mire edge: Interhummock_chamber
# Northern Finland_Mire: Lawn_chamber
# Northern Finland_Mire: Sphagnum interhummock_chamber
# Pallas_FI_Pal_101_2019_chamber
# Pallas_FI_Pal_102_2019_chamber
# Pallas_FI_Pal_103_2019_chamber
# Pallas_FI_Pal_104_2019_chamber
# Pallas_FI_Pal_10A_2019_chamber
# Pallas_FI_Pal_10B_2019_chamber
# Pallas_FI_Pal_10C_2019_chamber
# Pallas_FI_Pal_11A_2019_chamber
# Pallas_FI_Pal_11B_2019_chamber
# Pallas_FI_Pal_11C_2019_chamber
# Pallas_FI_Pal_12A_2019_chamber
# Pallas_FI_Pal_12B_2019_chamber
# Pallas_FI_Pal_12C_2019_chamber
# Pallas_FI_Pal_13A_2019_chamber
# Pallas_FI_Pal_13B_2019_chamber
# Pallas_FI_Pal_13C_2019_chamber
# Pallas_FI_Pal_14A_2019_chamber
# Pallas_FI_Pal_14B_2019_chamber
# Pallas_FI_Pal_14C_2019_chamber
# Pallas_FI_Pal_15A_2019_chamber
# Pallas_FI_Pal_15B_2019_chamber
# Pallas_FI_Pal_15C_2019_chamber
# Pallas_FI_Pal_16A_2019_chamber
# Pallas_FI_Pal_16B_2019_chamber
# Pallas_FI_Pal_16C_2019_chamber
# Pallas_FI_Pal_17A_2019_chamber
# Pallas_FI_Pal_17B_2019_chamber
# Pallas_FI_Pal_17C_2019_chamber
# Pallas_FI_Pal_18A_2019_chamber
# Pallas_FI_Pal_18B_2019_chamber
# Pallas_FI_Pal_18C_2019_chamber
# Pallas_FI_Pal_1A_2019_chamber
# Pallas_FI_Pal_1B_2019_chamber
# Pallas_FI_Pal_1C_2019_chamber
# Pallas_FI_Pal_201_2019_chamber
# Pallas_FI_Pal_202_2019_chamber
# Pallas_FI_Pal_203_2019_chamber
# Pallas_FI_Pal_20A_2019_chamber
# Pallas_FI_Pal_20B_2019_chamber
# Pallas_FI_Pal_20C_2019_chamber
# Pallas_FI_Pal_21A_2019_chamber
# Pallas_FI_Pal_21B_2019_chamber
# Pallas_FI_Pal_21C_2019_chamber
# Pallas_FI_Pal_22A_2019_chamber
# Pallas_FI_Pal_22B_2019_chamber
# Pallas_FI_Pal_22C_2019_chamber
# Pallas_FI_Pal_23A_2019_chamber
# Pallas_FI_Pal_23B_2019_chamber
# Pallas_FI_Pal_23C_2019_chamber
# Pallas_FI_Pal_24A_2019_chamber
# Pallas_FI_Pal_24B_2019_chamber
# Pallas_FI_Pal_24C_2019_chamber
# Pallas_FI_Pal_25A_2019_chamber
# Pallas_FI_Pal_25B_2019_chamber
# Pallas_FI_Pal_25C_2019_chamber
# Pallas_FI_Pal_2A_2019_chamber
# Pallas_FI_Pal_2B_2019_chamber
# Pallas_FI_Pal_2C_2019_chamber
# Pallas_FI_Pal_301_2019_chamber
# Pallas_FI_Pal_302_2019_chamber
# Pallas_FI_Pal_303_2019_chamber
# Pallas_FI_Pal_304_2019_chamber
# Pallas_FI_Pal_305_2019_chamber
# Pallas_FI_Pal_3A_2019_chamber
# Pallas_FI_Pal_3B_2019_chamber
# Pallas_FI_Pal_3C_2019_chamber
# Pallas_FI_Pal_401_2019_chamber
# Pallas_FI_Pal_402_2019_chamber
# Pallas_FI_Pal_403_2019_chamber
# Pallas_FI_Pal_4A_2019_chamber
# Pallas_FI_Pal_4B_2019_chamber
# Pallas_FI_Pal_4C_2019_chamber
# Pallas_FI_Pal_5A_2019_chamber
# Pallas_FI_Pal_5B_2019_chamber
# Pallas_FI_Pal_5C_2019_chamber
# Pallas_FI_Pal_6A_2019_chamber
# Pallas_FI_Pal_6B_2019_chamber
# Pallas_FI_Pal_6C_2019_chamber
# Pallas_FI_Pal_7A_2019_chamber
# Pallas_FI_Pal_7B_2019_chamber
# Pallas_FI_Pal_7C_2019_chamber
# Pallas_FI_Pal_8A_2019_chamber
# Pallas_FI_Pal_8B_2019_chamber
# Pallas_FI_Pal_8C_2019_chamber
# Pallas_FI_Pal_T1_P10_E_2020_chamber
# Pallas_FI_Pal_T1_P10_N_2020_chamber
# Pallas_FI_Pal_T1_P11_E_2020_chamber
# Pallas_FI_Pal_T1_P11_N_2020_chamber
# Pallas_FI_Pal_T1_P1_E_2019_chamber
# Pallas_FI_Pal_T1_P1_E_2020_chamber
# Pallas_FI_Pal_T1_P1_N_2019_chamber
# Pallas_FI_Pal_T1_P1_N_2020_chamber
# Pallas_FI_Pal_T1_P1_W_2019_chamber
# Pallas_FI_Pal_T1_P1_W_2020_chamber
# Pallas_FI_Pal_T1_P2_E_2019_chamber
# Pallas_FI_Pal_T1_P2_E_2020_chamber
# Pallas_FI_Pal_T1_P2_N_2019_chamber
# Pallas_FI_Pal_T1_P2_N_2020_chamber
# Pallas_FI_Pal_T1_P2_W_2019_chamber
# Pallas_FI_Pal_T1_P2_W_2020_chamber
# Pallas_FI_Pal_T1_P3_E_2019_chamber
# Pallas_FI_Pal_T1_P3_E_2020_chamber
# Pallas_FI_Pal_T1_P3_N_2019_chamber
# Pallas_FI_Pal_T1_P3_N_2020_chamber
# Pallas_FI_Pal_T1_P3_W_2019_chamber
# Pallas_FI_Pal_T1_P3_W_2020_chamber
# Pallas_FI_Pal_T1_P4_E_2019_chamber
# Pallas_FI_Pal_T1_P4_E_2020_chamber
# Pallas_FI_Pal_T1_P4_N_2019_chamber
# Pallas_FI_Pal_T1_P4_N_2020_chamber
# Pallas_FI_Pal_T1_P4_W_2019_chamber
# Pallas_FI_Pal_T1_P4_W_2020_chamber
# Pallas_FI_Pal_T1_P5_E_2019_chamber
# Pallas_FI_Pal_T1_P5_E_2020_chamber
# Pallas_FI_Pal_T1_P5_N_2019_chamber
# Pallas_FI_Pal_T1_P5_N_2020_chamber
# Pallas_FI_Pal_T1_P5_W_2019_chamber
# Pallas_FI_Pal_T1_P5_W_2020_chamber
# Pallas_FI_Pal_T1_P6_E_2019_chamber
# Pallas_FI_Pal_T1_P6_E_2020_chamber
# Pallas_FI_Pal_T1_P6_N_2019_chamber
# Pallas_FI_Pal_T1_P6_N_2020_chamber
# Pallas_FI_Pal_T1_P6_W_2019_chamber
# Pallas_FI_Pal_T1_P6_W_2020_chamber
# Pallas_FI_Pal_T1_P7_E_2019_chamber
# Pallas_FI_Pal_T1_P7_E_2020_chamber
# Pallas_FI_Pal_T1_P7_N_2019_chamber
# Pallas_FI_Pal_T1_P7_N_2020_chamber
# Pallas_FI_Pal_T1_P7_W_2019_chamber
# Pallas_FI_Pal_T1_P7_W_2020_chamber
# Pallas_FI_Pal_T1_P8_E_2019_chamber
# Pallas_FI_Pal_T1_P8_E_2020_chamber
# Pallas_FI_Pal_T1_P8_N_2019_chamber
# Pallas_FI_Pal_T1_P8_N_2020_chamber
# Pallas_FI_Pal_T1_P8_W_2019_chamber
# Pallas_FI_Pal_T1_P8_W_2020_chamber
# Pallas_FI_Pal_T1_P9_E_2020_chamber
# Pallas_FI_Pal_T1_P9_N_2020_chamber
# Pallas_FI_Pal_T1_P9_W_2020_chamber
# Pallas_FI_Pal_T2_P10_E_2020_chamber
# Pallas_FI_Pal_T2_P10_N_2020_chamber
# Pallas_FI_Pal_T2_P10_W_2020_chamber
# Pallas_FI_Pal_T2_P11_E_2020_chamber
# Pallas_FI_Pal_T2_P11_N_2020_chamber
# Pallas_FI_Pal_T2_P11_W_2020_chamber
# Pallas_FI_Pal_T2_P1_E_2019_chamber
# Pallas_FI_Pal_T2_P1_N_2019_chamber
# Pallas_FI_Pal_T2_P1_N_2020_chamber
# Pallas_FI_Pal_T2_P1_W_2019_chamber
# Pallas_FI_Pal_T2_P1_W_2020_chamber
# Pallas_FI_Pal_T2_P2_E_2020_chamber
# Pallas_FI_Pal_T2_P2_N_2020_chamber
# Pallas_FI_Pal_T2_P2_W_2020_chamber
# Pallas_FI_Pal_T2_P3_E_2020_chamber
# Pallas_FI_Pal_T2_P3_N_2020_chamber
# Pallas_FI_Pal_T2_P3_W_2020_chamber
# Pallas_FI_Pal_T2_P4_E_2020_chamber
# Pallas_FI_Pal_T2_P4_N_2020_chamber
# Pallas_FI_Pal_T2_P4_W_2020_chamber
# Pallas_FI_Pal_T2_P5_E_2020_chamber
# Pallas_FI_Pal_T2_P5_N_2020_chamber
# Pallas_FI_Pal_T2_P6_E_2020_chamber
# Pallas_FI_Pal_T2_P6_W_2020_chamber
# Pallas_FI_Pal_T2_P7_E_2020_chamber
# Pallas_FI_Pal_T2_P7_N_2020_chamber
# Pallas_FI_Pal_T2_P7_W_2020_chamber
# Pallas_FI_Pal_T2_P8_E_2020_chamber
# Pallas_FI_Pal_T2_P8_N_2020_chamber
# Pallas_FI_Pal_T2_P8_W_2020_chamber
# Pallas_FI_Pal_T2_P9_E_2020_chamber
# Pallas_FI_Pal_T2_P9_N_2020_chamber
# Pallas_FI_Pal_T2_P9_W_2020_chamber
# Pallas_FI_Pal_T3_P10_E_2020_chamber
# Pallas_FI_Pal_T3_P10_N_2020_chamber
# Pallas_FI_Pal_T3_P10_W_2020_chamber
# Pallas_FI_Pal_T3_P11_E_2020_chamber
# Pallas_FI_Pal_T3_P11_W_2020_chamber
# Pallas_FI_Pal_T3_P1_E_2019_chamber
# Pallas_FI_Pal_T3_P1_E_2020_chamber
# Pallas_FI_Pal_T3_P1_N_2019_chamber
# Pallas_FI_Pal_T3_P1_N_2020_chamber
# Pallas_FI_Pal_T3_P1_W_2019_chamber
# Pallas_FI_Pal_T3_P2_E_2019_chamber
# Pallas_FI_Pal_T3_P2_E_2020_chamber
# Pallas_FI_Pal_T3_P2_N_2019_chamber
# Pallas_FI_Pal_T3_P2_N_2020_chamber
# Pallas_FI_Pal_T3_P2_W_2019_chamber
# Pallas_FI_Pal_T3_P3_E_2019_chamber
# Pallas_FI_Pal_T3_P3_N_2019_chamber
# Pallas_FI_Pal_T3_P3_N_2020_chamber
# Pallas_FI_Pal_T3_P3_W_2019_chamber
# Pallas_FI_Pal_T3_P3_W_2020_chamber
# Pallas_FI_Pal_T3_P4_E_2020_chamber
# Pallas_FI_Pal_T3_P4_N_2020_chamber
# Pallas_FI_Pal_T3_P4_W_2020_chamber
# Pallas_FI_Pal_T3_P5_E_2020_chamber
# Pallas_FI_Pal_T3_P5_N_2020_chamber
# Pallas_FI_Pal_T3_P5_W_2020_chamber
# Pallas_FI_Pal_T3_P6_E_2020_chamber
# Pallas_FI_Pal_T3_P6_N_2020_chamber
# Pallas_FI_Pal_T3_P6_W_2020_chamber
# Pallas_FI_Pal_T3_P7_E_2020_chamber
# Pallas_FI_Pal_T3_P7_N_2020_chamber
# Pallas_FI_Pal_T3_P7_W_2020_chamber
# Pallas_FI_Pal_T3_P8_E_2020_chamber
# Pallas_FI_Pal_T3_P8_N_2020_chamber
# Pallas_FI_Pal_T3_P8_W_2020_chamber
# Pallas_FI_Pal_T3_P9_E_2020_chamber
# Pallas_FI_Pal_T3_P9_N_2020_chamber
# Pallas_FI_Pal_T3_P9_W_2020_chamber
# Pallas_FI_Pal_T4_P11_E_2019_chamber
# Pallas_FI_Pal_T4_P11_N_2019_chamber
# Pallas_FI_Pal_T4_P11_W_2019_chamber
# Pallas_FI_Pal_T4_P12_E_2019_chamber
# Pallas_FI_Pal_T4_P12_N_2019_chamber
# Pallas_FI_Pal_T4_P12_W_2019_chamber
# Pallas_FI_Pal_T4_P1_E_2019_chamber
# Pallas_FI_Pal_T4_P1_N_2019_chamber
# Pallas_FI_Pal_T4_P1_W_2019_chamber
# Pallas_FI_Pal_T4_P2_E_2019_chamber
# Pallas_FI_Pal_T4_P2_N_2019_chamber
# Pallas_FI_Pal_T4_P2_W_2019_chamber
# Pallas_FI_Pal_T4_P3_E_2019_chamber
# Pallas_FI_Pal_T4_P3_N_2019_chamber
# Pallas_FI_Pal_T4_P3_W_2019_chamber
# Pallas_FI_Pal_T4_P4_E_2019_chamber
# Pallas_FI_Pal_T4_P4_N_2019_chamber
# Pallas_FI_Pal_T4_P4_W_2019_chamber
# Pallas_FI_Pal_T4_P6_E_2019_chamber
# Pallas_FI_Pal_T4_P6_N_2019_chamber
# Pallas_FI_Pal_T4_P6_W_2019_chamber
# Pallas_FI_Pal_T4_P7_E_2019_chamber
# Pallas_FI_Pal_T4_P7_N_2019_chamber
# Pallas_FI_Pal_T4_P7_W_2019_chamber
# Pallas_FI_Pal_T4_P8_E_2019_chamber
# Pallas_FI_Pal_T4_P8_N_2019_chamber
# Pallas_FI_Pal_T4_P8_W_2019_chamber
# Pallas_FI_Pal_T4_P9_E_2019_chamber
# Pallas_FI_Pal_T4_P9_N_2019_chamber
# Pallas_FI_Pal_T4_P9_W_2019_chamber
# Pallas_FI_Pal_T5_P4_E_2019_chamber
# Pallas_FI_Pal_T5_P4_N_2019_chamber
# Pallas_FI_Pal_T5_P4_W_2019_chamber
# Pallas_FI_Pal_T5_P5_E_2019_chamber
# Pallas_FI_Pal_T5_P5_N_2019_chamber
# Pallas_FI_Pal_T5_P5_W_2019_chamber
# Pallas_FI_Pal_T5_P6_E_2019_chamber
# Pallas_FI_Pal_T5_P6_N_2019_chamber
# Pallas_FI_Pal_T5_P6_W_2019_chamber
# Pallas_FI_Pal_T5_P7_E_2019_chamber
# Pallas_FI_Pal_T5_P7_N_2019_chamber
# Pallas_FI_Pal_T5_P7_W_2019_chamber
# Pallas_FI_Pal_T5_P8_E_2019_chamber
# Pallas_FI_Pal_T5_P8_N_2019_chamber
# Pallas_FI_Pal_T5_P8_W_2019_chamber
# Pallas_FI_Pal_T6_P11_E_2019_chamber
# Pallas_FI_Pal_T6_P11_N_2019_chamber
# Pallas_FI_Pal_T6_P11_W_2019_chamber
# Pallas_FI_Pal_T6_P14_E_2019_chamber
# Pallas_FI_Pal_T6_P14_N_2019_chamber
# Pallas_FI_Pal_T6_P14_W_2019_chamber
# Pallas_FI_Pal_T6_P1_E_2019_chamber
# Pallas_FI_Pal_T6_P1_N_2019_chamber
# Pallas_FI_Pal_T6_P1_W_2019_chamber
# Pallas_FI_Pal_T6_P2_E_2019_chamber
# Pallas_FI_Pal_T6_P2_N_2019_chamber
# Pallas_FI_Pal_T6_P2_W_2019_chamber
# Pallas_FI_Pal_T6_P3_E_2019_chamber
# Pallas_FI_Pal_T6_P3_N_2019_chamber
# Pallas_FI_Pal_T6_P3_W_2019_chamber
# Pallas_FI_Pal_T6_P4_E_2019_chamber
# Pallas_FI_Pal_T6_P4_N_2019_chamber
# Pallas_FI_Pal_T6_P4_W_2019_chamber
# Pallas_FI_Pal_T6_P5_E_2019_chamber
# Pallas_FI_Pal_T6_P5_N_2019_chamber
# Pallas_FI_Pal_T6_P5_W_2019_chamber
# Pallas_FI_Pal_T6_P6_E_2019_chamber
# Pallas_FI_Pal_T6_P6_N_2019_chamber
# Pallas_FI_Pal_T6_P6_W_2019_chamber
# Pallas_FI_Pal_T6_P7_E_2019_chamber
# Pallas_FI_Pal_T6_P7_N_2019_chamber
# Pallas_FI_Pal_T6_P7_W_2019_chamber
# Pallas_FI_Pal_T6_P9_E_2019_chamber
# Pallas_FI_Pal_T6_P9_N_2019_chamber
# Pallas_FI_Pal_T6_P9_W_2019_chamber
# Pallas_FI_Pal_T8_P10_E_2019_chamber
# Pallas_FI_Pal_T8_P10_N_2019_chamber
# Pallas_FI_Pal_T8_P10_W_2019_chamber
# Pallas_FI_Pal_T8_P11_E_2019_chamber
# Pallas_FI_Pal_T8_P11_N_2019_chamber
# Pallas_FI_Pal_T8_P11_W_2019_chamber
# Pallas_FI_Pal_T8_P7_E_2019_chamber
# Pallas_FI_Pal_T8_P7_N_2019_chamber
# Pallas_FI_Pal_T8_P7_W_2019_chamber
# Pallas_FI_Pal_T8_P8_E_2019_chamber
# Pallas_FI_Pal_T8_P8_N_2019_chamber
# Pallas_FI_Pal_T8_P8_W_2019_chamber
# Pallas_FI_Pal_T8_P9_E_2019_chamber
# Pallas_FI_Pal_T8_P9_N_2019_chamber
# Pallas_FI_Pal_T8_P9_W_2019_chamber
# Pallas_FI_Pal_T9_P2_N_2019_chamber
# Pallas_FI_Pal_T9_P2_W_2019_chamber
# Pallas_FI_Pal_T9_P3_E_2019_chamber
# Pallas_FI_Pal_T9_P3_N_2019_chamber
# Pallas_FI_Pal_T9_P3_W_2019_chamber
# Pallas_FI_Pal_T9_P4_E_2019_chamber
# Pallas_FI_Pal_T9_P4_N_2019_chamber
# Pallas_FI_Pal_T9_P4_W_2019_chamber
# Pallas_FI_Pal_T9_P5_E_2019_chamber
# Pallas_FI_Pal_T9_P5_N_2019_chamber
# Pallas_FI_Pal_T9_P5_W_2019_chamber
# Pallas_FI_Pal_T9_P6_E_2019_chamber
# Pallas_FI_Pal_T9_P6_N_2019_chamber
# Pallas_FI_Pal_T9_P6_W_2019_chamber
# Pallas_FI_Pal_T9_P7_W_2019_chamber
# Petsikko_Dry Hollow (DH), DH1_chamber
# Petsikko_Dry Hollow (DH), DH2_chamber
# Petsikko_Dry Hollow (DH), DH3_chamber
# Petsikko_Forest Hummocks (HF), HF1_chamber
# Petsikko_Forest Hummocks (HF), HF2_chamber
# Petsikko_Forest Hummocks (HF), HF3_chamber
# Petsikko_Lichen-covered Hummocks (HL), HL1_chamber
# Petsikko_Lichen-covered Hummocks (HL), HL2_chamber
# Petsikko_Lichen-covered Hummocks (HL), HL4_chamber
# Petsikko_Mire Hummocks (HM), HM1_chamber
# Petsikko_Mire Hummocks (HM), HM2_chamber
# Petsikko_Mire Hummocks (HM), HM3_chamber
# Quebec - 1975 Harvested Black Spruce_CA-Qc2_tower
# Salmisuo Mire, Eastern Finland_Lawns_chamber
# Salmisuo_Carex_chamber
# Salmisuo_Eriophorum Lawn_chamber
# Salmisuo_FI-Salm_tower
# Salmisuo_Hummocks_chamber
# Salmisuo_Wet Flark_chamber
# Sammaltunturi fell_FI-SamFell_tower
# Samoylov Island_RU-Sam (closed)_tower
# Samoylov Island_RU-Sam (open)_tower
# Samoylov Island_RU-Sam_tower
# Sarkka_Drained_chamber
# Sarkka_Natural_chamber
# Seida_Bare peat_chamber
# Seida_Betula nana tundra heath_chamber
# Seida_Carex fen_chamber
# Seida_Dry lichen tundra heath_chamber
# Seida_Eriophorum fen_chamber
# Seida_RU-Vrk_tower
# Seida_Shrub tundra heath, dry_chamber
# Seida_Shrub tundra heath, moist_chamber
# Seida_Tundra bog, dry_chamber
# Seida_Tundra bog, moist_chamber
# Seida_Willow_chamber
# Sodankyla_BRDF_SnowDiffusion
# Sodankyla_Bog_SnowDiffusion
# Sodankyla_ECB_SnowDiffusion
# Sodankyla_ECF_SnowDiffusion
# Sodankyla_F12_SnowDiffusion
# Sodankyla_F13_SnowDiffusion
# Sodankyla_F21_SnowDiffusion
# Sodankyla_F22_SnowDiffusion
# Sodankyla_F23_SnowDiffusion
# Sodankyla_F31_SnowDiffusion
# Sodankyla_F32_SnowDiffusion
# Sodankyla_F33_SnowDiffusion
# Sodankyla_FI-Sod_tower
# Sodankyla_FUV_SnowDiffusion
# Sodankyla_Forest_chamber
# Sodankyla_H01_SnowDiffusion
# Sodankyla_H04_SnowDiffusion
# Sodankyla_H06_SnowDiffusion
# Sodankyla_H08_SnowDiffusion
# Sodankyla_H09_SnowDiffusion
# Sodankyla_H10_SnowDiffusion
# Sodankyla_H13_SnowDiffusion
# Sodankyla_H50dry_SnowDiffusion
# Sodankyla_H50wet_SnowDiffusion
# Sodankyla_LF_SnowDiffusion
# Sodankyla_NB01_SnowDiffusion
# Sodankyla_NB05_SnowDiffusion
# Sodankyla_NB06_SnowDiffusion
# Sodankyla_R01_SnowDiffusion
# Sodankyla_R02_SnowDiffusion
# Sodankyla_SB03_SnowDiffusion
# Sodankyla_SB07_SnowDiffusion
# Sodankyla_Wetland_chamber
# Stordalen Fen_SE-St1_tower
# Stordalen Mire_Bog_chamber
# Stordalen Mire_Fen_chamber
# Stordalen Mire_Palsa_chamber
# Stordalen Mire_Site A (minerotrophic)_chamber
# Stordalen Mire_Site B (ombrotrophic)_chamber
# Stordalen Palsa Bog_SE-Sto_tower
# Stordalen_Abisko-mixopeat_chamber
# Stordalen_Avni transect collar 10_chamber
# Stordalen_Avni transect collar 11_chamber
# Stordalen_Avni transect collar 12_chamber
# Stordalen_Avni transect collar 13_chamber
# Stordalen_Avni transect collar 14_chamber
# Stordalen_Avni transect collar 15_chamber
# Stordalen_Avni transect collar 16_chamber
# Stordalen_Avni transect collar 17_chamber
# Stordalen_Avni transect collar 18_chamber
# Stordalen_Avni transect collar 19_chamber
# Stordalen_Avni transect collar 1_chamber
# Stordalen_Avni transect collar 20_chamber
# Stordalen_Avni transect collar 21_chamber
# Stordalen_Avni transect collar 22_chamber
# Stordalen_Avni transect collar 23_chamber
# Stordalen_Avni transect collar 24_chamber
# Stordalen_Avni transect collar 25_chamber
# Stordalen_Avni transect collar 26_chamber
# Stordalen_Avni transect collar 27_chamber
# Stordalen_Avni transect collar 28_chamber
# Stordalen_Avni transect collar 2_chamber
# Stordalen_Avni transect collar 3_chamber
# Stordalen_Avni transect collar 4_chamber
# Stordalen_Avni transect collar 5_chamber
# Stordalen_Avni transect collar 6_chamber
# Stordalen_Avni transect collar 7_chamber
# Stordalen_Avni transect collar 8_chamber
# Stordalen_Avni transect collar 9_chamber
# Stordalen_IL Palsa_chamber
# Stordalen_IL Riparian Zone_chamber
# Stordalen_IL Thaw Front_chamber
# Stordalen_MS Palsa_chamber
# Stordalen_MS Riparian Zone_chamber
# Stordalen_MS Thaw Front_chamber
# Stordalen_StordalenDL10_agg_chamber
# Stordalen_StordalenDL1_agg_chamber
# Stordalen_StordalenDL2_agg_chamber
# Stordalen_StordalenDL3_agg_chamber
# Stordalen_StordalenDL4_agg_chamber
# Stordalen_StordalenDL5_agg_chamber
# Stordalen_StordalenDL6_agg_chamber
# Stordalen_StordalenDL8_agg_chamber
# Stordalen_StordalenDL9_agg_chamber
# Stordalen_StordalenDS-DL3_agg_chamber
# Stordalen_StordalenDS1_agg_chamber
# Stordalen_StordalenDS2_agg_chamber
# Stordalen_StordalenDS3_agg_chamber
# Stordalen_StordalenDS4_agg_chamber
# Stordalen_StordalenDS5_agg_chamber
# Stordalen_StordalenDSS1_agg_chamber
# Stordalen_StordalenDSS2_agg_chamber
# Stordalen_StordalenDSS3_agg_chamber
# Stordalen_StordalenDSS4_agg_chamber
# Stordalen_StordalenDSS5_agg_chamber
# Stordalen_StordalenPB1_agg_chamber
# Stordalen_StordalenPB2_agg_chamber
# Stordalen_StordalenPB3_agg_chamber
# Stordalen_StordalenPB4_agg_chamber
# Stordalen_StordalenPB5_agg_chamber
# Stordalen_StordalenPB7_agg_chamber
# Stordalen_StordalenPBS1_agg_chamber
# Stordalen_StordalenPBS2_agg_chamber
# Stordalen_StordalenPBS3_agg_chamber
# Stordalen_StordalenPBS4_agg_chamber
# Stordalen_StordalenPBS5_agg_chamber
# Stordalen_StordalenSE10_agg_chamber
# Stordalen_StordalenSE1_agg_chamber
# Stordalen_StordalenSE2_agg_chamber
# Stordalen_StordalenSE3_agg_chamber
# Stordalen_StordalenSE4_agg_chamber
# Stordalen_StordalenSE5_agg_chamber
# Stordalen_StordalenSE6_agg_chamber
# Stordalen_StordalenSE7_agg_chamber
# Stordalen_StordalenSE8_agg_chamber
# Stordalen_StordalenSE9_agg_chamber
# Stordalen_StordalenSW10_agg_chamber
# Stordalen_StordalenSW11_agg_chamber
# Stordalen_StordalenSW12_agg_chamber
# Stordalen_StordalenSW13_agg_chamber
# Stordalen_StordalenSW14_agg_chamber
# Stordalen_StordalenSW15_agg_chamber
# Stordalen_StordalenSW1_agg_chamber
# Stordalen_StordalenSW2_agg_chamber
# Stordalen_StordalenSW3_agg_chamber
# Stordalen_StordalenSW4_agg_chamber
# Stordalen_StordalenSW5_agg_chamber
# Stordalen_StordalenSW6_agg_chamber
# Stordalen_StordalenSW7_agg_chamber
# Stordalen_StordalenSW8_agg_chamber
# Stordalen_StordalenSW9_agg_chamber
# Stordalen_StordalenWW1_agg_chamber
# Stordalen_StordalenWW2_agg_chamber
# Stordalen_StordalenWW3_agg_chamber
# Stordalen_StordalenWW4_agg_chamber
# Stordalen_StordalenWW5_agg_chamber
# Storflaket_StorflaketDL10_agg_chamber
# Storflaket_StorflaketDL1_agg_chamber
# Storflaket_StorflaketDL2_agg_chamber
# Storflaket_StorflaketDL3_agg_chamber
# Storflaket_StorflaketDL4_agg_chamber
# Storflaket_StorflaketDL5_agg_chamber
# Storflaket_StorflaketDL6_agg_chamber
# Storflaket_StorflaketDL7_agg_chamber
# Storflaket_StorflaketDL8_agg_chamber
# Storflaket_StorflaketDL9_agg_chamber
# Storflaket_StorflaketDLS1_agg_chamber
# Storflaket_StorflaketDLS2_agg_chamber
# Storflaket_StorflaketDLS3_agg_chamber
# Storflaket_StorflaketDS/P33_agg_chamber
# Storflaket_StorflaketDS1_agg_chamber
# Storflaket_StorflaketDS2_agg_chamber
# Storflaket_StorflaketDS3_agg_chamber
# Storflaket_StorflaketDS4_agg_chamber
# Storflaket_StorflaketDS5_agg_chamber
# Storflaket_StorflaketDSS1_agg_chamber
# Storflaket_StorflaketDSS2_agg_chamber
# Storflaket_StorflaketDSS3_agg_chamber
# Storflaket_StorflaketDSS4_agg_chamber
# Storflaket_StorflaketDSS5_agg_chamber
# Storflaket_StorflaketDSS6_agg_chamber
# Storflaket_StorflaketDSS7_agg_chamber
# Storflaket_StorflaketPB1_agg_chamber
# Storflaket_StorflaketPB2_agg_chamber
# Storflaket_StorflaketPB3_agg_chamber
# Storflaket_StorflaketPB4_agg_chamber
# Storflaket_StorflaketPB5_agg_chamber
# Storflaket_StorflaketPBS1_agg_chamber
# Storflaket_StorflaketPBS2_agg_chamber
# Storflaket_StorflaketPBS3_agg_chamber
# Storflaket_StorflaketPBS4_agg_chamber
# Storflaket_StorflaketPBS5_agg_chamber
# Storflaket_StorflaketSE10_agg_chamber
# Storflaket_StorflaketSE11_agg_chamber
# Storflaket_StorflaketSE12_agg_chamber
# Storflaket_StorflaketSE13_agg_chamber
# Storflaket_StorflaketSE14_agg_chamber
# Storflaket_StorflaketSE15_agg_chamber
# Storflaket_StorflaketSE1_agg_chamber
# Storflaket_StorflaketSE2_agg_chamber
# Storflaket_StorflaketSE3_agg_chamber
# Storflaket_StorflaketSE4_agg_chamber
# Storflaket_StorflaketSE5_agg_chamber
# Storflaket_StorflaketSE6_agg_chamber
# Storflaket_StorflaketSE7_agg_chamber
# Storflaket_StorflaketSE8_agg_chamber
# Storflaket_StorflaketSE9_agg_chamber
# Storflaket_StorflaketSW10_agg_chamber
# Storflaket_StorflaketSW11_agg_chamber
# Storflaket_StorflaketSW12_agg_chamber
# Storflaket_StorflaketSW13_agg_chamber
# Storflaket_StorflaketSW14_agg_chamber
# Storflaket_StorflaketSW1_agg_chamber
# Storflaket_StorflaketSW2_agg_chamber
# Storflaket_StorflaketSW3_agg_chamber
# Storflaket_StorflaketSW4_agg_chamber
# Storflaket_StorflaketSW5_agg_chamber
# Storflaket_StorflaketSW6_agg_chamber
# Storflaket_StorflaketSW7_agg_chamber
# Storflaket_StorflaketSW8_agg_chamber
# Storflaket_StorflaketSW9_agg_chamber
# Storflaket_StorflaketWW10_agg_chamber
# Storflaket_StorflaketWW1_agg_chamber
# Storflaket_StorflaketWW2_agg_chamber
# Storflaket_StorflaketWW3_agg_chamber
# Storflaket_StorflaketWW4_agg_chamber
# Storflaket_StorflaketWW5_agg_chamber
# Storflaket_StorflaketWW6_agg_chamber
# Storflaket_StorflaketWW7_agg_chamber
# Storflaket_StorflaketWW8_agg_chamber
# Storflaket_StorflaketWW9_agg_chamber
# Tombstone_slavin_CA-TWOSL_tower
# Toolik Lake_Prudhoe Bay_chamber
# Tourist St._Tourist St.DL1_agg_chamber
# Tourist St._Tourist St.DL2_agg_chamber
# Tourist St._Tourist St.DL3_agg_chamber
# Tourist St._Tourist St.DL4_agg_chamber
# Tourist St._Tourist St.DL5_agg_chamber
# Tourist St._Tourist St.DLS10_agg_chamber
# Tourist St._Tourist St.DLS1_agg_chamber
# Tourist St._Tourist St.DLS2_agg_chamber
# Tourist St._Tourist St.DLS4_agg_chamber
# Tourist St._Tourist St.DLS8_agg_chamber
# Tourist St._Tourist St.DLS9_agg_chamber
# Tourist St._Tourist St.DS1_agg_chamber
# Tourist St._Tourist St.DS2_agg_chamber
# Tourist St._Tourist St.DS3_agg_chamber
# Tourist St._Tourist St.DS4_agg_chamber
# Tourist St._Tourist St.DS5_agg_chamber
# Tourist St._Tourist St.DSS1_agg_chamber
# Tourist St._Tourist St.DSS2_agg_chamber
# Tourist St._Tourist St.DSS3_agg_chamber
# Tourist St._Tourist St.DSS4_agg_chamber
# Tourist St._Tourist St.DSS5_agg_chamber
# Tourist St._Tourist St.PB/DL4_agg_chamber
# Tourist St._Tourist St.PB1_agg_chamber
# Tourist St._Tourist St.PB2_agg_chamber
# Tourist St._Tourist St.PB3_agg_chamber
# Tourist St._Tourist St.PB4_agg_chamber
# Tourist St._Tourist St.PB5_agg_chamber
# Tourist St._Tourist St.PBS/DS3_agg_chamber
# Tourist St._Tourist St.PBS10_agg_chamber
# Tourist St._Tourist St.PBS1_agg_chamber
# Tourist St._Tourist St.PBS2_agg_chamber
# Tourist St._Tourist St.PBS3_agg_chamber
# Tourist St._Tourist St.PBS4_agg_chamber
# Tourist St._Tourist St.PBS5_agg_chamber
# Tourist St._Tourist St.PBS6_agg_chamber
# Tourist St._Tourist St.PBS7_agg_chamber
# Tourist St._Tourist St.PBS8_agg_chamber
# Tourist St._Tourist St.PBS9_agg_chamber
# Tourist St._Tourist St.SE10_agg_chamber
# Tourist St._Tourist St.SE1_agg_chamber
# Tourist St._Tourist St.SE2_agg_chamber
# Tourist St._Tourist St.SE3_agg_chamber
# Tourist St._Tourist St.SE4_agg_chamber
# Tourist St._Tourist St.SE5_agg_chamber
# Tourist St._Tourist St.SE6_agg_chamber
# Tourist St._Tourist St.SE7_agg_chamber
# Tourist St._Tourist St.SE8_agg_chamber
# Tourist St._Tourist St.SE9_agg_chamber
# Tourist St._Tourist St.SW1_agg_chamber
# Tourist St._Tourist St.SW2_agg_chamber
# Tourist St._Tourist St.SW3_agg_chamber
# Tourist St._Tourist St.SW4_agg_chamber
# Tourist St._Tourist St.SW5_agg_chamber
# Tourist St._Tourist St.SW6_agg_chamber
# Tourist St._Tourist St.WW1_agg_chamber
# Tourist St._Tourist St.WW2_agg_chamber
# Tourist St._Tourist St.WW3_agg_chamber
# Tourist St._Tourist St.WW4_agg_chamber
# Tourist St._Tourist St.WW5_agg_chamber
# Tura, Russia_Forest_Floor_Ag_chamber
# Tura_RU-Tur Feathermoss cover_chamber
# Tura_RU-Tur Lichen cover_chamber
# Tura_RU-Tur_tower
# Varrio_FI-Var_tower
# Varrio_Varrio_Fire155_chamber
# Varrio_Varrio_Fire45_chamber
# Varrio_Varrio_Fire5_chamber
# Varrio_Varrio_Fire65_chamber
# Varrio_Varrio_Grazed_chamber
# Varrio_Varrio_non-grazed_chamber
# Wolf_creek_Buckbrush_CA-WCBB_tower
# YKD (burned)_US-YK1_tower
# YKD (unburned)_US-YK2_tower
# YKD_Burned Fen -15B_F1_chamber
# YKD_Burned Fen -15B_F2_chamber
# YKD_Burned Fen -15B_F3_chamber
# YKD_burned degraded plateau -15B_DP1_chamber
# YKD_burned degraded plateau -15B_DP2_chamber
# YKD_burned degraded plateau -15B_DP3_chamber
# YKD_burned shrub edge -15B_S1_chamber
# YKD_burned shrub edge -15B_S2_chamber
# YKD_burned shrub edge -15B_S3_chamber
# YKD_exposed burned soil -15B_X1_chamber
# YKD_exposed burned soil -15B_X2_chamber
# YKD_exposed burned soil -15B_X3_chamber
# YKD_unburned Fen -UB_F1_chamber
# YKD_unburned Fen -UB_F2_chamber
# YKD_unburned Fen -UB_F3_chamber
# YKD_unburned degraded plateau -UB_DP1_chamber
# YKD_unburned degraded plateau -UB_DP2_chamber
# YKD_unburned degraded plateau -UB_DP3_chamber
# YKD_unburned lichen peat plateau -UB_L1_chamber
# YKD_unburned lichen peat plateau -UB_L2_chamber
# YKD_unburned lichen peat plateau -UB_L3_chamber
# YKD_unburned shrub edge -UB_S1_chamber
# YKD_unburned shrub edge -UB_S2_chamber
# YKD_unburned shrub edge -UB_S3_chamber
# Yakutsk Spasskaya Pad Pine_RU-Sk2_tower
# Yakutsk, Russia_Burned_chamber
# Yakutsk, Russia_Control_chamber
# Yakutsk, Russia_Felled_chamber
# Yamal_Peninsula_A_chamber
# Yamal_Peninsula_B_chamber
# Yamal_Peninsula_C_chamber
# Yamal_Peninsula_D_chamber
# Yamal_Peninsula_E_chamber
# Yamal_Peninsula_F_chamber
# Yamal_Peninsula_G_chamber
# Yukon_1969_chamber
# Yukon_1990_chamber
# Yukon_2012_chamber
# Yukon_Control_chamber
# ZOTTO Bog_RU-Zo1_tower
# ZOTTO Forest_RU-Zo2_tower
# Zotino; Central Siberia_RU-Zfw 1_tower
# Zotino; Central Siberia_RU-Zfw 2_tower
# Zotino_RU-Zot_tower
# ARM-NSA-Oliktok_US-A03_tower
# Abisko_Abisko Scientific Research Station_chamber
# Adventdalen, Svalbard_Advent-fen, active low center ice wedge polyons_Other
# Adventdalen, Svalbard_Ch01_chamber
# Adventdalen, Svalbard_Ch02_chamber
# Adventdalen, Svalbard_dry heath_chamber
# Adventdalen, Svalbard_heath shallow_Other
# Adventdalen, Svalbard_meadow shallow_Other
# Adventdalen_Ch01_chamber
# Adventdalen_Ch02_chamber
# Adventdalen_P1_chamber
# Adventdalen_P2_chamber
# Adventdalen_P3_chamber
# Adventdalen_P4_chamber
# Adventdalen_P5_chamber
# Adventdalen_P6_chamber
# Adventdalen_P7_chamber
# Adventdalen_SJ-Adv_tower
# Alaska_soil 5, point A. ALS5AST_chamber
# Alaska_soil 5, point B. ALS5BST_chamber
# Anaktuvuk River Moderate Burn_US-An2_tower
# Anaktuvuk River Severe Burn_US-An1_tower
# Anaktuvuk River Unburned_US-An3_tower
# ArcticCoast_Above Surface_chamber
# ArcticCoast_At Surface_chamber
# ArcticCoast_Below Surface_chamber
# ArcticCoast_Emerging Vegetation_chamber
# ArcticFoothills_Tussock Tundra_chamber
# ArcticFoothills_Wet Meadow_chamber
# Atqasuk_ATQ_pool_chamber
# Atqasuk_ATQ_ridge_inter_tussock_chamber
# Atqasuk_ATQ_ridge_tussock_chamber
# ...
# Kilpisjarvi_chamber_11212_chamber
# Kilpisjarvi_chamber_11213_chamber
# Kilpisjarvi_chamber_11214_chamber
# Kilpisjarvi_chamber_11215_chamber
# Kilpisjarvi_chamber_11216_chamber
# Kilpisjarvi_chamber_11217_chamber
# Kilpisjarvi_chamber_11218_chamber
# Kilpisjarvi_chamber_11219_chamber
# Kilpisjarvi_chamber_11220_chamber
# Kilpisjarvi_chamber_11221_chamber
# Kilpisjarvi_chamber_11222_chamber
# Kilpisjarvi_chamber_11223_chamber
# Kilpisjarvi_chamber_11224_chamber
# Kilpisjarvi_chamber_11225_chamber
# Kilpisjarvi_chamber_1123_chamber
# Kilpisjarvi_chamber_1129_chamber
# Kilpisjarvi_chamber_1135_chamber
# Kilpisjarvi_chamber_1141_chamber
# Kilpisjarvi_chamber_1147_chamber
# Kilpisjarvi_chamber_1159_chamber
# Kilpisjarvi_chamber_115_chamber
# Kilpisjarvi_chamber_12201_chamber
# Kilpisjarvi_chamber_12202_chamber
# Kilpisjarvi_chamber_12203_chamber
# Kilpisjarvi_chamber_12204_chamber
# Kilpisjarvi_chamber_12205_chamber
# Kilpisjarvi_chamber_12206_chamber
# Kilpisjarvi_chamber_12207_chamber
# Kilpisjarvi_chamber_12208_chamber
# Kilpisjarvi_chamber_12209_chamber
# Kilpisjarvi_chamber_12210_chamber
# Kilpisjarvi_chamber_12211_chamber
# Kilpisjarvi_chamber_12212_chamber
# Kilpisjarvi_chamber_12213_chamber
# Kilpisjarvi_chamber_12214_chamber
# Kilpisjarvi_chamber_12215_chamber
# Kilpisjarvi_chamber_12216_chamber
# Kilpisjarvi_chamber_12217_chamber
# Kilpisjarvi_chamber_12218_chamber
# Kilpisjarvi_chamber_12219_chamber
# Kilpisjarvi_chamber_12220_chamber
# Kilpisjarvi_chamber_12221_chamber
# Kilpisjarvi_chamber_12222_chamber
# Kilpisjarvi_chamber_12223_chamber
# Kilpisjarvi_chamber_12224_chamber
# Kilpisjarvi_chamber_181_chamber
# Kilpisjarvi_chamber_187_chamber
# Kilpisjarvi_chamber_193_chamber
# Kilpisjarvi_chamber_199_chamber
# Kilpisjarvi_chamber_19_chamber
# Kilpisjarvi_chamber_241_chamber
# Kilpisjarvi_chamber_247_chamber
# Kilpisjarvi_chamber_253_chamber
# Kilpisjarvi_chamber_259_chamber
# Kilpisjarvi_chamber_25_chamber
# Kilpisjarvi_chamber_265_chamber
# Kilpisjarvi_chamber_271_chamber
# Kilpisjarvi_chamber_277_chamber
# Kilpisjarvi_chamber_31_chamber
# Kilpisjarvi_chamber_325_chamber
# Kilpisjarvi_chamber_331_chamber
# Kilpisjarvi_chamber_349_chamber
# Kilpisjarvi_chamber_355_chamber
# Kilpisjarvi_chamber_367_chamber
# Kilpisjarvi_chamber_37_chamber
# Kilpisjarvi_chamber_388_chamber
# Kilpisjarvi_chamber_403_chamber
# Kilpisjarvi_chamber_409_chamber
# Kilpisjarvi_chamber_415_chamber
# Kilpisjarvi_chamber_421_chamber
# Kilpisjarvi_chamber_427_chamber
# Kilpisjarvi_chamber_433_chamber
# Kilpisjarvi_chamber_439_chamber
# Kilpisjarvi_chamber_445_chamber
# Kilpisjarvi_chamber_481_chamber
# Kilpisjarvi_chamber_487_chamber
# Kilpisjarvi_chamber_493_chamber
# Kilpisjarvi_chamber_499_chamber
# Kilpisjarvi_chamber_505_chamber
# Kilpisjarvi_chamber_511_chamber
# Kilpisjarvi_chamber_517_chamber
# Kilpisjarvi_chamber_523_chamber
# Kilpisjarvi_chamber_565_chamber
# Kilpisjarvi_chamber_571_chamber
# Kilpisjarvi_chamber_577_chamber
# Kilpisjarvi_chamber_583_chamber
# Kilpisjarvi_chamber_589_chamber
# Kilpisjarvi_chamber_595_chamber
# Kilpisjarvi_chamber_607_chamber
# Kilpisjarvi_chamber_643_chamber
# Kilpisjarvi_chamber_649_chamber
# Kilpisjarvi_chamber_655_chamber
# Kilpisjarvi_chamber_661_chamber
# Kilpisjarvi_chamber_667_chamber
# Kilpisjarvi_chamber_679_chamber
# Kilpisjarvi_chamber_721_chamber
# Kilpisjarvi_chamber_727_chamber
# Kilpisjarvi_chamber_733_chamber
# Kilpisjarvi_chamber_739_chamber
# Kilpisjarvi_chamber_745_chamber
# Kilpisjarvi_chamber_751_chamber
# Kilpisjarvi_chamber_757_chamber
# Kilpisjarvi_chamber_805_chamber
# Kilpisjarvi_chamber_811_chamber
# Kilpisjarvi_chamber_817_chamber
# Kilpisjarvi_chamber_823_chamber
# Kilpisjarvi_chamber_829_chamber
# Kilpisjarvi_chamber_835_chamber
# Kilpisjarvi_chamber_889_chamber
# Kilpisjarvi_chamber_895_chamber
# Kilpisjarvi_chamber_901_chamber
# Kilpisjarvi_chamber_907_chamber
# Kilpisjarvi_chamber_913_chamber
# Kilpisjarvi_chamber_919_chamber
# Kilpisjarvi_chamber_91_chamber
# Kilpisjarvi_chamber_961_chamber
# Kilpisjarvi_chamber_967_chamber
# Kilpisjarvi_chamber_973_chamber
# Kilpisjarvi_chamber_979_chamber
# Kilpisjarvi_chamber_97_chamber
# Kilpisjarvi_chamber_985_chamber
# Kuparuk Watershed, North Slope_Coastal Plain_Other
# Kuparuk Watershed, North Slope_Riparian_Other
# Kuparuk Watershed, North Slope_Upland tussock_Other
# Kuparuk Watershed, North Slope_Water track_Other
# Kytalyk, Russia_FD1_chamber
# Kytalyk, Russia_FD2_chamber
# Kytalyk, Russia_FW1_chamber
# Kytalyk, Russia_FW2_chamber
# Kytalyk, Russia_FW3_chamber
# Kytalyk, Russia_FW4_chamber
# Kytalyk, Russia_RU-Cok_tower
# Kytalyk, Russia_TD1_chamber
# Kytalyk, Russia_TD2_chamber
# Kytalyk, Russia_TD3_chamber
# Kytalyk, Russia_TD4_chamber
# Kytalyk, Russia_TW1_chamber
# Kytalyk, Russia_TW2_chamber
# Kytalyk, Russia_TW3_chamber
# Kytalyk, Russia_TW4_chamber
# Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_chamber
# Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower
# Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_chamber
# Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower
# Latnjajaure_heath meadow_Other
# Latnjajaure_heath shallow_Other
# Latnjajaure_heath snowbed_Other
# Latnjajaure_meadow shallow_Other
# Latnjajaure_meadow snowbed_Other
# Latnjajaure_mesic meadow_Other
# Mellemlandet_chamber
# Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower
# NE2 (Toolik)_NE2_chamber
# NEON Barrow Environmental Observatory (BARR)_US-xBA_tower
# NGEE Arctic Barrow_US-NGB_tower
# NGEE Arctic Council_US-NGC_tower
# North Slope_Coastal tundra Ch08_chamber
# North Slope_Subalpine tundra Ch03_chamber
# North Slope_Subalpine tundra Ch06_chamber
# North Slope_Upland tundra Ch03_chamber
# North Slope_Upland tundra Ch07_chamber
# North Slope_moist acidic tundra_Other
# Nuuk Fen_GL-NuF_tower
# Paktajaure_heath_chamber
# Pallas_FI_Pal_T2_P10_E_2019_chamber
# Pallas_FI_Pal_T2_P10_N_2019_chamber
# Pallas_FI_Pal_T2_P10_W_2019_chamber
# Pallas_FI_Pal_T2_P11_E_2019_chamber
# Pallas_FI_Pal_T2_P11_N_2019_chamber
# Pallas_FI_Pal_T2_P11_W_2019_chamber
# Pallas_FI_Pal_T2_P2_E_2019_chamber
# Pallas_FI_Pal_T2_P2_N_2019_chamber
# Pallas_FI_Pal_T2_P2_W_2019_chamber
# Pallas_FI_Pal_T2_P3_E_2019_chamber
# Pallas_FI_Pal_T2_P3_N_2019_chamber
# Pallas_FI_Pal_T2_P3_W_2019_chamber
# Pallas_FI_Pal_T2_P4_E_2019_chamber
# Pallas_FI_Pal_T2_P4_N_2019_chamber
# Pallas_FI_Pal_T2_P4_W_2019_chamber
# Pallas_FI_Pal_T2_P5_E_2019_chamber
# Pallas_FI_Pal_T2_P5_N_2019_chamber
# Pallas_FI_Pal_T2_P5_W_2019_chamber
# Pallas_FI_Pal_T2_P6_E_2019_chamber
# Pallas_FI_Pal_T2_P6_N_2019_chamber
# Pallas_FI_Pal_T2_P6_W_2019_chamber
# Pallas_FI_Pal_T2_P7_E_2019_chamber
# Pallas_FI_Pal_T2_P7_N_2019_chamber
# Pallas_FI_Pal_T2_P7_W_2019_chamber
# Pallas_FI_Pal_T2_P8_E_2019_chamber
# Pallas_FI_Pal_T2_P8_N_2019_chamber
# Pallas_FI_Pal_T2_P8_W_2019_chamber
# Pallas_FI_Pal_T2_P9_E_2019_chamber
# Pallas_FI_Pal_T2_P9_N_2019_chamber
# Pallas_FI_Pal_T2_P9_W_2019_chamber
# Pallas_FI_Pal_T3_P10_E_2019_chamber
# Pallas_FI_Pal_T3_P10_N_2019_chamber
# Pallas_FI_Pal_T3_P10_W_2019_chamber
# Pallas_FI_Pal_T3_P11_E_2019_chamber
# Pallas_FI_Pal_T3_P11_N_2019_chamber
# Pallas_FI_Pal_T3_P11_W_2019_chamber
# Pallas_FI_Pal_T3_P4_E_2019_chamber
# Pallas_FI_Pal_T3_P4_N_2019_chamber
# Pallas_FI_Pal_T3_P4_W_2019_chamber
# Pallas_FI_Pal_T3_P5_E_2019_chamber
# Pallas_FI_Pal_T3_P5_N_2019_chamber
# Pallas_FI_Pal_T3_P5_W_2019_chamber
# Pallas_FI_Pal_T3_P6_E_2019_chamber
# Pallas_FI_Pal_T3_P6_N_2019_chamber
# Pallas_FI_Pal_T3_P6_W_2019_chamber
# Pallas_FI_Pal_T3_P7_E_2019_chamber
# Pallas_FI_Pal_T3_P7_N_2019_chamber
# Pallas_FI_Pal_T3_P7_W_2019_chamber
# Pallas_FI_Pal_T3_P8_E_2019_chamber
# Pallas_FI_Pal_T3_P8_N_2019_chamber
# Pallas_FI_Pal_T3_P8_W_2019_chamber
# Pallas_FI_Pal_T3_P9_E_2019_chamber
# Pallas_FI_Pal_T3_P9_N_2019_chamber
# Pallas_FI_Pal_T3_P9_W_2019_chamber
# Prudhoe Bay_Prudhoe Bay_chamber
# Raisduoddar_Light grazing_chamber
# Raisduoddar_Old grazer-induced grassification_chamber
# Raisduoddar_Recent grazer-induced grassification_chamber
# Resolute Bay Polar Desert_CA-RSB_tower
# Rylekaerene_Cassiope heath 1_chamber
# Rylekaerene_Cassiope heath 2_chamber
# Rylekaerene_Cassiope heath 3_chamber
# Rylekaerene_Cassiope heath 4_chamber
# Rylekaerene_Cassiope heath 5_chamber
# Rylekaerene_Continuous fen 10_chamber
# Rylekaerene_Continuous fen 11_chamber
# Rylekaerene_Continuous fen 12_chamber
# Rylekaerene_Continuous fen 13_chamber
# Rylekaerene_Continuous fen 14_chamber
# Rylekaerene_Continuous fen 15_chamber
# Rylekaerene_Continuous fen 1_chamber
# Rylekaerene_Continuous fen 2_chamber
# Rylekaerene_Continuous fen 3_chamber
# Rylekaerene_Continuous fen 4_chamber
# Rylekaerene_Continuous fen 5_chamber
# Rylekaerene_Continuous fen 6_chamber
# Rylekaerene_Continuous fen 7_chamber
# Rylekaerene_Continuous fen 8_chamber
# Rylekaerene_Continuous fen 9_chamber
# Rylekaerene_Dryas heath 1_chamber
# Rylekaerene_Dryas heath 2_chamber
# Rylekaerene_Dryas heath 3_chamber
# Rylekaerene_Dryas heath 4_chamber
# Rylekaerene_Dryas heath 5_chamber
# Rylekaerene_Grassland 10_chamber
# Rylekaerene_Grassland 1_chamber
# Rylekaerene_Grassland 2_chamber
# Rylekaerene_Grassland 3_chamber
# Rylekaerene_Grassland 4_chamber
# Rylekaerene_Grassland 5_chamber
# Rylekaerene_Grassland 6_chamber
# Rylekaerene_Grassland 7_chamber
# Rylekaerene_Grassland 8_chamber
# Rylekaerene_Grassland 9_chamber
# Rylekaerene_Hummocky fen 10_chamber
# Rylekaerene_Hummocky fen 1_chamber
# Rylekaerene_Hummocky fen 2_chamber
# Rylekaerene_Hummocky fen 3_chamber
# Rylekaerene_Hummocky fen 4_chamber
# Rylekaerene_Hummocky fen 5_chamber
# Rylekaerene_Hummocky fen 6_chamber
# Rylekaerene_Hummocky fen 7_chamber
# Rylekaerene_Hummocky fen 8_chamber
# Rylekaerene_Hummocky fen 9_chamber
# Rylekaerene_Salix snowbed 1_chamber
# Rylekaerene_Salix snowbed 2_chamber
# Rylekaerene_Salix snowbed 3_chamber
# Rylekaerene_Salix snowbed 4_chamber
# Rylekaerene_Salix snowbed 5_chamber
# Rylekaerene_Vaccinium heath 1_chamber
# Rylekaerene_Vaccinium heath 2_chamber
# Rylekaerene_Vaccinium heath 3_chamber
# Rylekaerene_Vaccinium heath 4_chamber
# Rylekaerene_Vaccinium heath 5_chamber
# Rylekaerene_tower
# Sag River_Shrub_Other
# Sag River_US-Sag_tower
# Schefferville_Poor fen_chamber
# Schefferville_Ribbed fen- flark_chamber
# Schefferville_Ribbed fen- pool_chamber
# Schefferville_Ribbed fen- string_chamber
# Schefferville_Rich fen_chamber
# Skarvefjeld_chamber
# South Brooks Range_Tundra-boreal ecotone Ch02_chamber
# South Brooks Range_Tundra-boreal ecotone Ch05_chamber
# Stordalen Mire_Eriophorum Site_chamber
# Stordalen Mire_Palsa Site_chamber
# Stordalen Mire_Sphagnum Site_chamber
# Stordalen, Sweden_Stordalen_tower
# Stordalen_A_chamber
# Stordalen_B_chamber
# Thule_Thule chambers aggregated_chamber
# Tiksi_RU-Tks_tower
# Toolik Lake- Long-term US ITEX_CTL-C1_chamber
# Toolik Lake- Long-term US ITEX_CTL-C2_chamber
# Toolik Lake- Long-term US ITEX_CTL-C3_chamber
# Toolik Lake- Long-term US ITEX_CTL-C4_chamber
# Toolik Lake- Long-term US ITEX_CTL-C5_chamber
# Toolik Lake_Cassiope_Other
# Toolik Lake_Heath_Other
# Toolik Lake_Riparian_Other
# Toolik Lake_Snow drifts_Other
# Toolik Lake_Tussock_Other
# Toolik Lake_dry heath tundra_Other
# Toolik Lake_dwarf birch tundra_Other
# Toolik Lake_heath_Other
# Toolik Lake_riparian willow tundra_Other
# Toolik Lake_tussock tundra_Other
# Toolik Lake_wet sedge tundra_Other
# Toolik Moist Tussock Tundra_Carex meadows_chamber
# Toolik Moist Tussock Tundra_grazing lawn_chamber
# Toolik Moist Tussock Tundra_pond margin_chamber
# Toolik Moist Tussock Tundra_slough levee_chamber
# Toolik_1_chamber
# Toolik_2_chamber
# Toolik_Control_chamber
# Toolik_Toolik_chamber
# Toolik_average of inlet and outlet_chamber
# Trail Valley Creek (CA-TVC)_PC (Polygon Center)_chamber
# Trail Valley Creek (CA-TVC)_PR (Polygon Rim)_chamber
# Trail Valley Creek (CA-TVC)_PT (Polygon Trough)_chamber
# Trail Valley Creek (CA-TVC)_TL (Lichen) Automatic Chamber_chamber
# Trail Valley Creek (CA-TVC)_TL (Lichen)_chamber
# Trail Valley Creek (CA-TVC)_TS (Shrub) Automatic Chamber_chamber
# Trail Valley Creek (CA-TVC)_TS (Shrub)_chamber
# Trail Valley Creek (CA-TVC)_TT (Tussock) Automatic Chamber_chamber
# Trail Valley Creek (CA-TVC)_TT (Tussock)_chamber
# Trail Valley Creek (CA-TVC)_WL (wetland/thermokarst)_chamber
# Trail Valley Creek_CA-TVC_tower
# Trail_Valley_Creek_DS01_SnowDiffusion
# Trail_Valley_Creek_DS02_SnowDiffusion
# Trail_Valley_Creek_DS03_SnowDiffusion
# Trail_Valley_Creek_DS04_SnowDiffusion
# Trail_Valley_Creek_DS05_SnowDiffusion
# Trail_Valley_Creek_LC01_SnowDiffusion
# Trail_Valley_Creek_LC02_SnowDiffusion
# Trail_Valley_Creek_LC03_SnowDiffusion
# Trail_Valley_Creek_LC04_SnowDiffusion
# Trail_Valley_Creek_POLY01_SnowDiffusion
# Trail_Valley_Creek_POLY02_SnowDiffusion
# Trail_Valley_Creek_POLY03_SnowDiffusion
# Trail_Valley_Creek_RS01_SnowDiffusion
# Trail_Valley_Creek_RS02_SnowDiffusion
# Trail_Valley_Creek_TK01_SnowDiffusion
# Trail_Valley_Creek_TK02_SnowDiffusion
# Trail_Valley_Creek_TK03_SnowDiffusion
# Trail_Valley_Creek_TK04_SnowDiffusion
# Trail_Valley_Creek_TK05_SnowDiffusion
# Trail_Valley_Creek_TR01_SnowDiffusion
# Trail_Valley_Creek_TR02_SnowDiffusion
# Trail_Valley_Creek_TR03_SnowDiffusion
# Trail_Valley_Creek_TS01_SnowDiffusion
# Trail_Valley_Creek_TS02_SnowDiffusion
# Trail_Valley_Creek_TS03_SnowDiffusion
# Trail_Valley_Creek_TS04_SnowDiffusion
# Trail_Valley_Creek_TS05_SnowDiffusion
# Trail_Valley_Creek_TS06_SnowDiffusion
# Trail_Valley_Creek_TVC01_SnowDiffusion
# Trail_Valley_Creek_TVC02_SnowDiffusion
# Trail_Valley_Creek_TVC03_SnowDiffusion
# Trail_Valley_Creek_TVC04_SnowDiffusion
# Trail_Valley_Creek_TVC05_SnowDiffusion
# Trail_Valley_Creek_TVC06_SnowDiffusion
# U-PAD_Prudhoe Bay_chamber
# U-PAD_moist sedge_chamber
# U-PAD_wet sedge_chamber
# Umiujaq_tower
# Vaisjeaggi, northern Finland_subarctic palsa mire_chamber
# Vassijaure_heath_chamber
# Vuoskojaiveh_heath_chamber
# West Dock_Prudhoe Bay_chamber
# Wolf_creek_SparseShrub_CA-WCPLT_tower
# Wolf_creek_upper_forest_CA-WCUF_tower
# Yukon-Kuskokwim Delta_Tutakoke River_chamber
# Zackenberg Fen_GL-ZaF_chamber
# Zackenberg Fen_GL-ZaF_tower
# Zackenberg Heath_GL-ZaH_tower
# Zackenberg_Cassiope heath; NY-ITEX heath_chamber
# Zackenberg_Salix heath; NY-ITEX heath_chamber
# Zackenberg_chamber
# Zackenberg_dry heath_chamber
# Zackenberg_fen_Other
# nan
# Zackenberg_fen_chamber
# ARM-NSA-Barrow_US-A10_tower
# Barrow-CMDL_US-Brw_tower
# Barrow_BES_chamber
# Bayelva, Spitsbergen_SJ-Blv_tower
# Cambride_Bay_RP02_SnowDiffusion
# Central Marsh_US-Cms_tower
# Endalen, Svalbard_Dry Dryas heath_chamber
# Endalen, Svalbard_Moist Cassiope heath_chamber
# Endalen, Svalbard_Salix snow bed_chamber
# Finse west_NO-Fns_tower
# IBP-II_chamber
# Latnjajaure_dry heath Ctr 1_chamber
# Latnjajaure_dry heath Ctr 2_chamber
# Latnjajaure_dry heath Ctr 3_chamber
# Latnjajaure_dry heath Ctr 4_chamber
# Latnjajaure_dry heath Ctr 5A_chamber
# Latnjajaure_dry heath Ctr 5_chamber
# Latnjajaure_dry meadow Ctr 1_chamber
# Latnjajaure_dry meadow Ctr 2_chamber
# Latnjajaure_dry meadow Ctr 3_chamber
# Latnjajaure_dry meadow Ctr 4_chamber
# Latnjajaure_dry meadow Ctr 5_chamber
# Latnjajaure_mesic meadow Ctr 10_chamber
# Latnjajaure_mesic meadow Ctr 1_chamber
# Latnjajaure_mesic meadow Ctr 6_chamber
# Latnjajaure_mesic meadow Ctr 7_chamber
# Latnjajaure_mesic meadow Ctr 9_chamber
# Latnjajaure_wet meadow Ctr 1_chamber
# Latnjajaure_wet meadow Ctr 2_chamber
# Latnjajaure_wet meadow Ctr 3_chamber
# Latnjajaure_wet meadow Ctr 4_chamber
# Latnjajaure_wet meadow Ctr 5_chamber
# Nyalesund, Spitzbergen_Bare soil_chamber
# Nyalesund, Spitzbergen_Carex spp._chamber
# Nyalesund, Spitzbergen_Dryas octopetala_chamber
# Nyalesund, Spitzbergen_Mixed vegetation_chamber
# Nyalesund, Spitzbergen_Non vascular_chamber
# Nyalesund, Spitzbergen_Salix Polaris_chamber
# Nyalesund, Spitzbergen_Saxifraga oppostifolia_chamber
# Nyalesund, Spitzbergen_Silene acaulis_chamber
# Spitsbergen_Dark Chamber_chamber
# Utqiagvik Central_Central_chamber
# Utqiagvik North_North_chamber
# Utqiagvik South_South_chamber
# Utqiagvik_Intermediate_chamber
# Utqiagvik_Polygon Rim_chamber
# Utqiagvik_Utqiagvik plots aggregated_chamber
# Utqiagvik_Vascular-dominated_chamber
# Utqiagvik_wet sedge tundra_chamber
# Abisko Scientific Research Station_inner circle_chamber
# Abisko Scientific Research Station_outer circle_chamber
# Abisko Scientific Research Station_transition circle_chamber
# CBAWO wet sedge_chamber
# Latnjajaure_tussock tundra Ctr 1_chamber
# Latnjajaure_tussock tundra Ctr 2_chamber
# Latnjajaure_tussock tundra Ctr 3_chamber
# Latnjajaure_tussock tundra Ctr 4_chamber
# Latnjajaure_tussock tundra Ctr 5_chamber
# Svalbard_Bjornedalen_chamber
# Disko Island, West Greenland_Bare_chamber
# Disko Island, West Greenland_Heath_chamber
# Kolyma River Floodplain_Kolyma_chamber
# Tiksi_TD_chamber
# Tiksi_TW_chamber
