# %%
import os
import pandas as pd
from PIL import Image
import warnings

# Suppress specific PIL warnings if they appear
warnings.filterwarnings("ignore", message="Possibly corrupt EXIF data. ")

def combine_and_save_plots(target_col):
    """
    Finds existing CatBoost and SVM plots for each site,
    combines them side-by-side, and saves a new image.
    """
    # --- 1. Define Paths ---
    base_path = "/explore/nobackup/people/spotter5/anna_v/v2/loocv"
    
    # Paths to the existing, individual plot directories
    catboost_figures_path = os.path.join(base_path, target_col, "figures")
    svm_figures_path = os.path.join(base_path, target_col, "figures_svm_top_features")
    
    # Path for the new combined output images
    comparison_output_path = os.path.join(base_path, target_col, "figures", "svm_v_cat_combined")
    os.makedirs(comparison_output_path, exist_ok=True)

    print(f"\n--- Processing Target: {target_col.upper()} ---")
    print(f"Reading images from: {catboost_figures_path} and {svm_figures_path}")

    # --- 2. Find all unique sites from the filenames ---
    try:
        # Get a list of all catboost plot files
        cb_files = os.listdir(catboost_figures_path)
    except FileNotFoundError:
        print(f"❌ Error: Directory not found: {catboost_figures_path}. Skipping.")
        return

    # Extract site names (assuming format 'model_target_sitename_...png')
    sites = []
    for f in cb_files:
        if f.startswith(f'catboost_{target_col}_') and f.endswith('.png'):
            # Split the filename and extract the site part
            try:
                site_name = f.split(f'catboost_{target_col}_')[1].split('_timeseries_cat.png')[0]
                sites.append(site_name)
            except IndexError:
                continue # Skip files that don't match the expected format
    
    if not sites:
        print("No site plots found to combine.")
        return
        
    print(f"Found {len(sites)} unique sites. Combining images...")

    # --- 3. Loop, Combine, and Save ---
    for site in sites:
        # Define the full paths to the two images to be combined
        catboost_img_path = os.path.join(catboost_figures_path, f'catboost_{target_col}_{site}_timeseries_cat.png')
        svm_img_path = os.path.join(svm_figures_path, f'svm_{target_col}_{site}_timeseries_top_features.png')

        try:
            # Open the two images
            img_cb = Image.open(catboost_img_path)
            img_svm = Image.open(svm_img_path)

            # Get dimensions
            width_cb, height_cb = img_cb.size
            width_svm, height_svm = img_svm.size

            # Create a new blank canvas (width = sum of both, height = max of both)
            new_width = width_cb + width_svm
            new_height = max(height_cb, height_svm)
            combined_image = Image.new('RGB', (new_width, new_height), 'white')

            # Paste the CatBoost image on the left
            combined_image.paste(img_cb, (0, 0))
            # Paste the SVM image on the right
            combined_image.paste(img_svm, (width_cb, 0))
            
            # Define the output path for the new combined image
            output_filename = f'comparison_{target_col}_{site}.png'
            output_path = os.path.join(comparison_output_path, output_filename)
            
            # Save the new image
            combined_image.save(output_path)
            print(f"  - Saved combined plot for site: {site}")

        except FileNotFoundError as e:
            print(f"  - ❌ Skipping site '{site}': Missing one or both image files. Details: {e.filename}")
        except Exception as e:
            print(f"  - ❌ An error occurred for site '{site}': {e}")
            
    print(f"\n✅ Combination complete for '{target_col}'. Plots saved to: {comparison_output_path}")


if __name__ == '__main__':
    # List of target variables to run the analysis for
    targets_to_run = ['nee', 'gpp', 'reco', 'ch4_flux_total']

    for target in targets_to_run:
        combine_and_save_plots(target_col=target)
# Out:
# --- Processing Target: NEE ---
# Reading images from: /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures and /explore/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features
# Found 555 unique sites. Combining images...
#   - ❌ Skipping site 'Fyodorovskoye_RU-Fyo_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Fyodorovskoye_RU-Fyo_tower_timeseries_top_features.png
#   - Saved combined plot for site: Saskatchewan - Western Boreal, Mature Aspen_CA-Oas_tower
#   - ❌ Skipping site 'Hyytiala_FI-Hyy_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Hyytiala_FI-Hyy_tower_timeseries_top_features.png
#   - Saved combined plot for site: Manitoba - Northern Old Black Spruce (former BOREAS Northern Study Area)_CA-Man_tower
#   - Saved combined plot for site: Saskatchewan - Western Boreal, Mature Black Spruce_CA-Obs_tower
#   - Saved combined plot for site: Kaamanen_FI-Kaa_tower
#   - Saved combined plot for site: Nelegel_RU-Nel_tower
#   - ❌ Skipping site 'Neleger Burnt Forest_RU-NeB_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Neleger Burnt Forest_RU-NeB_tower_timeseries_top_features.png
#   - Saved combined plot for site: Neleger larch forest_RU-NeF_tower
#   - Saved combined plot for site: Central Marsh_US-Cms_tower
#   - ❌ Skipping site 'Zotino; Central Siberia_RU-Zfw 2_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Zotino; Central Siberia_RU-Zfw 2_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Degero_SE-Deg_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Degero_SE-Deg_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Flakaliden_SE-Fla_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Flakaliden_SE-Fla_tower_timeseries_top_features.png
#   - Saved combined plot for site: Sodankyla_FI-Sod_tower
#   - Saved combined plot for site: UCI-1964 burn site_CA-NS3_tower
#   - Saved combined plot for site: Neleger Cutover_RU-NeC_tower
#   - Saved combined plot for site: Saskatchewan - Western Boreal, forest burned in 1998_CA-SF3_tower
#   - Saved combined plot for site: Saskatchewan - Western Boreal, forest burned in 1989_CA-SF2_tower
#   - Saved combined plot for site: UCI-1930 burn site_CA-NS2_tower
#   - Saved combined plot for site: UCI-1981 burn site_CA-NS5_tower
#   - Saved combined plot for site: UCI-1989 burn site_CA-NS6_tower
#   - Saved combined plot for site: Delta Junction deciduous broadleaf forest_US-Bn1_tower
#   - Saved combined plot for site: Samoylov Island_RU-Sam_tower
#   - Saved combined plot for site: Zotino_RU-Zot_tower
#   - Saved combined plot for site: UCI-1998 burn site_CA-NS7_tower
#   - Saved combined plot for site: UCI-1850 burn site_CA-NS1_tower
#   - Saved combined plot for site: Hakasia 5yr_RU-Ha2_tower
#   - Saved combined plot for site: Hakasia Steppe_RU-Ha1_tower
#   - Saved combined plot for site: UCI-1964 burn site wet_CA-NS4_tower
#   - Saved combined plot for site: Delta Junction  evergreen conifer forest_US-Bn2_tower
#   - Saved combined plot for site: Kherlenbayan Ulaan_MN-Kbu_tower
#   - Saved combined plot for site: Southern Khentei Taiga_MN-Skt_tower
#   - Saved combined plot for site: University of Alaska, Fairbanks_US-Uaf_tower
#   - Saved combined plot for site: Kytalyk, Russia_RU-Cok_tower
#   - ❌ Skipping site 'Ontario - Groundhog River, Boreal Mixedwood Forest_CA-Gro_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_
tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Lac Le Caron peatland, an ombrotrophic bog_CA-LLC_tower_timeseries_top_features.png
#   - Saved combined plot for site: Anaktuvuk River Moderate Burn_US-An2_tower
#   - Saved combined plot for site: Anaktuvuk River Severe Burn_US-An1_tower
#   - Saved combined plot for site: Anaktuvuk River Unburned_US-An3_tower
#   - Saved combined plot for site: Cape Bounty_CA-CB_tower
#   - Saved combined plot for site: Nuuk Fen_GL-NuF_tower
#   - Saved combined plot for site: Rylekaerene_tower
#   - Saved combined plot for site: Seida_RU-Vrk_tower
#   - Saved combined plot for site: Zackenberg Fen_GL-ZaF_tower
#   - Saved combined plot for site: Andoya_NO-And_tower
#   - Saved combined plot for site: Bayelva, Spitsbergen_SJ-Blv_tower
#   - Saved combined plot for site: Iqaluit_CA-Iqa_tower
#   - Saved combined plot for site: Pond Inlet_CA-Pin_tower
#   - Saved combined plot for site: Poker Flat Research Range: Succession from fire scar to deciduous forest_US-Rpf_tower
#   - ❌ Skipping site 'Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Lake Hazen, Ellesmere Island_CA-LHazen1-semidesert_tower_timeseries_top_features.png
#   - Saved combined plot for site: Samoylov Island_RU-Sam (open)_tower
#   - ❌ Skipping site 'Lettosuo_FI-Let_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Lettosuo_FI-Let_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Siikaneva_FI-Sii_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Siikaneva_FI-Sii_tower_timeseries_top_features.png
#   - Saved combined plot for site: Udleg practice forest_MN-Udg_tower
#   - Saved combined plot for site: Daring Lake_CA-DL3_tower
#   - Saved combined plot for site: Elgeeii forest station_RU-Ege_tower
#   - Saved combined plot for site: Bonanza Creek Black Spruce_US-BZS_tower
#   - Saved combined plot for site: Daring Lake_CA-DL4_tower
#   - Saved combined plot for site: Tiksi_RU-Tks_tower
#   - Saved combined plot for site: Samoylov Island_RU-Sam (closed)_tower
#   - ❌ Skipping site 'Attawapiskat River Fen_CA-ARF_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Attawapiskat River Fen_CA-ARF_tower_timeseries_top_features.png
#   - Saved combined plot for site: Bonanza Creek Thermokarst Bog_US-BZB_tower
#   - Saved combined plot for site: Poker Flat Research Range Black Spruce Forest_US-Prr_tower
#   - ❌ Skipping site 'Attawapiskat River Bog_CA-ARB_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Attawapiskat River Bog_CA-ARB_tower_timeseries_top_features.png
#   - Saved combined plot for site: Bonanza Creek Rich Fen_US-BZF_tower
#   - Saved combined plot for site: Cascaden Ridge Fire Scar_US-Fcr_tower
#   - Saved combined plot for site: Lake Hazen, Ellesmere Island_CA-LHazen2-meadow wetland_tower
#   - ❌ Skipping site 'Siikaneva2_FI-Si2_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Siikaneva2_FI-Si2_tower_timeseries_top_features.png
#   - Saved combined plot for site: Cherskii ecotone_RU-Eusk_cher1_tower
#   - Saved combined plot for site: Kenttarova_FI-Ken_tower
#   - Saved combined plot for site: Lompolojankka_FI-Lom_tower
#   - Saved combined plot for site: Sammaltunturi fell_FI-SamFell_tower
#   - Saved combined plot for site: ARM-NSA-Barrow_US-A10_tower
#   - Saved combined plot for site: Adventdalen_SJ-Adv_tower
#   - Saved combined plot for site: Stordalen Fen_SE-St1_tower
#   - ❌ Skipping site 'Tervalamminsuo_Dry_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Tervalamminsuo_Dry_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Tervalamminsuo_Wet_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Tervalamminsuo_Wet_tower_timeseries_top_features.png
#   - Saved combined plot for site: NGEE Arctic Barrow_US-NGB_tower
#   - Saved combined plot for site: Cherskii disturbed forest_RU-Eusk_cher2_tower
#   - Saved combined plot for site: Disko_GL-Dsk_tower
#   - Saved combined plot for site: Havikpak Creek_CA-HPC_tower
#   - Saved combined plot for site: Scotty Creek Landscape_CA-SCC_tower
#   - Saved combined plot for site: ZOTTO Bog_RU-Zo1_tower
#   - Saved combined plot for site: ZOTTO Forest_RU-Zo2_tower
#   - Saved combined plot for site: Trail Valley Creek_CA-TVC_tower
#   - Saved combined plot for site: Cherskii reference_RU-Ch2_tower
#   - Saved combined plot for site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 1_US-Fo1_tower
#   - Saved combined plot for site: Barrow-CMDL_US-Brw_tower
#   - ❌ Skipping site 'Norunda_SE-Nor_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Norunda_SE-Nor_tower_timeseries_top_features.png
#   - Saved combined plot for site: Varrio_FI-Var_tower
#   - ❌ Skipping site 'Svartberget_SE-Svb_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Svartberget_SE-Svb_tower_timeseries_top_features.png
#   - Saved combined plot for site: Scotty Creek Bog_CA-SCB_tower
#   - Saved combined plot for site: Stordalen Palsa Bog_SE-Sto_tower
#   - Saved combined plot for site: Barrow-BEO_US-Beo_tower
#   - Saved combined plot for site: Council, Alaska_US-KOC_tower
#   - ❌ Skipping site 'Rosinedal-3_SE-Ros_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Rosinedal-3_SE-Ros_tower_timeseries_top_features.png
#   - ❌ Skipping site 'ARM-NSA-Oliktok_US-A03_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_ARM-NSA-Oliktok_US-A03_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Hyltemossa_SE-Htm_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Hyltemossa_SE-Htm_tower_timeseries_top_features.png
#   - Saved combined plot for site: Bibai bog_JP-Bby_tower
#   - ❌ Skipping site 'Fyodorovskoye2_RU-Fy2_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Fyodorovskoye2_RU-Fy2_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Mukhrino_Mukhrino_RHC_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Mukhrino_Mukhrino_RHC_tower_timeseries_top_features.png
#   - Saved combined plot for site: Nalaikh grassland_MN-Nkh_tower
#   - Saved combined plot for site: Wolf_creek_Buckbrush_CA-WCBB_tower
#   - Saved combined plot for site: Wolf_creek_SparseShrub_CA-WCPLT_tower
#   - Saved combined plot for site: Hustai grassland_MN-Hst_tower
#   - Saved combined plot for site: Wolf_creek_forest_CA-WCF_tower
#   - Saved combined plot for site: Umiujaq_tower
#   - Saved combined plot for site: Fish Island_FI-NWT_tower
#   - Saved combined plot for site: Smith Creek_CA-SMC_tower
#   - Saved combined plot for site: NGEE Arctic Council_US-NGC_tower
#   - Saved combined plot for site: NEON Delta Junction (DEJU)_US-xDJ_tower
#   - Saved combined plot for site: Bonanza Creek Old Thermokarst Bog_US-BZo_tower
#   - Saved combined plot for site: NEON Caribou Creek - Poker Flats Watershed (BONA)_US-xBN_tower
#   - Saved combined plot for site: NEON Healy (HEAL)_US-xHE_tower
#   - ❌ Skipping site 'Bouleau peatland_CA-BOU_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Bouleau peatland_CA-BOU_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Bernard spruce-moss valley_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Bernard spruce-moss valley_tower_timeseries_top_features.png
#   - Saved combined plot for site: Iskoras_NO-Isk-fen_tower
#   - Saved combined plot for site: Iskoras_NO-Isk-palsa_tower
#   - Saved combined plot for site: Iskoras_NO-Isk_tower
#   - ❌ Skipping site 'Finse west_NO-Fns_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Finse west_NO-Fns_tower_timeseries_top_features.png
#   - Saved combined plot for site: NEON Barrow Environmental Observatory (BARR)_US-xBA_tower
#   - Saved combined plot for site: YKD (unburned)_US-YK2_tower
#   - ❌ Skipping site 'Ljusdal_HY_HY_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Ljusdal_HY_HY_tower_timeseries_top_features.png
#   - Saved combined plot for site: YKD (burned)_US-YK1_tower
#   - ❌ Skipping site 'Ranskalankorpi_FI-Ran forestry treatment_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Ranskalankorpi_FI-Ran forestry treatment_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Ranskalankorpi_FI-Ran_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Ranskalankorpi_FI-Ran_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Stortjarn_SE-Srj_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Stortjarn_SE-Srj_tower_timeseries_top_features.png
#   - Saved combined plot for site: Wolf_creek_upper_forest_CA-WCUF_tower
#   - ❌ Skipping site 'Halmyran_SE-Hmr_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Halmyran_SE-Hmr_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Halsingfors mire_SE-HfM_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Halsingfors mire_SE-HfM_tower_timeseries_top_features.png
#   - Saved combined plot for site: Tombstone_slavin_CA-TWOSL_tower
#   - ❌ Skipping site 'Ljusdal_SLM_SLM_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Ljusdal_SLM_SLM_tower_timeseries_top_features.png
#   - Saved combined plot for site: Steen River_CA-STR_tower
#   - Saved combined plot for site: Lily Lake Fen_US-KPL_tower
#   - Saved combined plot for site: Abisko Stordalen birch forest_tower
#   - Saved combined plot for site: North Star Yedoma_US-NSY_tower
#   - Saved combined plot for site: Tura_RU-Tur_tower
#   - Saved combined plot for site: Lutose_CA-LUT_tower
#   - ❌ Skipping site 'Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Mukhrino field station, Khanty-Mansiysk, Russia_RU-Muh_tower_timeseries_top_features.png
#   - Saved combined plot for site: Plotnikovo field station, Tomsk, Rusia_RU-Plt_tower
#   - Saved combined plot for site: Cambridge Bay - Mesic_CB-mesic_tower
#   - Saved combined plot for site: Igarka_RU-Iga_tower
#   - Saved combined plot for site: Iqaluit Tundra_CA-IQ1_tower
#   - Saved combined plot for site: Churchill Fen 3_CA-CF3_tower
#   - ❌ Skipping site 'Pitsalu_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Pitsalu_tower_timeseries_top_features.png
#   - Saved combined plot for site: Flux Observations of Carbon from an Airborne Laboratory (FOCAL) Campaign Site 2_US-Fo2_tower
#   - Saved combined plot for site: Mittimatalik (Pond Inlet) Tundra_CA-Mtk_tower
#   - Saved combined plot for site: Resolute Bay Polar Desert_CA-RSB_tower
#   - Saved combined plot for site: Council Alaska Tundra_US-CAK_tower
#   - ❌ Skipping site 'Zotino; Central Siberia_RU-Zfw 1_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Zotino; Central Siberia_RU-Zfw 1_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Gunnarsholt_IS-Gun_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Gunnarsholt_IS-Gun_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Happy Valley_US-HVa_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Happy Valley_US-HVa_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Happy Valley Wet Sedge Tundra_US-HVs_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_Happy Valley Wet Sedge Tundra_US-HVs_tower_timeseries_top_features.png
#   - ❌ Skipping site 'Sag River_US-Sag_tower': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/nee/figures_svm_top_features/svm_nee_
tower_timeseries_weighted.png': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/ch4_flux_total/figures/catboost_ch4_flux_total_Sag River_US-Sag_tower_timeseries_weighted.png_timeseries_cat.png
#   - ❌ Skipping site 'Stordalen, Sweden_Stordalen_tower_timeseries_weighted.png': Missing one or both image files. Details: /panfs/ccds02/nobackup/people/spotter5/anna_v/v2/loocv/ch4_flux_total/figures/catboost_ch4_flux_total_Stordalen, Sweden_Stordalen_tower_timeseries_weighted.png_timeseries_cat.png
#
# ✅ Combination complete for 'ch4_flux_total'. Plots saved to: /explore/nobackup/people/spotter5/anna_v/v2/loocv/ch4_flux_total/figures/svm_v_cat_combined

# %%
import os
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Suppress warnings
os.environ['PYTHONWARNINGS'] = 'ignore::FutureWarning'
warnings.filterwarnings("ignore", category=FutureWarning)

def run_loso_analysis(target_col):
    """
    Performs a full Leave-One-Site-Out (LOSO) cross-validation for a given target variable.
    """
    print(f"--- Processing Target: {target_col.upper()} ---")
    file_path = "/explore/nobackup/people/spotter5/anna_v/v2/v2_model_training_final.csv"
    df = pd.read_csv(file_path)
    df['land_cover'] = df['land_cover'].astype(int)
    df['month'] = df['month'].astype(int)
    df = df[df['flux_method'] == 'EC']

    df['tmean_C'] = df[['tmmn', 'tmmx']].mean(axis=1)
    df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))

    feature_cols = [
        'EVI', 'NDVI', 'sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03',
        'sur_refl_b07', 'NDWI', 'pdsi', 'srad', 'tmean_C', 'vap', 'vs',
        'bdod_0_100cm', 'cec_0_100cm', 'cfvo_0_100cm', 'clay_0_100cm',
        'nitrogen_0_100cm', 'ocd_0_100cm', 'phh2o_0_100cm', 'sand_0_100cm',
        'silt_0_100cm', 'soc_0_100cm', 'co2_cont', 'ALT',
        'land_cover', 'month',
        'lai', 'fpar', 'Percent_NonTree_Vegetation',
        'Percent_NonVegetated', 'Percent_Tree_Cover'
    ]
    categorical_features = ['land_cover', 'month']
    df = df.dropna(subset=['site_reference', target_col])

    loocv_out_path = os.path.join("/explore/nobackup/people/spotter5/anna_v/v2/loocv", target_col)
    figures_path = os.path.join(loocv_out_path, "figures")
    models_out_path = '/explore/nobackup/people/spotter5/anna_v/v2/models'
    os.makedirs(loocv_out_path, exist_ok=True)
    os.makedirs(figures_path, exist_ok=True)
    os.makedirs(models_out_path, exist_ok=True)

    X = df[feature_cols].copy()
    y = df[target_col]
    sites = df["site_reference"].unique()

    for col in categorical_features:
        X[col] = X[col].astype('category')

    results = []
    all_preds_df_list = []

    for test_site in sites:
        print(f"  Processing site: {test_site}...")
        train_idx = df["site_reference"] != test_site
        test_idx = df["site_reference"] == test_site

        if test_idx.sum() < 1:
            continue

        X_train, y_train = X.loc[train_idx], y.loc[train_idx]
        X_test, y_test = X.loc[test_idx], y.loc[test_idx]
        dates_test = df.loc[test_idx, "date"]

        # Using CatBoost's native parameter 'rsm' (alias for colsample_bytree)
        model = CatBoostRegressor(
            iterations=1200,
            learning_rate=0.01,
            depth=8,
            subsample=0.7,
            random_state=42,
            l2_leaf_reg=0.1,
            rsm=0.8, # Correct native parameter for CatBoost
            cat_features=categorical_features,
            verbose=0,
            allow_writing_files=False
        )
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        site_df = pd.DataFrame({"Site": test_site, "Date": dates_test.values, "Observed": y_test.values, "Predicted": y_pred})
        all_preds_df_list.append(site_df)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        results.append({"Site": test_site, "RMSE": rmse, "MAE": mae, "R2": r2})

    if not results:
        print(f"No data processed for target '{target_col}'. Skipping.")
        return

    results_df = pd.DataFrame(results)
    all_preds_df = pd.concat(all_preds_df_list, ignore_index=True)

    results_csv_path = os.path.join(loocv_out_path, f'catboost_results_{target_col}_cat.csv')
    predictions_csv_path = os.path.join(loocv_out_path, f'catboost_predictions_{target_col}_cat.csv')
    results_df.to_csv(results_csv_path, index=False)
    all_preds_df.to_csv(predictions_csv_path, index=False)
    print(f"\n  Results saved to: {results_csv_path}")

    rmse_all = np.sqrt(mean_squared_error(all_preds_df["Observed"], all_preds_df["Predicted"]))
    r2_all = r2_score(all_preds_df["Observed"], all_preds_df["Predicted"])
    mae_all = mean_absolute_error(all_preds_df["Observed"], all_preds_df["Predicted"])
    print(f"\n  --- Pooled Metrics for {target_col.upper()} ---")
    print(f"  Pooled R²: {r2_all:.4f}, Pooled RMSE: {rmse_all:.4f}, Pooled MAE: {mae_all:.4f}")

    print("\n  Generating and saving individual site plots...")
    for site in all_preds_df["Site"].unique():
        fig, ax = plt.subplots(figsize=(12, 7))
        site_df = all_preds_df[all_preds_df["Site"] == site].sort_values("Date")
        site_metrics = results_df[results_df["Site"] == site].iloc[0]

        ax.plot(site_df["Date"], site_df["Observed"], label="Observed", marker="o", linestyle='-', markersize=4)
        ax.plot(site_df["Date"], site_df["Predicted"], label="Predicted", marker="x", linestyle='--', markersize=4)
        ax.set_title(f"Observed vs. Predicted {target_col} for Site: {site}")
        ax.legend(), ax.grid(True), fig.autofmt_xdate()

        textstr = f"RMSE: {site_metrics['RMSE']:.2f}\nMAE: {site_metrics['MAE']:.2f}\nR²: {site_metrics['R2']:.2f}"
        ax.text(0.97, 0.03, textstr, transform=ax.transAxes, fontsize=10,
                verticalalignment='bottom', horizontalalignment='right',
                bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.7))

        plot_filename = f'catboost_{target_col}_{site}_timeseries_cat.png'
        plot_path = os.path.join(figures_path, plot_filename)
        plt.savefig(plot_path, dpi=300, bbox_inches='tight')
        plt.close(fig)
    print(f"  All site plots saved to: {figures_path}")

    print("\n  Training and saving final model on all data...")
    final_model = CatBoostRegressor(
        iterations=1200, learning_rate=0.01, depth=8, subsample=0.7,
        random_state=42, l2_leaf_reg=0.1, rsm=0.8,
        cat_features=categorical_features, verbose=0, allow_writing_files=False
    )
    final_model.fit(X, y)
    model_filename = os.path.join(models_out_path, f'{target_col}.json')
    final_model.save_model(model_filename)
    print(f"  Final model saved to: {model_filename}")

if __name__ == '__main__':
    targets_to_run = ['gpp', 'nee', 'reco', 'ch4_flux_total']
    for target in targets_to_run:
        print(f"\n{'='*50}\nRUNNING ANALYSIS FOR: {target.upper()}\n{'='*50}")
        run_loso_analysis(target_col=target)
        print(f"\n{'='*50}\nCOMPLETED ANALYSIS FOR: {target.upper()}\n{'='*50}")
